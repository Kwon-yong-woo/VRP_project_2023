# %%
import os
import random
import time
import datetime
import torch
import argparse

import pandas as pd
import numpy as np

# %%
from transformers import BertTokenizer, BertForSequenceClassification, AdamW, get_linear_schedule_with_warmup, BertConfig

from tensorflow.keras.preprocessing.sequence import pad_sequences
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
torch.cuda.is_available()
# Out:
# False

# %%
# data Loading 
### dataframe의 col 이름이 document, label 이어야 한다. 
def load_data(args):
    temp = pd.read_csv(args.raw_data, sep="\t",encoding='cp949')
    temp = temp
    document = temp.document.tolist()
    labels = temp.label.tolist()
    return document, labels
# Marking 앞단 끝단에 
def add_special_token(document):
    added = ["[CLS]" + str(sentence) + "[SEP]" for sentence in document]
    return added
# Tokenization
def tokenization(document, mode="huggingface"):
    if mode == "huggingface":
        tokenizer = BertTokenizer.from_pretrained(
                'bert-base-multilingual-cased', 
                do_lower_case=False,
                )
        tokenized = [tokenizer.tokenize(sentence) for sentence in document]
        ids = [tokenizer.convert_tokens_to_ids(sentence) for sentence in tokenized]
        return ids
# Padding = 길이 일치
def padding(ids, args):
    ids = pad_sequences(ids, maxlen=args.max_len, dtype="long", truncating='post', padding='post')
    return ids

def attention_mask(ids):
    masks = []
    for id in ids:
        mask = [float(i>0) for i in id]
        masks.append(mask)
    return masks

def preprocess(args):
    document, labels = load_data(args)
    document = add_special_token(document)
    ids = tokenization(document)
    ids = padding(ids, args)
    masks = attention_mask(ids)
    del document
    return ids, masks, labels

def train_test_data_split(ids, masks, labels):
    train_ids, test_ids, train_labels, test_labels = train_test_split(ids, labels
                                                                      , random_state=42, test_size=0.1)
    train_masks, test_masks, _, _ = train_test_split(masks, ids, random_state=42, test_size=0.1)
    return train_ids, train_masks, train_labels, test_ids, test_masks, test_labels

def build_dataloader(ids, masks, label, args):
    dataloader = TensorDataset(torch.tensor(ids), torch.tensor(masks), torch.tensor(label))
    dataloader = DataLoader(dataloader, sampler=RandomSampler(dataloader), batch_size=args.batch_size)
    return dataloader
##############################################################################

def build_model(args):
    model = BertForSequenceClassification.from_pretrained("bert-base-multilingual-cased", num_labels=args.num_labels)
    if torch.cuda.is_available():
        device = torch.device("cuda")
        print(f"{torch.cuda.get_device_name(0)} available")
        model = model.cuda()
    else:
        device = torch.device("cpu")
        print("no GPU available")
        model = model
    return model, device

def test(test_dataloader, model, device):
    model.eval()
    total_accuracy = 0
    for batch in test_dataloader:
        batch = tuple(index.to(device) for index in batch)
        ids, masks, labels = batch
        with torch.no_grad():
            outputs = model(ids, token_type_ids=None, attention_mask=masks)
        pred = [torch.argmax(logit).cpu().detach().item() for logit in outputs.logits]
        true = [label for label in labels.cpu().numpy()]
        accuracy = accuracy_score(true, pred)
        total_accuracy += accuracy
    avg_accuracy = total_accuracy/len(test_dataloader)
    print(f"test AVG accuracy : {avg_accuracy: .2f}")
    return avg_accuracy

def train(train_dataloader, test_dataloader, args):
    model, device = build_model(args)
    
    # 옵티마이저 정의 
    optimizer = AdamW(model.parameters(), lr=2e-5, eps=1e-8)
    
    # learning rate decay
    scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=len(train_dataloader)*args.epochs)
    
    # 시드 고정
    random.seed(args.seed_val)
    np.random.seed(args.seed_val)
    torch.manual_seed(args.seed_val)
    torch.cuda.manual_seed_all(args.seed_val)
    

    
    # 그레디언트 초기화
    model.zero_grad()
    for epoch in range(0, args.epochs):
        # 훈련모드 
        model.train()
        
        # 로스와 정확도 초기화
        total_loss, total_accuracy = 0, 0
        print("-"*30)
        for step, batch in enumerate(train_dataloader):
            if step % 500 == 0 :
                print(f"Epoch : {epoch+1} in {args.epochs} / Step : {step}")

            # 배치 선정
            batch = tuple(index.to(device) for index in batch)
            ids, masks, labels, = batch

            # forward
            outputs = model(ids, token_type_ids=None, attention_mask=masks, labels=labels)
            
            # loss 도출
            loss = outputs.loss
            total_loss += loss.item()

            # 정확도 도출
            pred = [torch.argmax(logit).cpu().detach().item() for logit in outputs.logits]
            true = [label for label in labels.cpu().numpy()]
            accuracy = accuracy_score(true, pred)
            total_accuracy += accuracy
            
            # 그레디언트 연산
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            
            # 파라미터 업데이트
            optimizer.step()
            
            # 러닝레이트 최적화
            scheduler.step()
            
            # 그레디언트 초기화
            model.zero_grad()
            
        # epoch 당 loss 와 정확도 계산
        avg_loss = total_loss / len(train_dataloader)
        avg_accuracy = total_accuracy/len(train_dataloader)
        print(f" {epoch+1} Epoch Average train loss :  {avg_loss}")
        print(f" {epoch+1} Epoch Average train accuracy :  {avg_accuracy}")
        
        # test 수행
        acc = test(test_dataloader, model, device)
        
        # 모델 저장
        os.makedirs("results", exist_ok=True)
        #f = os.path.join("results", f'epoch_{epoch+1}_evalAcc_{acc*100:.0f}.pth')
        f = args.save_data + "\\" + "results_" + f'epoch_{epoch+1}_evalAcc_{acc*100:.0f}.pth'
        torch.save(model.state_dict(), f)
        print('Saved checkpoint:', f)

def run(args):
    ids, masks, labels = preprocess(args)
    train_ids, train_masks, train_labels, test_ids, test_masks, test_labels = train_test_data_split(ids, masks, labels)
    train_dataloader = build_dataloader(train_ids, train_masks, train_labels, args)
    test_dataloader = build_dataloader(test_ids, test_masks, test_labels, args)
    train(train_dataloader, test_dataloader, args)

# %%
load_path = r"C:\Users\Samsung\Desktop\all\Project\23_VRPTW\Classification\{}"
save_path = r"C:\Users\Samsung\Desktop\all\Project\23_VRPTW\Classification\model"

# %%
if __name__ == "__main__":
    parser = argparse.ArgumentParser()

    parser.add_argument("-raw_data", default=load_path.format("Data_Train.txt"))
    parser.add_argument("-save_data", default=save_path)
    
    parser.add_argument("-max_len", default=10, type=int)
    parser.add_argument("-batch_size", default=4, type=int)
    parser.add_argument("-num_labels", default=21, type=int)
    parser.add_argument("-epochs", default=4, type=int)
    parser.add_argument("-seed_val", default=4, type=int)

    #args = parser.parse_args()
    args,_ = parser.parse_known_args()
    run(args)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# C:\Users\Samsung\anaconda3\Lib\site-packages\transformers\optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# no GPU available
# ------------------------------
# Epoch : 1 in 4 / Step : 0
# Epoch : 1 in 4 / Step : 500
# Epoch : 1 in 4 / Step : 1000
#  1 Epoch Average train loss :  2.0711011273898503
#  1 Epoch Average train accuracy :  0.3874761222540592
# test AVG accuracy :  0.57
# Saved checkpoint: C:\Users\Samsung\Desktop\all\Project\23_VRPTW\Classification\model\results_epoch_1_evalAcc_57.pth
# ------------------------------
# Epoch : 2 in 4 / Step : 0
# Epoch : 2 in 4 / Step : 500
# Epoch : 2 in 4 / Step : 1000
#  2 Epoch Average train loss :  1.2685430964353603
#  2 Epoch Average train accuracy :  0.6525191021967526
# test AVG accuracy :  0.64
# Saved checkpoint: C:\Users\Samsung\Desktop\all\Project\23_VRPTW\Classification\model\results_epoch_2_evalAcc_64.pth
# ------------------------------
# Epoch : 3 in 4 / Step : 0
# Epoch : 3 in 4 / Step : 500
# Epoch : 3 in 4 / Step : 1000
#  3 Epoch Average train loss :  0.878015460593247
#  3 Epoch Average train accuracy :  0.7679083094555874
# test AVG accuracy :  0.69
# Saved checkpoint: C:\Users\Samsung\Desktop\all\Project\23_VRPTW\Classification\model\results_epoch_3_evalAcc_69.pth
# ------------------------------
# Epoch : 4 in 4 / Step : 0
# Epoch : 4 in 4 / Step : 500
# Epoch : 4 in 4 / Step : 1000
#  4 Epoch Average train loss :  0.6526285820850104
#  4 Epoch Average train accuracy :  0.8298710601719198
# test AVG accuracy :  0.71
# Saved checkpoint: C:\Users\Samsung\Desktop\all\Project\23_VRPTW\Classification\model\results_epoch_4_evalAcc_71.pth

# %%
parser = argparse.ArgumentParser()

# %%
def load_data(args):
    temp = pd.read_csv(args, sep="\t",encoding='cp949')
    temp = temp
    document = temp.document.tolist()
    labels = temp.label.tolist()
    return document, labels

# %%
path_ = r"C:\Users\Samsung\Desktop\all\Project\23_VRPTW\Classification\Data_Train.txt"

# %%
doc,lab = load_data(path_)

# %%
def add_special_token(document):
    added = ["[CLS]" + str(sentence) + "[SEP]" for sentence in document]
    return added

# %%
def tokenization(document):
    tokenizer = BertTokenizer.from_pretrained(
            'bert-base-multilingual-cased', 
            do_lower_case=False,
            )
    tokenized = [tokenizer.tokenize(sentence) for sentence in document]
    ids = [tokenizer.convert_tokens_to_ids(sentence) for sentence in tokenized]
    return ids

# %%
tokenization(doc)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# C:\Users\Samsung\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:137: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Samsung\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# [[9734, 12310, 13890, 10533, 47407],
#  [11474,
#   14250,
#   57908,
#   10410,
#   33824,
#   26037,
#   10550,
#   148,
#   11273,
#   25853,
#   10240,
#   113,
#   9318,
#   118768,
#   17342,
#   17342,
#   24891,
#   92688,
#   12692,
#   88332,
#   119188,
#   114,
#   122,
#   78560,
#   10174,
#   113,
#   25853,
#   10240,
#   114,
#   9001,
#   18778],
#  [193, 15184, 12692, 28188, 122, 47407],
#  [8865, 16985, 11261, 51533],
#  [8887, 49919, 113, 10244, 17196, 114],
#  [9049, 119308, 35506, 89108, 9420, 11882, 18392, 16323, 12605],
#  [9056, 37388, 38851, 15001, 9056, 68055, 14801, 9435, 16605, 17730],
#  [9091, 118667, 13764, 30134, 44026, 10240],
#  [100],
#  [100, 113, 20843, 10240, 120, 9355, 114],
#  [9161,
#   92688,
#   31401,
#   60479,
#   12692,
#   92564,
#   80174,
#   12605,
#   119073,
#   119367,
#   88332,
#   69168,
#   10929,
#   10240],
#  [9272,
#   48446,
#   119351,
#   17342,
#   51533,
#   12605,
#   46150,
#   14153,
#   45725,
#   28847,
#   10929,
#   10240],
#  [9291, 92564, 62200],
#  [9318, 16439, 16439, 89478],
#  [9318, 119169, 61156, 119430, 10016, 21928],
#  [9318,
#   10739,
#   119346,
#   9827,
#   9376,
#   12692,
#   24891,
#   9962,
#   15001,
#   9428,
#   119409,
#   12310],
#  [9323, 12945, 118956, 9113, 56645, 119087, 113, 9418, 30873, 48446, 114],
#  [9449,
#   50450,
#   11102,
#   27355,
#   42815,
#   9944,
#   30873,
#   12605,
#   9663,
#   12508,
#   42337,
#   9280,
#   77692,
#   16664,
#   63308],
#  [9477, 46150, 14153, 45725, 14867, 15410, 10240],
#  [9626, 21789, 13890, 9405, 51431, 14867, 9027, 71013, 12224, 10240],
#  [9634, 38688, 46520],
#  [9638, 60479, 119175, 100, 113, 8909, 114],
#  [9641, 10954, 31605, 31605, 9734, 30005, 12692],
#  [9684, 11287, 38696, 9420, 24017, 118667, 18622, 124, 47407],
#  [9735,
#   14646,
#   28188,
#   118760,
#   9448,
#   118992,
#   111,
#   10392,
#   10410,
#   132,
#   9901,
#   22695,
#   22695,
#   119010],
#  [9751, 16605, 14279, 9751, 16605, 22458, 23160, 11766, 10240],
#  [100],
#  [9928, 12092, 126, 47407],
#  [9928,
#   119351,
#   10739,
#   26444,
#   89851,
#   17342,
#   12605,
#   113,
#   8848,
#   13764,
#   119367,
#   118667,
#   114,
#   123,
#   117,
#   10365,
#   47407],
#  [9942,
#   56645,
#   14040,
#   69592,
#   21876,
#   119421,
#   15001,
#   24982,
#   25503,
#   22695,
#   10739,
#   48387,
#   113,
#   101820,
#   10161,
#   114],
#  [9968,
#   25503,
#   118920,
#   12605,
#   22695,
#   15001,
#   9113,
#   56645,
#   119087,
#   113,
#   9418,
#   30873,
#   48446,
#   114],
#  [9993,
#   41620,
#   9485,
#   20308,
#   118906,
#   119440,
#   9607,
#   41919,
#   9694,
#   27506,
#   54055,
#   58303],
#  [113, 9001, 18778, 114, 100],
#  [113, 9027, 71013, 114, 9259, 25517, 118956, 42144, 48599, 20305, 10240],
#  [113, 9139, 30005, 10459, 35506, 35866, 114, 9139],
#  [113, 9208, 28911, 114, 8909, 21386, 119312, 118802, 14646, 12310, 103155],
#  [113,
#   9208,
#   28911,
#   114,
#   9538,
#   119253,
#   20308,
#   37388,
#   106826,
#   32792,
#   10929,
#   11447],
#  [113,
#   9246,
#   21386,
#   6843,
#   9281,
#   21386,
#   114,
#   9291,
#   11664,
#   20479,
#   18784,
#   13890,
#   13545,
#   63308],
#  [113,
#   9335,
#   20308,
#   114,
#   9448,
#   11664,
#   12310,
#   79544,
#   119092,
#   20479,
#   15891,
#   53398,
#   10929,
#   10240],
#  [113,
#   9335,
#   20308,
#   114,
#   9779,
#   119330,
#   79544,
#   119092,
#   20479,
#   15891,
#   53398,
#   10929,
#   10240],
#  [113,
#   9366,
#   14646,
#   21386,
#   119031,
#   23811,
#   10622,
#   40032,
#   11664,
#   114,
#   9405,
#   11882,
#   9486,
#   57030,
#   80468,
#   11090,
#   13545,
#   63308],
#  [113, 9379, 71439, 114, 9486, 29364, 17138, 100],
#  [113, 9489, 37093, 114, 9834, 67527, 46150, 12605, 22695, 122, 12030],
#  [113,
#   9499,
#   114,
#   100,
#   9692,
#   12030,
#   8865,
#   47181,
#   11102,
#   9499,
#   11664,
#   119274,
#   13890,
#   10757,
#   11447],
#  [113,
#   9519,
#   10739,
#   119324,
#   12965,
#   114,
#   9559,
#   12965,
#   55530,
#   119351,
#   119070,
#   101450,
#   118900,
#   119380,
#   52015,
#   30873,
#   14040,
#   113,
#   8892,
#   15001,
#   114],
#  [113,
#   9519,
#   10739,
#   119324,
#   12965,
#   114,
#   9559,
#   55530,
#   28911,
#   119070,
#   101450,
#   118900,
#   119380,
#   52015,
#   30873,
#   14040,
#   24982,
#   15184,
#   113,
#   9378,
#   35866,
#   52015,
#   30873,
#   14040,
#   10759,
#   116,
#   100,
#   114],
#  [113,
#   9519,
#   10739,
#   119324,
#   12965,
#   114,
#   9559,
#   55530,
#   119351,
#   119070,
#   101450,
#   118900,
#   119380,
#   52015,
#   30873,
#   14040,
#   24982,
#   15184,
#   113,
#   8924,
#   27654,
#   52015,
#   30873,
#   119070,
#   10759,
#   116,
#   100,
#   114],
#  [113,
#   9519,
#   10739,
#   119324,
#   12965,
#   114,
#   9559,
#   55530,
#   119351,
#   119070,
#   101450,
#   118900,
#   119380,
#   52015,
#   30873,
#   14040,
#   24982,
#   15184,
#   113,
#   8924,
#   27654,
#   52015,
#   30873,
#   14040,
#   10759,
#   116,
#   100,
#   114],
#  [113,
#   9519,
#   10739,
#   119324,
#   12965,
#   114,
#   9559,
#   55530,
#   119351,
#   119070,
#   101450,
#   118900,
#   119380,
#   52015,
#   30873,
#   14040,
#   24982,
#   15184,
#   113,
#   9958,
#   119418,
#   20308,
#   52015,
#   30873,
#   14040,
#   10759,
#   116,
#   100,
#   114],
#  [113,
#   9519,
#   10739,
#   119324,
#   12965,
#   114,
#   9559,
#   55530,
#   119351,
#   119070,
#   101450,
#   118900,
#   119380,
#   52015,
#   30873,
#   14040,
#   24982,
#   15184,
#   113,
#   9958,
#   119418,
#   20308,
#   52015,
#   30873,
#   14040,
#   10759,
#   116,
#   100,
#   114],
#  [113,
#   9519,
#   10739,
#   119324,
#   12965,
#   114,
#   100,
#   113,
#   9056,
#   20308,
#   52015,
#   17342,
#   21614,
#   114,
#   10150,
#   10240],
#  [113,
#   9519,
#   10739,
#   119324,
#   12965,
#   114,
#   100,
#   113,
#   9376,
#   17342,
#   21614,
#   114,
#   10150,
#   10240],
#  [113, 9532, 25503, 119387, 114, 9390, 39420, 13764],
#  [113, 9665, 114, 9996, 28143, 38631, 40991, 168, 9706, 48533],
#  [113,
#   9689,
#   114,
#   9385,
#   78136,
#   56645,
#   9318,
#   16439,
#   16439,
#   118912,
#   27355,
#   42815,
#   9318,
#   16439,
#   16439,
#   79544,
#   16017,
#   77526],
#  [113,
#   9689,
#   114,
#   9580,
#   118841,
#   12310,
#   124,
#   37712,
#   9963,
#   41605,
#   78136,
#   9477,
#   119351,
#   10739,
#   20308,
#   13958,
#   11447,
#   192,
#   127,
#   36789],
#  [113, 9689, 114, 9641, 101322, 118746, 21386, 86015, 22458, 10150, 47407],
#  [113,
#   9689,
#   114,
#   8924,
#   27654,
#   9641,
#   14871,
#   11287,
#   16605,
#   21155,
#   8982,
#   16323,
#   118642,
#   119341,
#   16718,
#   10240],
#  [113,
#   9689,
#   114,
#   8924,
#   27654,
#   9641,
#   14871,
#   11287,
#   16605,
#   21155,
#   9657,
#   12965,
#   119341,
#   16718,
#   10240],
#  [113,
#   9689,
#   114,
#   8959,
#   119034,
#   21155,
#   52951,
#   9107,
#   118654,
#   56645,
#   9064,
#   10892,
#   9032,
#   118894,
#   12508,
#   23466,
#   122,
#   119,
#   126,
#   10240,
#   115,
#   10533,
#   11090],
#  [113,
#   9689,
#   114,
#   8965,
#   118694,
#   11018,
#   119312,
#   9252,
#   10892,
#   29364,
#   10530,
#   8909,
#   21386,
#   9759,
#   118802,
#   14646,
#   9727,
#   21789,
#   24974,
#   11093,
#   10240],
#  [113, 9689, 114, 9027, 71013, 100, 100, 10462, 119, 125, 10240],
#  [113, 9689, 114, 9027, 71013, 100, 9836, 37388, 21155, 10777, 10240],
#  [113,
#   9689,
#   114,
#   9027,
#   71013,
#   9330,
#   119444,
#   18778,
#   9379,
#   119003,
#   14867,
#   18948,
#   10240,
#   115,
#   125,
#   58303],
#  [113,
#   9689,
#   114,
#   9027,
#   71013,
#   9487,
#   17342,
#   14867,
#   113,
#   9268,
#   45725,
#   118963,
#   12605,
#   114,
#   11796,
#   11447,
#   192,
#   129,
#   36789],
#  [113,
#   9689,
#   114,
#   9027,
#   71013,
#   9521,
#   17138,
#   119341,
#   14867,
#   103917,
#   87372,
#   10240,
#   115,
#   127,
#   58303],
#  [113, 9689, 114, 9027, 71013, 9580, 119233, 12965, 38696, 12408, 10240],
#  [113, 9689, 114, 9027, 71013, 9581, 15891, 15891, 14867, 12545, 10240],
#  [113,
#   9689,
#   114,
#   9027,
#   119435,
#   68055,
#   27355,
#   119268,
#   9942,
#   17342,
#   36240,
#   9238,
#   119134,
#   105197,
#   13764,
#   70162,
#   118631,
#   16718,
#   11447,
#   192,
#   122,
#   36789],
#  [113,
#   9689,
#   114,
#   9056,
#   37388,
#   38851,
#   15001,
#   9663,
#   119405,
#   37819,
#   57030,
#   14279,
#   73450,
#   9450,
#   24982,
#   16605,
#   17730,
#   10757,
#   63308],
#  [113,
#   9689,
#   114,
#   9056,
#   37388,
#   38851,
#   15001,
#   9663,
#   119405,
#   37819,
#   57030,
#   14279,
#   73450,
#   9450,
#   24982,
#   16605,
#   17730,
#   113,
#   9675,
#   22695,
#   58303,
#   114,
#   12214,
#   63308],
#  [113,
#   9689,
#   114,
#   9069,
#   31720,
#   119422,
#   9993,
#   41620,
#   22333,
#   14040,
#   12508,
#   113,
#   9963,
#   114],
#  [113,
#   9689,
#   114,
#   9069,
#   14871,
#   9854,
#   37114,
#   57030,
#   11664,
#   119274,
#   13890,
#   13648,
#   11447],
#  [113,
#   9689,
#   114,
#   82642,
#   10530,
#   28396,
#   10530,
#   12605,
#   9786,
#   17342,
#   118930,
#   119286],
#  [113,
#   9689,
#   114,
#   9095,
#   14279,
#   11565,
#   111,
#   10392,
#   10410,
#   132,
#   139,
#   100,
#   10407,
#   110,
#   9879,
#   55670,
#   29364,
#   118969,
#   21825,
#   11447,
#   192,
#   122,
#   36789],
#  [113,
#   9689,
#   114,
#   9095,
#   14279,
#   11565,
#   111,
#   139,
#   9095,
#   14279,
#   9615,
#   10739,
#   20308,
#   26784,
#   118999,
#   45725,
#   10757,
#   77526,
#   192,
#   122,
#   36789],
#  [113,
#   9689,
#   114,
#   9095,
#   14279,
#   11565,
#   111,
#   139,
#   9095,
#   14279,
#   9615,
#   10739,
#   20308,
#   26784,
#   118999,
#   45725,
#   10757,
#   77526,
#   192,
#   10197,
#   36789],
#  [113,
#   9689,
#   114,
#   9095,
#   108280,
#   28396,
#   119123,
#   29455,
#   9083,
#   18392,
#   12692,
#   88332,
#   12965,
#   9456,
#   11664,
#   12310,
#   119218,
#   29268,
#   119,
#   126,
#   10240],
#  [113,
#   9689,
#   114,
#   9095,
#   108280,
#   28396,
#   119123,
#   29455,
#   9095,
#   14279,
#   8845,
#   50450,
#   48549,
#   12692,
#   59879,
#   11090,
#   8892,
#   118974,
#   10739,
#   119341,
#   9551,
#   119326,
#   11102,
#   20479,
#   29364,
#   17859,
#   10240],
#  [113,
#   9689,
#   114,
#   9095,
#   108280,
#   28396,
#   119123,
#   29455,
#   9095,
#   14279,
#   9651,
#   25486,
#   21386,
#   8892,
#   118974,
#   10739,
#   11093,
#   10240],
#  [113,
#   9689,
#   114,
#   9095,
#   108280,
#   28396,
#   119123,
#   29455,
#   9095,
#   14279,
#   119251,
#   18622,
#   9059,
#   63218,
#   48599,
#   42144,
#   10244,
#   10240,
#   113,
#   9580,
#   12692,
#   12508,
#   49881,
#   114],
#  [113,
#   9689,
#   114,
#   9095,
#   108280,
#   28396,
#   119123,
#   29455,
#   9095,
#   14279,
#   119251,
#   18622,
#   9059,
#   63218,
#   48599,
#   42144,
#   10244,
#   10240,
#   113,
#   9757,
#   25517,
#   11261,
#   119415,
#   114],
#  [113,
#   9689,
#   114,
#   9095,
#   108280,
#   28396,
#   119123,
#   29455,
#   100,
#   9074,
#   100372,
#   21614,
#   100,
#   13849,
#   10240],
#  [113,
#   9689,
#   114,
#   9095,
#   108280,
#   28396,
#   119123,
#   29455,
#   9543,
#   30134,
#   8935,
#   14646,
#   66540,
#   10462,
#   10240],
#  [113,
#   9689,
#   114,
#   9095,
#   108280,
#   28396,
#   119123,
#   29455,
#   9543,
#   30134,
#   9448,
#   11664,
#   12310,
#   22458,
#   23160,
#   20479,
#   27296,
#   11447],
#  [113,
#   9689,
#   114,
#   9095,
#   108280,
#   28396,
#   119123,
#   29455,
#   9543,
#   30134,
#   9460,
#   17342,
#   9730,
#   118794,
#   119027,
#   33188,
#   119218,
#   24253,
#   10240],
#  [113,
#   9689,
#   114,
#   9095,
#   108280,
#   28396,
#   119123,
#   29455,
#   9543,
#   30134,
#   9460,
#   17342,
#   9730,
#   118794,
#   83811,
#   21789,
#   13890,
#   27296,
#   10240],
#  [113,
#   9689,
#   114,
#   9095,
#   108280,
#   28396,
#   119123,
#   29455,
#   9543,
#   30134,
#   9460,
#   17342,
#   9879,
#   11903,
#   12692,
#   118773,
#   119218,
#   24253,
#   10240],
#  [113,
#   9689,
#   114,
#   9095,
#   108280,
#   28396,
#   119123,
#   29455,
#   9543,
#   30134,
#   9460,
#   17342,
#   9879,
#   11903,
#   12692,
#   119027,
#   21611,
#   119341,
#   27296,
#   11447],
#  [113,
#   9689,
#   114,
#   9095,
#   108280,
#   28396,
#   119123,
#   29455,
#   9543,
#   30134,
#   9665,
#   70915,
#   119218,
#   24253,
#   10240],
#  [113,
#   9689,
#   114,
#   9095,
#   108280,
#   28396,
#   119123,
#   29455,
#   9543,
#   30134,
#   118667,
#   18622,
#   9543,
#   30134,
#   100,
#   9379,
#   119003,
#   118667,
#   18622,
#   12048,
#   10240],
#  [113,
#   9689,
#   114,
#   9095,
#   108280,
#   28396,
#   119123,
#   29455,
#   9819,
#   24206,
#   119391,
#   9568,
#   42815,
#   17342,
#   118838,
#   12214,
#   10147,
#   11369],
#  [113,
#   9689,
#   114,
#   9122,
#   119415,
#   11903,
#   15184,
#   25517,
#   31065,
#   100,
#   9186,
#   12030,
#   30005,
#   27355],
#  [113,
#   9689,
#   114,
#   100,
#   48253,
#   23811,
#   108578,
#   9701,
#   40958,
#   100,
#   9670,
#   43022,
#   119235,
#   13890,
#   118912,
#   17859,
#   10240],
#  [113,
#   9689,
#   114,
#   9208,
#   28911,
#   119027,
#   47181,
#   32232,
#   39041,
#   9365,
#   21386,
#   118958,
#   14867,
#   111,
#   9365,
#   21386,
#   29455,
#   119003,
#   118958,
#   14867,
#   53258,
#   11447],
#  [113,
#   9689,
#   114,
#   9208,
#   28911,
#   17730,
#   11882,
#   9606,
#   18778,
#   14843,
#   118832,
#   100,
#   100,
#   9238,
#   119416,
#   168,
#   15844,
#   10240],
#  [113,
#   9689,
#   114,
#   9252,
#   10892,
#   18778,
#   14523,
#   9252,
#   10892,
#   29364,
#   10530,
#   9568,
#   14523,
#   16323,
#   119312,
#   9819,
#   29364,
#   12186,
#   63308],
#  [113,
#   9689,
#   114,
#   9252,
#   10892,
#   29364,
#   10530,
#   79633,
#   14871,
#   52951,
#   9462,
#   118802,
#   14646,
#   113,
#   8909,
#   21386,
#   114,
#   11176,
#   11447],
#  [113, 9689, 114, 9309, 21928, 9580, 119233, 12965, 118948, 20479],
#  [113,
#   9689,
#   114,
#   9385,
#   78136,
#   56645,
#   9599,
#   118911,
#   118832,
#   8924,
#   73352,
#   119412,
#   56645,
#   12030,
#   11766,
#   63308],
#  [113,
#   9689,
#   114,
#   9385,
#   78136,
#   56645,
#   9599,
#   118911,
#   118832,
#   9468,
#   10739,
#   20308,
#   9133,
#   12310,
#   12048,
#   63308],
#  [113,
#   9689,
#   114,
#   9385,
#   78136,
#   56645,
#   9599,
#   118911,
#   118832,
#   102574,
#   42144,
#   10739,
#   28188,
#   119375,
#   12605,
#   8924,
#   73352,
#   119307,
#   9310,
#   12605,
#   9344,
#   12692,
#   11766,
#   63308],
#  [113,
#   9689,
#   114,
#   9385,
#   78136,
#   56645,
#   9757,
#   25517,
#   9372,
#   12965,
#   119089,
#   19105,
#   25517,
#   11766,
#   63308],
#  [113,
#   9689,
#   114,
#   9405,
#   20626,
#   14423,
#   67527,
#   9069,
#   67527,
#   18471,
#   9579,
#   41919,
#   118996,
#   12965,
#   119010,
#   100,
#   10757,
#   11447,
#   192,
#   122,
#   36789],
#  [113,
#   9689,
#   114,
#   9405,
#   20626,
#   14423,
#   67527,
#   9069,
#   67527,
#   18471,
#   9579,
#   41919,
#   118996,
#   12965,
#   119010,
#   9472,
#   20308,
#   67527,
#   10757,
#   11447,
#   192,
#   122,
#   36789],
#  [113,
#   9689,
#   114,
#   9410,
#   35115,
#   21155,
#   52951,
#   9238,
#   119134,
#   119267,
#   119267,
#   18622,
#   24891,
#   88332,
#   119188,
#   12367,
#   11447],
#  [113,
#   9689,
#   114,
#   9467,
#   119407,
#   67527,
#   21155,
#   52951,
#   9751,
#   16605,
#   14279,
#   9521,
#   16323,
#   21711,
#   9024,
#   30842,
#   18778,
#   55530,
#   23466,
#   12605,
#   22695,
#   18392,
#   9258,
#   21614,
#   118681,
#   28911,
#   12310,
#   45987,
#   10929,
#   10240],
#  [113,
#   9689,
#   114,
#   9477,
#   119180,
#   118972,
#   56710,
#   12605,
#   9157,
#   48653,
#   9032,
#   27023,
#   9418,
#   30873,
#   15001,
#   13912,
#   10240],
#  [113,
#   9689,
#   114,
#   9477,
#   119180,
#   118972,
#   56710,
#   12605,
#   9491,
#   119412,
#   9056,
#   20308,
#   24206,
#   24206,
#   28188,
#   100,
#   11370,
#   10240],
#  [113,
#   9689,
#   114,
#   9477,
#   119180,
#   118972,
#   56710,
#   12605,
#   9491,
#   119412,
#   9551,
#   78136,
#   56645,
#   10739,
#   100,
#   11370,
#   10240],
#  [113,
#   9689,
#   114,
#   9477,
#   119180,
#   118972,
#   56710,
#   12605,
#   9491,
#   119412,
#   10016,
#   36240,
#   13764,
#   100,
#   11370,
#   10240],
#  [113,
#   9689,
#   114,
#   9477,
#   119180,
#   118972,
#   56710,
#   12605,
#   9779,
#   119330,
#   9359,
#   11261,
#   77884,
#   17730,
#   9901,
#   12605,
#   22695,
#   9418,
#   30873,
#   15001,
#   13912,
#   10240],
#  [113,
#   9689,
#   114,
#   9487,
#   108280,
#   28396,
#   16985,
#   10739,
#   9641,
#   14871,
#   11287,
#   16605,
#   21155,
#   9087,
#   11287,
#   25503,
#   119341,
#   16718,
#   10240],
#  [113,
#   9689,
#   114,
#   9487,
#   108280,
#   28396,
#   16985,
#   10739,
#   9641,
#   14871,
#   11287,
#   16605,
#   21155,
#   9448,
#   118920,
#   12692,
#   118642,
#   119341,
#   16718,
#   10240],
#  [113,
#   9689,
#   114,
#   9500,
#   24974,
#   49212,
#   119123,
#   29455,
#   9812,
#   48446,
#   9462,
#   15891,
#   124,
#   118636,
#   9083,
#   25517,
#   10244,
#   115,
#   10244],
#  [113,
#   9689,
#   114,
#   9500,
#   24974,
#   49212,
#   119123,
#   29455,
#   9812,
#   48446,
#   9462,
#   15891,
#   124,
#   118636,
#   28911,
#   25517,
#   10244,
#   115,
#   10244],
#  [113,
#   9689,
#   114,
#   9500,
#   24974,
#   49212,
#   119123,
#   29455,
#   9812,
#   48446,
#   9966,
#   70915,
#   10739,
#   9405,
#   12945,
#   119025,
#   13389,
#   115,
#   123],
#  [113,
#   9689,
#   114,
#   9500,
#   24974,
#   49212,
#   119123,
#   29455,
#   9812,
#   48446,
#   9559,
#   25517,
#   78136,
#   27654,
#   13912,
#   115,
#   124,
#   113,
#   9294,
#   79544,
#   114],
#  [113,
#   9689,
#   114,
#   9500,
#   24974,
#   49212,
#   119123,
#   29455,
#   10003,
#   56645,
#   46861,
#   9246,
#   18392,
#   15001,
#   113,
#   9796,
#   114,
#   10407,
#   100372],
#  [113,
#   9689,
#   114,
#   9516,
#   119113,
#   119405,
#   15001,
#   9516,
#   119113,
#   11261,
#   100,
#   33283,
#   11447],
#  [113,
#   9689,
#   114,
#   9516,
#   119113,
#   119405,
#   15001,
#   9516,
#   119113,
#   11261,
#   100,
#   25676,
#   11447],
#  [113,
#   9689,
#   114,
#   9519,
#   10739,
#   48446,
#   119412,
#   17342,
#   25517,
#   12605,
#   118927,
#   119375,
#   9519,
#   10739,
#   48446,
#   10530,
#   44359,
#   100,
#   9376,
#   10739,
#   100,
#   10208,
#   63308],
#  [113,
#   9689,
#   114,
#   100,
#   9901,
#   69592,
#   56645,
#   12030,
#   48387,
#   12605,
#   119181,
#   118625,
#   113,
#   9793,
#   48446,
#   26444,
#   10739,
#   114],
#  [113,
#   9689,
#   114,
#   9559,
#   12605,
#   119123,
#   119405,
#   15001,
#   70069,
#   10723,
#   8909,
#   21386,
#   119312,
#   118802,
#   14646,
#   9727,
#   21789,
#   120,
#   9365,
#   119285,
#   118635,
#   24974,
#   12048,
#   10240],
#  [113,
#   9689,
#   114,
#   9559,
#   12605,
#   97146,
#   49212,
#   119027,
#   35115,
#   9410,
#   35115,
#   20309,
#   119010,
#   9323,
#   119449,
#   22458,
#   22200,
#   8964,
#   11664,
#   17196,
#   23811,
#   15935,
#   10240,
#   125,
#   21789,
#   58303],
#  [113,
#   9689,
#   114,
#   9559,
#   12605,
#   97146,
#   49212,
#   119027,
#   35115,
#   9410,
#   35115,
#   20309,
#   119010,
#   9323,
#   119449,
#   22458,
#   22200,
#   100,
#   15935,
#   10240,
#   125,
#   21789,
#   58303],
#  [113,
#   9689,
#   114,
#   9559,
#   12605,
#   97146,
#   49212,
#   119027,
#   35115,
#   9410,
#   35115,
#   20309,
#   119010,
#   9323,
#   119449,
#   22458,
#   22200,
#   9420,
#   24017,
#   21711,
#   119253,
#   15935,
#   10240,
#   125,
#   21789,
#   58303],
#  [113,
#   9689,
#   114,
#   9559,
#   12605,
#   97146,
#   49212,
#   119027,
#   35115,
#   9410,
#   35115,
#   20309,
#   119010,
#   9323,
#   119449,
#   22458,
#   22200,
#   100,
#   22296,
#   10240,
#   125,
#   21789,
#   58303],
#  [113,
#   9689,
#   114,
#   9559,
#   10739,
#   18622,
#   10530,
#   12605,
#   119405,
#   15001,
#   8920,
#   12692,
#   217,
#   9499,
#   11882,
#   9299,
#   11261,
#   19105,
#   9706,
#   10892,
#   9711,
#   118969,
#   13912,
#   10240],
#  [113,
#   9689,
#   114,
#   9562,
#   12508,
#   24017,
#   119446,
#   71439,
#   47181,
#   9057,
#   21876,
#   78136,
#   35866,
#   15184,
#   9532,
#   118818,
#   15184,
#   100,
#   9946,
#   28188,
#   25503,
#   9213,
#   24891,
#   101820,
#   11369],
#  [113,
#   9689,
#   114,
#   9562,
#   12508,
#   24017,
#   119446,
#   71439,
#   47181,
#   9238,
#   86933,
#   9057,
#   21876,
#   78136,
#   35866,
#   15184,
#   9532,
#   118818,
#   15184,
#   100,
#   9011,
#   118882,
#   12692,
#   9519,
#   89523,
#   97146,
#   35922,
#   10147,
#   11369],
#  [113,
#   9689,
#   114,
#   9562,
#   12508,
#   24017,
#   119446,
#   71439,
#   47181,
#   9379,
#   119166,
#   15001,
#   9946,
#   26444,
#   16985,
#   61156,
#   16985,
#   9947,
#   119087,
#   9901,
#   21614,
#   28911,
#   90850,
#   10296,
#   20309,
#   113,
#   9995,
#   11102,
#   9946,
#   14646,
#   119358,
#   114,
#   10803,
#   11447],
#  [113,
#   9689,
#   114,
#   9562,
#   12508,
#   24017,
#   119446,
#   71439,
#   47181,
#   9435,
#   10739,
#   28396,
#   28396,
#   118873,
#   24891,
#   9336,
#   92564,
#   9967,
#   77692,
#   9962,
#   15001,
#   69592,
#   14040,
#   9238,
#   119373,
#   17342,
#   10739,
#   48036,
#   10757,
#   63308,
#   9901,
#   27355,
#   54141,
#   79544],
#  [113,
#   9689,
#   114,
#   9562,
#   12508,
#   24017,
#   119446,
#   71439,
#   47181,
#   9435,
#   10739,
#   28396,
#   28396,
#   118873,
#   24891,
#   9336,
#   92564,
#   9967,
#   77692,
#   9962,
#   15001,
#   69592,
#   14040,
#   9238,
#   119373,
#   12965,
#   97146,
#   18622,
#   10757,
#   63308,
#   9485,
#   15184,
#   30873,
#   12605,
#   79544],
#  [113,
#   9689,
#   114,
#   9562,
#   12508,
#   24017,
#   119446,
#   71439,
#   47181,
#   9460,
#   68984,
#   30005,
#   22695,
#   118766,
#   9202,
#   24891,
#   23811,
#   12692,
#   9318,
#   48446,
#   69592,
#   14040,
#   13545,
#   10240],
#  [113,
#   9689,
#   114,
#   9562,
#   12508,
#   24017,
#   119446,
#   71439,
#   47181,
#   9562,
#   17342,
#   12605,
#   90833,
#   9612,
#   54141,
#   118663,
#   118857,
#   9485,
#   20308,
#   118906,
#   9359,
#   118900,
#   119123,
#   84372,
#   9559,
#   119044,
#   12605,
#   11766,
#   63308],
#  [113,
#   9689,
#   114,
#   9562,
#   12508,
#   24017,
#   119446,
#   71439,
#   47181,
#   9582,
#   54141,
#   42144,
#   48446,
#   9083,
#   18392,
#   12692,
#   9428,
#   20308,
#   67527,
#   9901,
#   27355,
#   18622,
#   128,
#   63308,
#   115,
#   124,
#   58303],
#  [113,
#   9689,
#   114,
#   9562,
#   12508,
#   24017,
#   119446,
#   71439,
#   47181,
#   9582,
#   54141,
#   42144,
#   48446,
#   9347,
#   118922,
#   31605,
#   119274,
#   118865,
#   12605,
#   46150,
#   9241,
#   12692,
#   15001,
#   39420,
#   119431,
#   12692,
#   9477,
#   20308,
#   118867,
#   9318,
#   48446,
#   119327,
#   118873,
#   48387,
#   122,
#   11369],
#  [113,
#   9689,
#   114,
#   9562,
#   12508,
#   24017,
#   119446,
#   71439,
#   47181,
#   9582,
#   54141,
#   42144,
#   48446,
#   9435,
#   118689,
#   23811,
#   9336,
#   92564,
#   9959,
#   77692,
#   9962,
#   15001,
#   69592,
#   14040,
#   9186,
#   118936,
#   79544,
#   10777,
#   63308],
#  [113,
#   9689,
#   114,
#   9562,
#   12508,
#   24017,
#   119446,
#   71439,
#   47181,
#   9582,
#   54141,
#   42144,
#   48446,
#   9435,
#   118689,
#   23811,
#   9336,
#   92564,
#   9959,
#   77692,
#   9962,
#   15001,
#   69592,
#   14040,
#   9186,
#   118936,
#   79544,
#   12214,
#   63308],
#  [113,
#   9689,
#   114,
#   9562,
#   12508,
#   24017,
#   119446,
#   71439,
#   47181,
#   9582,
#   54141,
#   42144,
#   48446,
#   9962,
#   15001,
#   9415,
#   25503,
#   22695,
#   10739,
#   48387,
#   8874,
#   113,
#   9559,
#   66554,
#   119153,
#   114,
#   23144,
#   63308],
#  [113,
#   9689,
#   114,
#   9562,
#   12508,
#   24017,
#   119446,
#   71439,
#   47181,
#   9690,
#   119144,
#   9751,
#   25387,
#   14279,
#   10919,
#   10240],
#  [113,
#   9689,
#   114,
#   9562,
#   12508,
#   24017,
#   119446,
#   71439,
#   47181,
#   9918,
#   12692,
#   28188,
#   10025,
#   89523,
#   17342,
#   21711,
#   9951,
#   20308,
#   119054,
#   15184,
#   100],
#  [113,
#   9689,
#   114,
#   9580,
#   118841,
#   12310,
#   74212,
#   42424,
#   11273,
#   13966,
#   140,
#   57487,
#   9125,
#   30873,
#   9958,
#   18622,
#   119330,
#   23811,
#   48549,
#   9202,
#   34994,
#   16985,
#   20308,
#   22333,
#   12424,
#   79940,
#   9477,
#   119391,
#   105392,
#   10530,
#   48446,
#   59095,
#   13389,
#   11447],
#  [113,
#   9689,
#   114,
#   9580,
#   118841,
#   12310,
#   8935,
#   18622,
#   17342,
#   14867,
#   9268,
#   45725,
#   113,
#   12048,
#   10240,
#   12674,
#   11011,
#   114],
#  [113,
#   9689,
#   114,
#   9580,
#   118841,
#   12310,
#   9254,
#   84177,
#   9580,
#   118841,
#   12310,
#   9803,
#   118969,
#   9874,
#   119357,
#   8935,
#   18622,
#   119113,
#   118969,
#   19206,
#   10240],
#  [113,
#   9689,
#   114,
#   9580,
#   118841,
#   12310,
#   9254,
#   84177,
#   9580,
#   118841,
#   12310,
#   9803,
#   118969,
#   9580,
#   119027,
#   118992,
#   11664,
#   12310,
#   118788,
#   118969],
#  [113,
#   9689,
#   114,
#   9580,
#   118841,
#   12310,
#   9254,
#   84177,
#   9580,
#   118841,
#   12310,
#   9803,
#   118969,
#   9672,
#   83811,
#   118788,
#   118969],
#  [113,
#   9689,
#   114,
#   9580,
#   118841,
#   12310,
#   9254,
#   84177,
#   9580,
#   118841,
#   12310,
#   9803,
#   118969,
#   100],
#  [113,
#   9689,
#   114,
#   9580,
#   118841,
#   12310,
#   9254,
#   84177,
#   9580,
#   118841,
#   12310,
#   9803,
#   118969,
#   9767,
#   38631,
#   118773,
#   101202,
#   29455,
#   118788,
#   118969],
#  [113, 9689, 114, 9580, 118841, 12310, 9568, 24017, 47181, 10803, 11447],
#  [113,
#   9689,
#   114,
#   9580,
#   118841,
#   12310,
#   9579,
#   41919,
#   9456,
#   11664,
#   12310,
#   22458,
#   23160,
#   20479,
#   10757,
#   11447],
#  [113,
#   9689,
#   114,
#   9580,
#   118841,
#   12310,
#   9580,
#   105197,
#   55530,
#   23466,
#   9415,
#   27355,
#   105197,
#   42144,
#   12605,
#   10777,
#   11447],
#  [113,
#   9689,
#   114,
#   9580,
#   118841,
#   12310,
#   9626,
#   21789,
#   13890,
#   9803,
#   113,
#   15115,
#   11447,
#   12674,
#   11211,
#   21789,
#   114],
#  [113,
#   9689,
#   114,
#   9580,
#   118841,
#   12310,
#   9803,
#   118751,
#   27023,
#   9258,
#   119309,
#   11102,
#   118912,
#   21825,
#   10174,
#   15794,
#   9319,
#   12605],
#  [113,
#   9689,
#   114,
#   9580,
#   118841,
#   12310,
#   9942,
#   100929,
#   25517,
#   8872,
#   106249,
#   11261,
#   17730,
#   9901,
#   12605,
#   22695,
#   22333,
#   12605,
#   15935,
#   11447],
#  [113,
#   9689,
#   114,
#   9580,
#   118841,
#   12310,
#   9942,
#   100929,
#   25517,
#   9344,
#   10739,
#   119297,
#   9873,
#   23811,
#   26444,
#   9238,
#   20626,
#   118839,
#   12214,
#   10240],
#  [113, 9689, 114, 9580, 118841, 12310, 100, 12048, 10240],
#  [113,
#   9689,
#   114,
#   9580,
#   118841,
#   12310,
#   17342,
#   14867,
#   9580,
#   118841,
#   12310,
#   9757,
#   18784,
#   50450,
#   8848,
#   13764,
#   16617,
#   9310,
#   12605],
#  [113, 9689, 114, 9580, 12692, 37093, 9034, 10622, 105197, 13764],
#  [113,
#   9689,
#   114,
#   9604,
#   12692,
#   119249,
#   9344,
#   92688,
#   119405,
#   15001,
#   9519,
#   119008,
#   11287,
#   73306,
#   9538,
#   119253,
#   118969,
#   119123],
#  [113,
#   9689,
#   114,
#   9608,
#   15184,
#   12692,
#   8939,
#   31401,
#   30005,
#   82490,
#   100,
#   18022,
#   11447,
#   192,
#   122,
#   36789],
#  [113, 9689, 114, 9612, 21928, 9356, 12310, 113, 3440, 4859, 114, 100],
#  [113, 9689, 114, 9612, 18392, 21155, 52951, 100],
#  [113,
#   9689,
#   114,
#   9619,
#   15001,
#   122,
#   12030,
#   41693,
#   71013,
#   8908,
#   21614,
#   18622,
#   24891,
#   28188,
#   119233,
#   12965,
#   55530],
#  [113,
#   9689,
#   114,
#   9625,
#   11102,
#   37114,
#   25549,
#   9960,
#   97146,
#   119441,
#   9559,
#   81483,
#   119054,
#   113,
#   9294,
#   79544,
#   114],
#  [113,
#   9689,
#   114,
#   9638,
#   12508,
#   42144,
#   10739,
#   28188,
#   9062,
#   11287,
#   119080,
#   106249,
#   9448,
#   14040,
#   12508],
#  [113, 9689, 114, 9670, 11903, 21614, 9625, 65649, 28188, 12692, 75965, 17730],
#  [113,
#   9689,
#   114,
#   9670,
#   21155,
#   52951,
#   8868,
#   10892,
#   119312,
#   11664,
#   119287,
#   119076,
#   12186,
#   11447,
#   192,
#   127,
#   36789],
#  [113,
#   9689,
#   114,
#   9670,
#   21155,
#   52951,
#   9064,
#   63218,
#   11102,
#   11664,
#   119287,
#   119076,
#   92688,
#   12508,
#   118958,
#   10530,
#   10739,
#   16664,
#   11447,
#   192,
#   10250,
#   36789],
#  [113,
#   9689,
#   114,
#   9670,
#   21155,
#   52951,
#   9064,
#   63218,
#   11102,
#   92688,
#   12508,
#   118958,
#   8868,
#   10892,
#   119312,
#   118802,
#   42815,
#   16664,
#   11447],
#  [113,
#   9689,
#   114,
#   9670,
#   21155,
#   52951,
#   9519,
#   118936,
#   15001,
#   12638,
#   20309,
#   118802,
#   92688,
#   12508,
#   118958,
#   16664,
#   11447],
#  [113,
#   9689,
#   114,
#   9670,
#   21155,
#   52951,
#   9708,
#   12453,
#   11664,
#   22333,
#   11102,
#   118802,
#   42815,
#   16664,
#   11447,
#   192,
#   10250,
#   36789],
#  [113,
#   9689,
#   114,
#   9670,
#   21155,
#   52951,
#   9788,
#   119076,
#   11287,
#   118813,
#   92688,
#   12508,
#   118958,
#   8868,
#   10892,
#   119312,
#   118802,
#   42815,
#   16664,
#   11447,
#   192,
#   122,
#   36789],
#  [113, 9689, 114, 9670, 27355, 21155, 52951, 9330, 119274, 118667, 18622],
#  [113,
#   9689,
#   114,
#   9672,
#   58205,
#   10530,
#   28396,
#   119123,
#   29455,
#   9786,
#   119391,
#   48446,
#   42144,
#   9294,
#   21711,
#   20309,
#   106826,
#   97146],
#  [113,
#   9689,
#   114,
#   9672,
#   10739,
#   119123,
#   10739,
#   88321,
#   49196,
#   9968,
#   25503,
#   41605,
#   21876,
#   9906,
#   119307],
#  [113,
#   9689,
#   114,
#   9672,
#   10739,
#   17730,
#   10739,
#   119405,
#   15001,
#   9604,
#   12692,
#   118958,
#   28396,
#   12692,
#   22458,
#   96090,
#   54141,
#   119280,
#   11261],
#  [113,
#   9689,
#   114,
#   9706,
#   86933,
#   119141,
#   17342,
#   10739,
#   28396,
#   9938,
#   45465,
#   84177,
#   100],
#  [113,
#   9689,
#   114,
#   9708,
#   16323,
#   119422,
#   9746,
#   35506,
#   13890,
#   12945,
#   9779,
#   24891,
#   43098,
#   10240],
#  [113,
#   9689,
#   114,
#   9873,
#   118963,
#   10739,
#   9672,
#   16323,
#   30005,
#   12692,
#   13441,
#   13890,
#   16718,
#   10240],
#  [113,
#   9689,
#   114,
#   9901,
#   118714,
#   12605,
#   25517,
#   31065,
#   8996,
#   10739,
#   49543,
#   10892,
#   13890,
#   12965,
#   9657,
#   12965,
#   17196,
#   10739,
#   37114,
#   118739,
#   22333,
#   12605,
#   113,
#   9708,
#   119235,
#   100372,
#   21614,
#   118912,
#   114],
#  [113, 9689, 114, 9901, 118873, 24891, 151, 30025, 124, 24989, 27355, 21386],
#  [113, 9689, 114, 9904, 12092, 9074, 100, 12048, 10240],
#  [113, 9689, 114, 9904, 12092, 100, 113, 9268, 45725, 114, 12048, 10240],
#  [113,
#   9689,
#   114,
#   9904,
#   12092,
#   9379,
#   119003,
#   14867,
#   13389,
#   11447,
#   192,
#   122,
#   36789],
#  [113,
#   9689,
#   114,
#   9904,
#   12092,
#   100,
#   113,
#   9362,
#   12508,
#   14867,
#   114,
#   13389,
#   10240],
#  [113, 9689, 114, 9904, 70915, 9405, 118641, 18623, 20479, 24253, 10240],
#  [113,
#   9689,
#   114,
#   9940,
#   67527,
#   119405,
#   15001,
#   9946,
#   25517,
#   20308,
#   9538,
#   119253,
#   21611,
#   49919,
#   89523,
#   10739,
#   19233,
#   11447],
#  [113,
#   9689,
#   114,
#   9942,
#   56645,
#   14040,
#   12508,
#   9486,
#   36210,
#   38688,
#   78705,
#   9448,
#   12605,
#   46520],
#  [113,
#   9689,
#   114,
#   100,
#   10302,
#   118758,
#   119122,
#   60479,
#   9913,
#   119392,
#   15184,
#   9344,
#   10739,
#   119334,
#   22333,
#   11903,
#   122,
#   119,
#   127,
#   11369,
#   37611,
#   9901,
#   27355,
#   18622],
#  [113,
#   9689,
#   114,
#   9952,
#   118762,
#   42144,
#   10739,
#   28188,
#   118746,
#   26784,
#   14863,
#   12945,
#   33768,
#   12030,
#   9580,
#   49515,
#   119063,
#   16617,
#   43022,
#   14646,
#   66540,
#   8935,
#   14646,
#   66540,
#   10533,
#   10240,
#   10533,
#   11447,
#   192,
#   122,
#   36789],
#  [113,
#   9689,
#   114,
#   9952,
#   67527,
#   114,
#   9735,
#   18623,
#   119134,
#   119326,
#   119235,
#   118663,
#   10739,
#   32792,
#   10929,
#   115,
#   10197],
#  [113,
#   9689,
#   114,
#   9952,
#   67527,
#   21386,
#   26784,
#   8927,
#   17342,
#   58205,
#   8908,
#   21614,
#   119027,
#   66540,
#   118969,
#   23144,
#   10240],
#  [113,
#   9689,
#   114,
#   9952,
#   67527,
#   21386,
#   26784,
#   8927,
#   17342,
#   58205,
#   100,
#   11176,
#   10240],
#  [113,
#   9689,
#   114,
#   9952,
#   67527,
#   21386,
#   26784,
#   8927,
#   17342,
#   58205,
#   8987,
#   12092,
#   118834,
#   101202,
#   29455,
#   16718,
#   10240],
#  [113,
#   9689,
#   114,
#   9952,
#   67527,
#   21386,
#   26784,
#   8927,
#   17342,
#   58205,
#   9626,
#   57138,
#   8996,
#   28000,
#   9062,
#   83811,
#   15891,
#   17342,
#   14867,
#   113,
#   17095,
#   10240,
#   115,
#   125,
#   118989,
#   114],
#  [113,
#   9689,
#   114,
#   9952,
#   67527,
#   21386,
#   26784,
#   8927,
#   17342,
#   58205,
#   9626,
#   57138,
#   8996,
#   28000,
#   9788,
#   119287,
#   17342,
#   14867,
#   113,
#   18948,
#   10240,
#   115,
#   125,
#   58303,
#   114],
#  [113,
#   9689,
#   114,
#   9952,
#   67527,
#   21386,
#   26784,
#   8927,
#   17342,
#   58205,
#   9626,
#   57138,
#   8996,
#   28000,
#   9788,
#   119287,
#   17342,
#   14867,
#   14890,
#   33884,
#   24140,
#   113,
#   17095,
#   115,
#   125,
#   58303,
#   114],
#  [113,
#   9689,
#   114,
#   9952,
#   67527,
#   21386,
#   26784,
#   8927,
#   17342,
#   58205,
#   9626,
#   57138,
#   8996,
#   28000,
#   9788,
#   119287,
#   17342,
#   14867,
#   9603,
#   12310,
#   14890,
#   118,
#   33884,
#   24140,
#   14519,
#   10240],
#  [113,
#   9689,
#   114,
#   9952,
#   67527,
#   21386,
#   26784,
#   8927,
#   17342,
#   58205,
#   9879,
#   11287,
#   119080,
#   106249,
#   11287,
#   17342,
#   16985,
#   14153,
#   23144,
#   10240],
#  [113,
#   9689,
#   114,
#   9960,
#   97146,
#   15184,
#   12692,
#   9281,
#   34951,
#   11287,
#   9628,
#   32537,
#   13764,
#   41442,
#   16758,
#   34951,
#   118834],
#  [113, 9694, 78705, 114, 9450, 22333, 80331, 24982, 16605, 17730],
#  [113,
#   9751,
#   16605,
#   14279,
#   114,
#   9309,
#   77884,
#   34994,
#   11261,
#   77884,
#   15891,
#   28396,
#   53398,
#   10929,
#   11447],
#  [113,
#   9834,
#   17342,
#   21614,
#   114,
#   9136,
#   119312,
#   24206,
#   17342,
#   118930,
#   71793,
#   10929,
#   11447],
#  [113, 9901, 114, 100],
#  [113, 9901, 114, 100],
#  [113, 9901, 114, 9253, 39420, 12605, 119010],
#  [113, 9901, 114, 9420, 20308, 67527, 22333, 30005, 35866],
#  [113, 9901, 114, 9472, 20308, 67527, 119010, 113, 9238, 114],
#  [113, 9901, 114, 9670, 43022, 20308, 17342, 14871],
#  [113, 9901, 114, 9798, 97146, 35465],
#  [113, 9928, 114, 9238, 32537, 41605],
#  [113,
#   9953,
#   114,
#   9568,
#   24982,
#   30461,
#   9568,
#   24982,
#   27355,
#   42815,
#   9568,
#   24982,
#   8888,
#   119287,
#   119076,
#   118802,
#   42815,
#   10777,
#   63308,
#   10777,
#   11447,
#   192,
#   122,
#   36789],
#  [113, 9960, 57030, 114, 9678, 119144, 113, 9309, 23160, 114, 12048, 11447],
#  [113,
#   9978,
#   22458,
#   114,
#   9258,
#   21614,
#   11664,
#   119274,
#   13890,
#   11176,
#   10240,
#   116,
#   10407,
#   10240],
#  [113,
#   9978,
#   22458,
#   114,
#   9734,
#   11664,
#   119274,
#   13890,
#   11900,
#   10240,
#   116,
#   10777,
#   10240,
#   113,
#   9069,
#   12692,
#   34907],
#  [115, 8887, 49919],
#  [115, 9405, 118641, 83811, 15891],
#  [115, 9779, 119330],
#  [10083, 10083, 9049, 9834, 56645, 44359, 9186, 118936, 118912, 10386, 10240],
#  [164,
#   36137,
#   11274,
#   166,
#   164,
#   9309,
#   15184,
#   12692,
#   166,
#   102574,
#   90833,
#   42144,
#   9519,
#   118936,
#   15001,
#   10533,
#   175,
#   113,
#   10197,
#   58303,
#   114],
#  [164,
#   140,
#   166,
#   9202,
#   17730,
#   22333,
#   12605,
#   125,
#   119,
#   129,
#   47407,
#   113,
#   9001,
#   13890,
#   114],
#  [164,
#   140,
#   166,
#   9284,
#   106249,
#   118907,
#   17196,
#   10739,
#   125,
#   119,
#   11978,
#   47407,
#   113,
#   9001,
#   13890,
#   114],
#  [164,
#   140,
#   166,
#   9379,
#   119003,
#   118727,
#   14867,
#   13890,
#   123,
#   47407,
#   113,
#   9001,
#   13890,
#   114],
#  [164,
#   140,
#   166,
#   9379,
#   15184,
#   14646,
#   66540,
#   10244,
#   10240,
#   113,
#   9001,
#   13890,
#   114],
#  [164, 140, 166, 100, 10923, 10240, 113, 9001, 13890, 114],
#  [164, 140, 166, 100, 10923, 10240, 113, 9001, 13890, 114],
#  [164,
#   140,
#   166,
#   9942,
#   12692,
#   22458,
#   96090,
#   13441,
#   13890,
#   11903,
#   28911,
#   12310,
#   123,
#   47407,
#   113,
#   9001,
#   13890,
#   114],
#  [164, 80622, 166, 9735, 12310, 49543, 46520],
#  [164,
#   21290,
#   166,
#   21290,
#   42144,
#   11261,
#   118760,
#   118684,
#   32815,
#   22458,
#   37004,
#   119308,
#   17342,
#   118629,
#   116,
#   124,
#   10240,
#   192,
#   10247,
#   55530],
#  [164,
#   21290,
#   166,
#   21290,
#   42144,
#   11261,
#   118760,
#   118684,
#   32815,
#   22458,
#   12030,
#   119308,
#   17342,
#   118629,
#   116,
#   124,
#   10240,
#   192,
#   10247,
#   55530],
#  [164,
#   9027,
#   119435,
#   166,
#   9644,
#   40032,
#   108578,
#   37824,
#   10739,
#   38631,
#   119092,
#   10150,
#   47407],
#  [164, 9069, 31720, 166, 9379, 119003, 20479, 15891, 22333, 12605, 120, 8857],
#  [164, 9279, 82490, 166, 48774, 10240, 119092, 20479, 15891],
#  [164,
#   9283,
#   16439,
#   22458,
#   166,
#   10186,
#   41442,
#   127,
#   63308,
#   9460,
#   119253,
#   29364,
#   105197,
#   9283,
#   25503,
#   16323,
#   113,
#   8987,
#   114],
#  [164,
#   9283,
#   106065,
#   166,
#   9692,
#   119136,
#   11018,
#   22200,
#   33188,
#   13890,
#   113,
#   9565,
#   114,
#   113,
#   9294,
#   27506,
#   118649,
#   114,
#   9294,
#   18471],
#  [164,
#   9283,
#   106065,
#   166,
#   9795,
#   68984,
#   12605,
#   118927,
#   41620,
#   14279,
#   80174,
#   86001,
#   28981,
#   15184],
#  [164,
#   9499,
#   20305,
#   47407,
#   166,
#   9565,
#   16323,
#   118746,
#   119435,
#   14423,
#   40991,
#   108578,
#   37824,
#   9565,
#   16323,
#   119092,
#   113,
#   9208,
#   28911,
#   62200,
#   114],
#  [164, 9499, 20305, 47407, 166, 9765, 40311, 31720, 12310, 22458],
#  [164,
#   9519,
#   36240,
#   10739,
#   166,
#   9487,
#   18471,
#   48533,
#   10622,
#   110589,
#   100,
#   10757,
#   63308],
#  [164,
#   9532,
#   118667,
#   166,
#   8924,
#   27654,
#   9268,
#   45725,
#   9890,
#   12692,
#   119412,
#   30873,
#   12605,
#   116,
#   113,
#   122,
#   117,
#   10259,
#   10147,
#   10240,
#   192,
#   10709,
#   119295,
#   119075,
#   114],
#  [164,
#   9559,
#   12605,
#   119123,
#   119405,
#   15001,
#   166,
#   164,
#   175,
#   10107,
#   12692,
#   119351,
#   18392,
#   10723,
#   8909,
#   21386,
#   119312,
#   118802,
#   14646,
#   9365,
#   119285,
#   119245,
#   21789,
#   118635,
#   24974,
#   11093,
#   10240,
#   116,
#   11093,
#   10240,
#   166],
#  [164, 9735, 79718, 166, 9543, 76036, 119274, 97146, 119327],
#  [164, 9751, 16605, 14279, 166, 73142, 13890, 46520],
#  [164,
#   9786,
#   119391,
#   54141,
#   18622,
#   24891,
#   88332,
#   119188,
#   166,
#   73142,
#   88332,
#   119188],
#  [164, 9906, 119307, 166, 9287, 62200, 9477, 88332, 18622, 82512],
#  [164,
#   9906,
#   119307,
#   166,
#   9287,
#   62200,
#   12605,
#   119345,
#   28396,
#   23811,
#   12605,
#   119334,
#   24982,
#   15184],
#  [164, 9954, 17138, 166, 9365, 21155, 46520],
#  [10719,
#   38964,
#   11127,
#   69196,
#   77802,
#   32469,
#   11517,
#   168,
#   9379,
#   12638,
#   10739,
#   49212,
#   118786,
#   118780,
#   10530,
#   12965,
#   118927,
#   12692,
#   37004,
#   14871,
#   35506,
#   49025,
#   20309],
#  [105002, 10929, 118834, 88332, 119188],
#  [122, 9158, 12605],
#  [122, 9313, 11287, 35866],
#  [122, 9486, 24974, 42815],
#  [122, 9689, 42337, 24982, 17730, 113, 9933, 119404, 114],
#  [10407,
#   110,
#   9186,
#   15001,
#   29455,
#   15184,
#   9689,
#   12605,
#   122,
#   11369,
#   113,
#   9074,
#   118987,
#   9665,
#   24974,
#   114],
#  [12186, 21928, 50248, 119078, 17342, 10739, 54141, 12508, 27355, 21789],
#  [12186, 16985, 18392, 42771, 15001, 56645, 119087, 69168, 10929, 10240],
#  [10186,
#   24989,
#   12092,
#   14040,
#   107693,
#   118667,
#   113,
#   126,
#   10240,
#   115,
#   10186,
#   118989,
#   114],
#  [13389, 63308, 9611, 21876, 119209, 12692, 9405, 11882],
#  [99448, 24974, 9604, 29455],
#  [123,
#   91075,
#   46935,
#   68999,
#   52338,
#   29833,
#   10731,
#   39774,
#   49378,
#   39272,
#   32071,
#   13849,
#   10240,
#   113,
#   9757,
#   25517,
#   22695,
#   31401,
#   15184,
#   10729,
#   58303,
#   114,
#   13849,
#   10240,
#   10686,
#   10759,
#   78560,
#   10174,
#   118727,
#   18778],
#  [123, 9099, 13890],
#  [123, 9486, 57030],
#  [10180, 9003, 118729, 9946, 69753, 12965, 10150, 41442, 9359, 119393],
#  [10180, 92688, 25503, 12605, 119307],
#  [21881,
#   10929,
#   9421,
#   10739,
#   106065,
#   18227,
#   41620,
#   18622,
#   47289,
#   10407,
#   10240,
#   115,
#   124],
#  [21881, 10929, 9477, 23811, 15184, 88332, 12965, 9779, 47289],
#  [21881, 10929, 100],
#  [21881, 10929, 40311, 10892, 23466, 40958, 46520, 18622, 47289],
#  [21881, 10929, 40311, 10892, 23466, 40311, 119314, 11102],
#  [21881, 10929, 18622, 119054],
#  [21881,
#   10929,
#   18622,
#   47289,
#   9580,
#   12692,
#   12508,
#   41919,
#   9524,
#   46150,
#   113,
#   125,
#   21789,
#   58303,
#   114],
#  [21881,
#   10929,
#   18622,
#   47289,
#   37462,
#   10929,
#   11447,
#   115,
#   125,
#   117,
#   9485,
#   78136,
#   25503,
#   60469,
#   26444,
#   119336,
#   92564,
#   35866],
#  [100, 116, 126, 58303, 24982, 15184],
#  [10197,
#   118858,
#   25387,
#   119053,
#   22333,
#   80331,
#   17730,
#   9887,
#   52015,
#   11417,
#   63308],
#  [10306,
#   23811,
#   118762,
#   114,
#   9365,
#   15001,
#   30873,
#   21614,
#   101202,
#   73352,
#   52015,
#   56645,
#   15001],
#  [10233,
#   93520,
#   36742,
#   93280,
#   77802,
#   32469,
#   11274,
#   168,
#   100,
#   9960,
#   118910,
#   10892,
#   9294,
#   119253,
#   41442,
#   113,
#   10024,
#   41442,
#   114,
#   9519,
#   18778,
#   10459,
#   46520,
#   118,
#   156],
#  [124, 8845, 13890],
#  [124, 8888, 101322, 12965],
#  [124, 9067, 14867],
#  [15335, 8954, 89292, 9448, 90927, 9022, 15184],
#  [25385,
#   119,
#   10233,
#   9062,
#   11287,
#   119080,
#   106249,
#   8954,
#   118686,
#   119286,
#   8935,
#   12605,
#   119375,
#   9258,
#   119309,
#   11102,
#   118912,
#   69168,
#   10240],
#  [124,
#   11517,
#   9246,
#   12605,
#   20308,
#   8896,
#   21386,
#   52951,
#   9186,
#   12965,
#   113,
#   10462,
#   100372,
#   58303,
#   114,
#   9069,
#   27506],
#  [124,
#   11517,
#   113,
#   9511,
#   12692,
#   119141,
#   114,
#   148,
#   11565,
#   118,
#   12749,
#   9997,
#   12945,
#   23811,
#   12605,
#   20308],
#  [124, 76036, 12945, 11882, 21155, 57030],
#  [124, 37712, 9309, 15184, 101450, 11766, 10240],
#  [124, 37712, 9456, 11664, 12310, 9715, 13890, 89478, 10240],
#  [124, 37712, 9715, 13890],
#  [124, 37712, 9715, 13890, 10777, 11447],
#  [124, 37712, 9786, 56645, 9462, 11102, 118912, 10777, 11447],
#  [124, 37712, 9786, 56645, 9539, 18784, 100372, 21614, 118912, 10777, 11447],
#  [124,
#   37712,
#   118667,
#   18622,
#   119251,
#   18622,
#   118788,
#   118969,
#   22333,
#   12605,
#   37462,
#   10929,
#   10240],
#  [124, 37712, 119059, 11664, 12310, 119235, 13890, 89478, 10240],
#  [124, 37712, 119059, 11664, 12310, 24206, 56645],
#  [124, 37712, 119235, 13890],
#  [124, 37712, 24206, 56645],
#  [124, 37712, 24206, 56645, 100372, 21614, 118912, 10777, 10240, 115, 124],
#  [124,
#   37712,
#   119422,
#   41605,
#   41521,
#   12605,
#   119351,
#   10739,
#   20308,
#   39900,
#   10929,
#   10240],
#  [61293,
#   16439,
#   118841,
#   35866,
#   9457,
#   119308,
#   17342,
#   9678,
#   66540,
#   88332,
#   10739,
#   20308],
#  [17436, 16617, 43022, 118667, 55530, 119092, 124, 11733, 11447],
#  [11628, 100699, 9663, 37093, 119063, 21155, 119010],
#  [126, 55670, 9309, 119066, 11287, 35866],
#  [126, 119388, 119409, 18471, 119439, 33188, 78705],
#  [12791, 14646, 14423, 119245, 21789],
#  [128, 20129, 10003, 118893, 103917, 9330],
#  [128, 20129, 10003, 118893, 103917, 9405, 11882],
#  [16052, 9689, 12605, 9580, 12692, 18623, 80893],
#  [16052, 57030, 25517, 118876, 24747, 21069],
#  [16052,
#   57030,
#   25517,
#   61156,
#   21039,
#   9311,
#   15184,
#   13389,
#   10240,
#   115,
#   10218,
#   58303],
#  [10840, 88506, 10112, 9599, 22333, 15891, 10150, 11369],
#  [139,
#   114,
#   10083,
#   9834,
#   56645,
#   119191,
#   120,
#   8935,
#   18622,
#   119245,
#   21789,
#   69168,
#   10929,
#   11447,
#   120,
#   9414,
#   37093],
#  [139,
#   114,
#   10083,
#   9834,
#   56645,
#   119191,
#   120,
#   9405,
#   118641,
#   118642,
#   119341,
#   69168,
#   10929,
#   11447,
#   120,
#   9414,
#   37093],
#  [139,
#   114,
#   10083,
#   9834,
#   56645,
#   119191,
#   120,
#   9626,
#   21789,
#   13890,
#   69168,
#   10929,
#   11447,
#   120,
#   9414,
#   37093],
#  [139,
#   114,
#   10083,
#   9834,
#   56645,
#   119191,
#   13441,
#   13890,
#   119245,
#   21789,
#   69168,
#   10929,
#   11447,
#   120,
#   9414,
#   37093],
#  [139,
#   114,
#   10083,
#   9964,
#   30134,
#   47499,
#   10929,
#   11447,
#   113,
#   11055,
#   58303,
#   114,
#   86607,
#   13034,
#   120,
#   9414,
#   37093],
#  [100],
#  [100],
#  [100],
#  [49622, 19282, 18622, 119330],
#  [49622,
#   19282,
#   43022,
#   106249,
#   118773,
#   11903,
#   12692,
#   17196,
#   10739,
#   113,
#   9448,
#   40032,
#   17196,
#   10739,
#   118912,
#   114],
#  [30429,
#   32650,
#   56906,
#   10288,
#   9559,
#   45725,
#   119368,
#   15001,
#   9689,
#   42337,
#   24982,
#   17730,
#   48205,
#   10929,
#   63308,
#   32537,
#   79544,
#   122,
#   21789],
#  [66710, 11403, 10150, 91837, 9420, 9625, 21386, 77692, 123, 10240],
#  [66710,
#   11403,
#   10197,
#   10083,
#   9547,
#   24017,
#   21039,
#   24891,
#   9379,
#   22695,
#   36553,
#   10738],
#  [66710,
#   11403,
#   10083,
#   9486,
#   29364,
#   17138,
#   42815,
#   21386,
#   77692,
#   9477,
#   119330,
#   119412,
#   30873,
#   12605],
#  [66710,
#   11403,
#   10083,
#   9486,
#   29364,
#   17138,
#   42815,
#   21386,
#   77692,
#   119383,
#   118958,
#   12692,
#   119412,
#   30873,
#   12605,
#   61156,
#   119382,
#   120,
#   9414,
#   37093],
#  [140, 147, 9107, 50248, 119423, 30134],
#  [140, 147, 9331, 31928, 119423, 42144, 119025, 118667, 36210, 37388, 118667],
#  [140, 147, 9694, 28143, 118958, 11287, 35866],
#  [140, 147, 9963, 118975, 12605, 119351, 10739, 20308],
#  [140, 147, 10003, 62200, 20308, 119099, 24982, 12508],
#  [51457,
#   10425,
#   82447,
#   19987,
#   43100,
#   10230,
#   44271,
#   32939,
#   79657,
#   16357,
#   11469,
#   20706,
#   86480],
#  [80622,
#   9331,
#   31928,
#   9487,
#   114,
#   9694,
#   28143,
#   118958,
#   11287,
#   35866,
#   122,
#   47407],
#  [80622, 9331, 31928, 31928, 119341, 122, 11733, 11447],
#  [171, 10418, 9486, 36210, 38688],
#  [80622, 9486, 36210, 38688],
#  [80622,
#   9952,
#   18471,
#   16605,
#   100,
#   9415,
#   119309,
#   11102,
#   118912,
#   14992,
#   11447,
#   192,
#   122,
#   36789],
#  [80622, 9952, 18471, 16605, 118667, 118969, 24989, 32537, 12508],
#  [80622, 9964, 30134, 10777, 10240, 115, 125],
#  [80622, 9964, 30134, 51431, 16985, 30842, 22458, 119092, 69975, 10929, 10240],
#  [80622, 114, 9456, 11664, 12310, 25805, 11903, 10407, 10240],
#  [80622, 114, 9952, 18471, 16605, 100, 11900, 10240],
#  [80622, 114, 12186, 9519, 18392, 42771, 9113, 56645, 119087, 16017],
#  [80622, 114, 8959, 22333, 40032, 122, 47407],
#  [80622, 114, 9056, 105462, 40311, 20479, 13890, 119245, 21789],
#  [80622, 114, 9259, 12605, 118989],
#  [80622, 114, 9313, 11287, 35866, 122, 11733, 10240],
#  [80622, 114, 9331, 41442, 31928, 119341, 122, 47407],
#  [80622, 114, 9331, 31928, 119423, 21928, 14867, 10757, 10240],
#  [80622, 114, 9379, 86933, 16439, 22333, 24982, 12508, 90533, 11166, 10240],
#  [80622, 114, 100, 10777, 10240],
#  [80622, 114, 9604, 18778, 12945, 12692, 14867],
#  [80622,
#   114,
#   9964,
#   42144,
#   119025,
#   16758,
#   11287,
#   118667,
#   36210,
#   12692,
#   118667,
#   118,
#   125,
#   115,
#   10250],
#  [80622, 114, 9964, 30134, 17131, 10240],
#  [80622, 63218, 31928, 9952, 119127, 31928, 119341, 122, 47407],
#  [80622, 63218, 31928, 119153, 62211, 21928, 48205, 10929, 10240],
#  [80622,
#   63218,
#   31928,
#   42815,
#   8909,
#   31605,
#   119312,
#   12310,
#   49543,
#   10929,
#   119,
#   126,
#   11369],
#  [100],
#  [100],
#  [80622, 21155, 36210, 38688, 113, 9638, 20595, 114],
#  [80622, 36210, 37388, 118667, 37301, 118989],
#  [80622,
#   17730,
#   18392,
#   17730,
#   21928,
#   9379,
#   29455,
#   11664,
#   9405,
#   118641,
#   118642,
#   119341,
#   10757,
#   10240],
#  [80622,
#   17730,
#   18392,
#   17730,
#   21928,
#   9379,
#   29455,
#   11664,
#   9448,
#   11664,
#   12310,
#   32537,
#   20479,
#   10757,
#   10240],
#  [80622, 17730, 18392, 17730, 21928, 9486, 36210, 38688],
#  [80622,
#   17730,
#   18392,
#   17730,
#   21928,
#   9966,
#   70915,
#   11102,
#   119312,
#   9746,
#   18392,
#   119144,
#   8909,
#   21386,
#   119312,
#   118802,
#   14646,
#   22405,
#   11447,
#   192,
#   123,
#   36789],
#  [171, 10418, 119251, 78136, 27654, 10759, 119, 123, 47407],
#  [80622, 119423, 30134, 10777, 10240],
#  [42818, 168, 9786, 24982, 17342, 118956, 103917],
#  [21177, 27008, 9519, 118927, 12692, 24206, 28981],
#  [16057,
#   11490,
#   49025,
#   10729,
#   11274,
#   10407,
#   110,
#   100,
#   113,
#   123,
#   11369,
#   114,
#   9355],
#  [16057,
#   11490,
#   49025,
#   11011,
#   11274,
#   10407,
#   110,
#   100,
#   113,
#   123,
#   11369,
#   114,
#   9355],
#  [16057,
#   11490,
#   49025,
#   11166,
#   11274,
#   10407,
#   110,
#   100,
#   113,
#   123,
#   11369,
#   114,
#   9355],
#  [172, 10147, 29683, 11903, 34994, 80174, 9779, 24891, 113, 9001, 18778, 114],
#  [100035,
#   10112,
#   9532,
#   119412,
#   119380,
#   42498,
#   63308,
#   113,
#   12066,
#   63308,
#   115,
#   129,
#   58303,
#   114],
#  [100035,
#   10112,
#   9580,
#   118873,
#   12508,
#   119380,
#   12066,
#   63308,
#   129,
#   58303,
#   119384],
#  [100035,
#   10112,
#   9901,
#   12030,
#   119121,
#   119412,
#   119380,
#   12066,
#   63308,
#   129,
#   58303,
#   119384],
#  [100035,
#   10112,
#   9946,
#   18622,
#   119380,
#   42498,
#   63308,
#   113,
#   12066,
#   63308,
#   115,
#   129,
#   58303,
#   114],
#  [141, 14703, 114, 100, 113, 12581, 10240, 10686, 11211, 114, 192, 11011],
#  [47132, 10129, 118, 40251, 10454, 69189],
#  [20569, 11287, 35866, 29455, 118751, 113, 122, 11733, 11447, 114],
#  [143,
#   11490,
#   9378,
#   35866,
#   92688,
#   12692,
#   9901,
#   27355,
#   54141,
#   113,
#   10832,
#   13546,
#   10237,
#   114,
#   11093,
#   10240,
#   120,
#   78978],
#  [143,
#   38850,
#   32995,
#   67753,
#   9457,
#   68984,
#   63218,
#   9657,
#   42144,
#   17196,
#   25503,
#   150],
#  [15459,
#   12310,
#   40419,
#   20626,
#   118710,
#   118,
#   10803,
#   113,
#   148,
#   58132,
#   59879,
#   120,
#   10407,
#   114],
#  [64655, 77884, 10739, 29455, 17196, 118802],
#  [144, 11305, 69954, 28236, 96409, 10115, 10759],
#  [144, 11305, 9344, 15184, 37004, 9798, 97146],
#  [144, 11305, 24206, 119405, 18622, 28981, 39420, 24206, 24747, 58303],
#  [175, 10107, 9595, 118802, 14646, 20676, 10240],
#  [144,
#   10107,
#   37135,
#   13264,
#   120,
#   9252,
#   10892,
#   119312,
#   40991,
#   118802,
#   14646,
#   99555,
#   10929,
#   10240],
#  [70069, 75282, 9246, 12605, 20308],
#  [70069, 12692, 119351, 18392, 73142, 25387, 18471, 21155, 52951, 46520],
#  [70069, 21155, 36210, 38688, 113, 9487, 18471, 21155, 52951, 114],
#  [70069, 25387, 18471, 21155, 52951],
#  [32600, 112, 187, 19372, 43013, 9330, 12092, 17342, 12508],
#  [32600, 112, 187, 19372, 43013, 9426, 46520],
#  [88321,
#   49196,
#   9499,
#   11261,
#   61844,
#   9246,
#   118762,
#   119010,
#   118912,
#   113,
#   70069,
#   114],
#  [82338,
#   58931,
#   24989,
#   58931,
#   36240,
#   76036,
#   119274,
#   113,
#   9279,
#   28000,
#   42337,
#   114,
#   115,
#   10150,
#   47407,
#   115,
#   100],
#  [145,
#   14703,
#   70447,
#   10731,
#   119308,
#   15001,
#   52015,
#   35866,
#   113,
#   9640,
#   12092,
#   16617,
#   24974,
#   114,
#   18302,
#   63308],
#  [40214, 9428, 92564, 31398, 20308, 67527],
#  [12820, 12310, 119411, 29364, 12186],
#  [12820, 12310, 119411, 29364, 20564],
#  [12820, 12310, 119411, 29364, 20564, 113, 9319, 12605, 114],
#  [12820, 12310, 119411, 29364, 49025, 10929, 113, 9319, 12605, 114],
#  [47124,
#   95472,
#   9834,
#   80174,
#   119327,
#   119300,
#   8848,
#   13764,
#   119286,
#   38521,
#   10240],
#  [148, 11565, 44026, 23811, 12605, 20308],
#  [148, 11565, 11373, 11011, 9246, 12605, 20308],
#  [179, 10575, 11373, 11011, 23811, 12605, 20308],
#  [148, 11565, 11373, 11011, 23811, 12605, 20308],
#  [179, 11565, 11373, 11011, 23811, 12605, 20308],
#  [148, 11565, 11373, 11011, 23811, 12605, 20308, 113, 9069, 114],
#  [148, 11565, 118, 22992, 9379, 89523, 23811, 12605, 20308],
#  [148, 11565, 118, 22992, 9641, 14863, 24974, 23811, 12605, 20308],
#  [148, 11565, 23811, 12605, 20308],
#  [148, 23811, 12605, 20308, 113, 148, 11565, 11373, 11011, 114],
#  [43586, 11369, 9309, 21039, 22458, 51533, 18778, 43962, 119158, 76897, 21069],
#  [51829, 49469, 118856, 57346],
#  [49780, 114, 9421, 28396, 49919, 16985, 11261, 23811],
#  [49780, 114, 9421, 28396, 49919, 25517, 119372, 24974],
#  [49780, 114, 9421, 28396, 49919, 119418, 20308, 119044],
#  [49780, 114, 9960, 97146, 42144, 48446, 69592, 14040, 11211, 32792, 10240],
#  [49780,
#   24017,
#   119446,
#   71439,
#   47181,
#   9559,
#   12965,
#   69592,
#   119049,
#   9997,
#   12945,
#   42337,
#   23160,
#   24974,
#   23811,
#   12605,
#   20308,
# ...
#  [8894, 119078, 10739, 119312, 16439, 29364, 10150, 47407],
#  [8894, 119078, 10739, 119312, 16439, 29364, 125, 47407],
#  [8894, 100420, 164, 8909, 31605, 21386, 166],
#  [8894, 100420, 16617, 118641],
#  [8896,
#   18778,
#   39420,
#   40032,
#   14863,
#   114,
#   9434,
#   12030,
#   24974,
#   23811,
#   12605,
#   20308],
#  [8896, 71013, 119253],
#  [8897, 105197],
#  [8898, 18392],
#  [8898, 18392, 8962, 30873, 22458],
#  [8898,
#   18392,
#   42144,
#   17196,
#   25503,
#   24982,
#   15184,
#   10884,
#   20309,
#   113,
#   9435,
#   15184,
#   114],
#  [100],
#  [8898, 18392, 119253, 22333, 46520],
#  [8898, 18392, 119405, 118823],
#  [8898, 18392, 119405, 118823, 9941, 56645],
#  [8898,
#   18392,
#   79544,
#   9675,
#   12692,
#   9265,
#   119070,
#   118930,
#   11261,
#   27355,
#   13057,
#   10240],
#  [8898, 13764],
#  [8898, 13764, 17234, 10929],
#  [8898, 13764, 120, 9390],
#  [8898, 13764, 11011, 35465, 27023, 10759, 118945, 32158],
#  [8898, 13764, 46520],
#  [8898, 13764, 46520, 120, 9390],
#  [8899, 45725, 119073],
#  [8903, 18778, 9379, 22695, 28847, 10929],
#  [8903, 67527, 14871, 14863, 9099, 13890, 119235, 118663, 10739, 10777, 10240],
#  [8903, 15891, 30134, 25517, 100329, 13890, 118610],
#  [8903,
#   16323,
#   43022,
#   18392,
#   12310,
#   26784,
#   9625,
#   11102,
#   28000,
#   12945,
#   9879,
#   18392,
#   100,
#   9580,
#   12692,
#   12508,
#   41919,
#   9313,
#   20308,
#   45725],
#  [8903, 38631, 9091, 118667, 13764, 30134],
#  [8903, 38631, 118667],
#  [8903, 38631, 118667, 10244, 11447],
#  [8903, 38631, 118667, 37301, 24989],
#  [100],
#  [8903, 38631, 119371, 21386, 52951, 9448, 25934, 33305, 9901, 37388, 118667],
#  [8903, 38631, 46150, 37388, 118667],
#  [8903, 38631, 14523, 48387, 9901, 37388, 118667, 164, 10328, 10240, 166],
#  [8907, 13764, 19105, 118802, 122, 117, 14992, 10240],
#  [8907, 13764, 19105, 118802, 49025, 10929, 10240],
#  [8907, 119268, 100, 9487, 18227, 118912, 11653, 10240],
#  [8907, 119268, 100, 9968, 25503, 118912, 11653, 10240],
#  [8907, 119268, 28188, 12692, 12508, 41919],
#  [8907, 119268, 118, 100, 118, 9487, 18227, 122, 118989, 12508],
#  [8908, 118802],
#  [8908, 22458, 119292, 48446, 10462, 11447],
#  [8908, 21614, 9580, 119233, 12965, 11903, 12692],
#  [8908, 21614, 105197, 13764, 12310, 103155],
#  [8908, 21614, 105197, 13764, 37114, 46150, 118912, 24747, 11011, 11447],
#  [8908, 21614, 21611, 49919],
#  [8908,
#   21614,
#   21611,
#   49919,
#   9901,
#   12030,
#   119113,
#   17196,
#   10739,
#   113,
#   10244,
#   17196,
#   114],
#  [8908, 21614, 21611, 49919, 113, 10244, 17196, 114],
#  [8908, 21614, 49919, 10197, 58303],
#  [8908, 21614, 16985, 118936, 15001, 10919, 10240],
#  [8908,
#   21614,
#   22028,
#   101202,
#   29455,
#   100372,
#   21614,
#   118912,
#   113,
#   14992,
#   10240,
#   114],
#  [8908, 21614, 99118, 42144, 97146, 13764, 12048, 10240],
#  [8908, 69592, 118921, 11018, 18622, 24891, 10832, 10240],
#  [8909,
#   31605,
#   21386,
#   9420,
#   20308,
#   67527,
#   10739,
#   9940,
#   14646,
#   11102,
#   9834,
#   67527,
#   9477,
#   46150,
#   14153,
#   45725,
#   22333,
#   12605],
#  [8909,
#   31605,
#   21386,
#   42815,
#   12310,
#   118746,
#   118751,
#   118894,
#   12508,
#   11882,
#   13764],
#  [8909, 29364, 118773, 51431, 96702, 10240],
#  [8909, 29364, 24974, 118933, 18622],
#  [8909, 21386, 9056, 18623, 24017, 47181],
#  [8909, 21386, 9378, 35866, 92688, 12692],
#  [8909, 21386, 9954, 118792, 9542, 10892, 9121, 71013],
#  [8909, 21386, 36553, 29364, 12965, 119218, 106249],
#  [8909, 21386, 14646, 119285, 118802, 14646],
#  [8909, 21386, 119092, 11261, 73306, 9604, 12692, 119092, 9139, 20479, 118834],
#  [8909, 21386, 119245, 21789, 118802, 14646, 10884, 47407],
#  [8909, 21386, 119251, 12310, 49543, 118649, 38631, 118667],
#  [8909, 21386, 119251, 12310, 49543, 119048, 122, 20309],
#  [8909, 21386, 119312, 9819, 20479, 29364],
#  [8909, 15891],
#  [8909, 15891, 120, 8857],
#  [61320,
#   21155,
#   52951,
#   18623,
#   38631,
#   28000,
#   13890,
#   9089,
#   68055,
#   16617,
#   12508,
#   113,
#   11093,
#   10240,
#   110893,
#   32792,
#   10240,
#   100,
#   168,
#   9460,
#   83811,
#   24974,
#   126,
#   11733,
#   10240,
#   120,
#   38478,
#   114],
#  [8910, 21611, 49919],
#  [8910, 19105, 118802, 120, 11895],
#  [8910, 19105, 118802, 120, 8857],
#  [100,
#   9268,
#   45725,
#   113,
#   13389,
#   10240,
#   115,
#   125,
#   114,
#   113,
#   9580,
#   118841,
#   12310,
#   114],
#  [100, 113, 13389, 10240, 12674, 11011, 114],
#  [8913, 10892, 22333, 40032, 10884, 47407],
#  [8915,
#   36553,
#   20479,
#   21386,
#   119312,
#   118802,
#   14646,
#   37462,
#   10929,
#   10240,
#   115,
#   123],
#  [8915,
#   42144,
#   98789,
#   12605,
#   65649,
#   12945,
#   42337,
#   23160,
#   24974,
#   23811,
#   12605,
#   20308,
#   113,
#   148,
#   11565,
#   11373,
#   11011,
#   114,
#   113,
#   9069,
#   27506,
#   114,
#   10462,
#   21789,
#   58303],
#  [8915, 37093, 11287, 52560, 42815, 21386, 77692],
#  [8915, 21039, 24891, 119123, 92688, 92688, 42815, 21386, 77692],
#  [8916, 41693, 9595, 25242, 13764, 47121, 10240],
#  [8916, 41693, 119385, 71793, 27528],
#  [8920, 12692],
#  [100, 120, 8857],
#  [110589,
#   24206,
#   56645,
#   113,
#   9539,
#   18784,
#   100372,
#   21614,
#   118912,
#   114,
#   10777,
#   11447],
#  [8924,
#   17342,
#   29455,
#   119153,
#   17342,
#   9941,
#   56645,
#   122,
#   47407,
#   115,
#   10186,
#   73380],
#  [8924, 37388, 118744, 17342],
#  [8924,
#   56645,
#   58205,
#   9861,
#   18622,
#   31531,
#   56645,
#   119070,
#   9834,
#   27654,
#   9240,
#   118736,
#   9358,
#   52951],
#  [8924, 56645, 48653, 69975, 11447],
#  [8924, 118903, 120, 8857],
#  [109043, 9136, 119312, 42144, 10244, 10240],
#  [109043, 9136, 119312, 119251, 118678, 42144, 10244, 10240],
#  [8924, 73352, 48549, 41521, 15184, 10757],
#  [8924, 73352, 48549, 41521, 15184, 10757, 10240],
#  [8924, 27654, 107693, 12605, 10729, 11369],
#  [8924, 27654, 29364, 45725, 119073, 10407, 100372],
#  [8924, 35115, 119357, 9331, 41442],
#  [8926, 14423],
#  [8927, 17342, 58205, 9318, 92688, 119324, 43022, 118773],
#  [100, 113, 9358, 52951, 114],
#  [100, 113, 9705, 16605, 52951, 114],
#  [8927,
#   11261,
#   31065,
#   104021,
#   25517,
#   118949,
#   20308,
#   119251,
#   118678,
#   111,
#   9313,
#   20308,
#   104021,
#   119333,
#   12605,
#   119375,
#   76977,
#   10240],
#  [8927,
#   11261,
#   31065,
#   104021,
#   25517,
#   118949,
#   20308,
#   18622,
#   24891,
#   111,
#   9779,
#   52015,
#   104021,
#   119333,
#   12605,
#   119375,
#   76977,
#   10240],
#  [8928, 17138, 9246, 24206, 11261, 25503, 8898, 13764],
#  [8928, 38631, 100],
#  [8929, 21155, 113, 8909, 114, 120, 11895],
#  [8929, 21155, 113, 9321, 119249, 114, 11093, 10240],
#  [8929, 21155, 113, 9321, 119249, 114, 10757, 10240],
#  [8929, 21155, 113, 9321, 119249, 114, 120, 11895],
#  [8929, 21155, 113, 9321, 119249, 46520, 114],
#  [8929, 21155, 113, 9321, 119249, 46520, 114, 120, 11895],
#  [8929, 21155, 113, 9327, 114],
#  [8929, 21155, 113, 9327, 114, 11093, 10240],
#  [8929, 21155, 113, 9327, 114, 10757, 10240],
#  [8929, 21155, 113, 9327, 114, 120, 11895],
#  [8932, 114, 9265, 119070, 118930, 11261, 27355],
#  [8932, 11903, 26737, 37093, 9975, 49212, 118927, 10739, 106826, 10197],
#  [8932, 27654, 9309, 25503, 103917, 88332, 119188, 39900, 11166, 10240],
#  [8932, 27654, 9595, 19105, 119224],
#  [8932, 27654, 9954, 58303, 19105, 119224],
#  [8932, 27654, 114, 9879, 118958, 21155, 119010, 10884, 117, 11093, 46520],
#  [8932, 14646, 24974, 9462, 106249, 18622, 119330, 11287, 17342, 16985, 14153],
#  [8932, 14646, 24974, 9779, 24891],
#  [8932,
#   91837,
#   22458,
#   48446,
#   119169,
#   38851,
#   18784,
#   8934,
#   15001,
#   78136,
#   56645,
#   10739],
#  [8932, 91837, 22458, 48446, 119169, 38851, 18784, 9056, 20308, 11261, 24891],
#  [8932, 91837, 22458, 48446, 119169, 38851, 18784, 9421, 92688, 15184],
#  [8932,
#   91837,
#   22458,
#   48446,
#   119169,
#   38851,
#   18784,
#   9812,
#   119372,
#   17342,
#   18392,
#   107693],
#  [8932,
#   91837,
#   22458,
#   48446,
#   119169,
#   38851,
#   18784,
#   9836,
#   11261,
#   41605,
#   36553,
#   15184],
#  [8932,
#   91837,
#   22458,
#   48446,
#   119169,
#   38851,
#   18784,
#   168,
#   9056,
#   20308,
#   9202,
#   24891],
#  [8932, 91837, 12605, 118937, 9056, 20308, 11261, 24891],
#  [8932, 48387, 118661],
#  [8932, 16605, 118834, 113, 122, 14871, 13764, 114],
#  [73142, 9139, 120, 11895],
#  [73142, 120, 9657, 16985, 119245, 46520],
#  [73142, 120, 9420, 18471, 46520],
#  [73142,
#   8843,
#   35866,
#   11903,
#   25517,
#   100329,
#   118831,
#   119312,
#   113,
#   9246,
#   118762,
#   118912,
#   114,
#   10777,
#   11447,
#   118,
#   12262,
#   85771,
#   11369],
#  [73142, 8845, 21155, 46520],
#  [73142, 8845, 21155, 46520, 120, 8857],
#  [73142, 8845, 21155, 46520, 120, 9319, 12605],
#  [73142, 8845, 13890, 120, 175],
#  [73142, 8845, 13890, 120, 8857],
#  [73142, 8847, 18622, 117, 8888, 101322, 12965, 117, 9410, 18622, 120, 8857],
#  [73142, 8848, 120, 8857],
#  [73142, 8848, 13764, 119367, 118667],
#  [73142, 8865, 47181, 24974, 52951, 120, 8857],
#  [73142, 8865, 47181, 32158, 38688, 120, 8857],
#  [73142, 8865, 11882, 46520, 117, 8880, 11882, 46520, 120, 8857],
#  [73142, 8887, 49919, 120, 8857],
#  [73142, 8888, 12310, 46520, 120, 11895],
#  [73142, 8888, 12310, 46520, 120, 8857],
#  [73142, 8888, 119274, 13890, 120, 8857],
#  [73142, 8898, 18392, 120, 9319, 12605],
#  [73142, 8898, 18392, 46520, 120, 10407, 10240],
#  [73142, 8898, 18392, 46520, 120, 11895],
#  [73142, 8898, 18392, 46520, 120, 8857],
#  [73142, 8898, 18392, 46520, 120, 9319, 12605],
#  [73142, 8898, 18392, 32158, 38688, 120, 8857],
#  [73142, 8898, 13764, 46520, 120, 8857],
#  [73142, 8909, 15891, 117, 9067, 14867, 120, 8857],
#  [73142, 8929, 21155, 113, 9327, 114, 120, 11895],
#  [73142, 8929, 21155, 46520, 120, 11895],
#  [73142, 8935, 120, 10407, 10240],
#  [73142, 8935, 120, 175],
#  [73142, 8935, 120, 8857],
#  [73142, 8935, 89523, 10739, 120, 123, 47407],
#  [73142, 8982, 29364, 46520, 117, 9336, 103906, 46520, 120, 8857],
#  [73142, 9001, 18778, 21155, 52951, 46520, 120, 11895],
#  [73142, 9001, 18778, 21155, 52951, 46520, 120, 8857],
#  [73142, 9001, 13890, 21155, 52951, 46520, 120, 10407, 10240],
#  [73142, 9001, 13890, 21155, 52951, 46520, 120, 8857],
#  [73142, 25805, 11903, 120, 8857],
#  [73142, 9062, 120, 175],
#  [73142, 9062, 120, 11895],
#  [73142, 9062, 120, 8857],
#  [73142, 9074, 118782],
#  [73142, 9087, 17342, 12508],
#  [73142, 101660, 107693, 120, 8857],
#  [73142, 101660, 107693, 46520],
#  [73142, 9096, 68833, 12310, 120, 10407, 10240],
#  [73142, 9096, 68833, 12310, 120, 11895],
#  [73142, 9096, 68833, 12310, 120, 8857],
#  [73142, 9099, 13890, 120, 8857],
#  [73142, 9102, 14646, 120, 175],
#  [73142, 9102, 14646, 120, 11895],
#  [73142, 9102, 14646, 120, 8857],
#  [73142, 9102, 42815],
#  [73142, 9102, 42815, 120, 8857],
#  [73142, 100, 118, 12262, 85771, 11369],
#  [73142, 9133, 12310, 120, 11895],
#  [73142, 9139],
#  [73142, 9139, 120, 175],
#  [73142, 9139, 101202, 29455, 117, 9591, 13764, 120, 11895],
#  [73142, 9139, 101202, 29455, 117, 9591, 13764, 120, 8857],
#  [73142, 9139, 20479, 118834],
#  [73142, 9139, 46520, 120, 10407, 10240],
#  [73142, 9139, 46520, 120, 11895],
#  [73142, 9139, 46520, 120, 8857],
#  [73142, 9157, 14867],
#  [73142, 9246, 11287, 27654, 120, 8857],
#  [73142, 9248, 118802],
#  [73142, 9255, 11664, 117, 9569, 14423, 11882, 18392, 120, 8857],
#  [73142, 9297, 17196, 24974, 52951, 120, 8857],
#  [73142, 9309, 24974, 24974, 52951, 120, 8857],
#  [73142, 9317, 30134, 119249],
#  [73142, 9330, 120, 8857],
#  [73142, 9330, 119274, 117, 9294, 120, 11895],
#  [73142, 9336, 21876, 120, 8857],
#  [73142, 100],
#  [73142, 9362, 12508, 17342, 14867, 120, 8857],
#  [73142, 9365, 21155, 46520, 120, 9319, 12605],
#  [73142, 9365, 21155, 46520, 113, 9001, 18778, 114, 120, 9319, 12605],
#  [73142, 9365, 21155, 46520, 120, 10407, 10240],
#  [73142, 9365, 21155, 46520, 120, 175],
#  [73142, 9365, 21155, 46520, 120, 11895],
#  [73142, 9365, 21155, 46520, 120, 8857],
#  [73142, 9379, 118751, 120, 8857],
#  [73142, 9390],
#  [73142, 9405, 119341, 46520, 120, 8857],
#  [73142, 9410, 66540, 118667, 118969],
#  [73142, 9415, 27355, 120, 11895],
#  [73142, 9418, 30873, 15001, 117, 8845, 50450, 21711, 119253, 120, 8857],
#  [73142, 9420, 18471, 46520, 120, 8857],
#  [73142, 9420, 119446, 24974, 52951, 120, 8857],
#  [73142,
#   100,
#   117,
#   9240,
#   12605,
#   117,
#   9890,
#   12692,
#   15184,
#   118922,
#   15184,
#   120,
#   8857],
#  [73142, 9435, 119335, 24982, 17730, 120, 8857],
#  [73142, 9448, 12605, 46520, 120, 175],
#  [73142, 9448, 12605, 46520, 120, 11895],
#  [73142, 9448, 12605, 46520, 120, 8857],
#  [73142, 9448, 14040, 12508, 120, 10407, 10240],
#  [73142, 9448, 14040, 12508, 120, 175],
#  [73142, 9448, 14040, 12508, 120, 8857],
#  [73142, 9460, 118963, 120, 8857],
#  [73142, 9460, 21386, 29364, 113, 9001, 18778, 114],
#  [73142, 9460, 58303, 22333, 11664, 12310, 120, 8857],
#  [73142, 9462, 14423],
#  [73142, 100, 120, 8857],
#  [73142, 9477, 46150, 14153, 45725, 120, 8857],
#  [73142, 9485, 12692, 119134, 120, 8857],
#  [73142,
#   9485,
#   24891,
#   106065,
#   22333,
#   12605,
#   69168,
#   10929,
#   11447,
#   118,
#   12262,
#   85771,
#   11369],
#  [73142, 9486, 38688, 52951],
#  [73142, 9486, 36210, 38688],
#  [73142, 9486, 52951, 37114, 118739],
#  [73142, 9499],
#  [73142, 9499, 120, 11895],
#  [73142, 9499, 10759],
#  [73142,
#   9499,
#   20479,
#   15891,
#   22333,
#   12605,
#   83811,
#   15891,
#   24974,
#   28847,
#   11447,
#   118,
#   139,
#   62146,
#   11090,
#   51036],
#  [73142, 9519, 48653, 20308, 67527, 120, 8857],
#  [73142, 9538, 119253],
#  [73142, 9543, 118739, 13890],
#  [73142, 9546, 118944],
#  [73142, 9546, 118944, 120, 8857],
#  [73142,
#   9559,
#   10739,
#   22458,
#   21039,
#   55358,
#   14040,
#   40032,
#   18622,
#   97146,
#   13764,
#   10884,
#   100595,
#   11447,
#   118,
#   32349,
#   108408,
#   139,
#   72185],
#  [73142, 9580, 118841, 12310, 9486, 36210, 38688],
#  [73142,
#   9580,
#   45725,
#   45725,
#   28188,
#   92688,
#   106826,
#   15001,
#   102360,
#   12605,
#   108122,
#   11447,
#   118,
#   12262,
#   85771,
#   11369],
#  [73142, 9600, 31503, 24974, 52951, 120, 8857],
#  [73142, 9604, 18778, 120, 8857],
#  [73142, 9626, 15891],
#  [73142, 9634, 38688, 120, 8857],
#  [73142, 9634, 38688, 46520, 120, 8857],
#  [73142, 9634, 38688, 46520, 120, 9319, 12605],
#  [73142, 9637, 46520],
#  [73142, 9637, 46520, 122],
#  [73142, 9638, 37093, 32158, 38688, 120, 8857],
#  [73142, 9638, 42815, 21155, 120, 8857],
#  [73142, 9656, 18227, 24974, 52951, 120, 8857],
#  [73142, 9657, 46520, 120, 8857],
#  [73142, 100, 120, 8857],
#  [73142, 9664, 13441, 13890, 10759, 11733, 11447, 118, 12262, 85771, 11369],
#  [73142, 9665, 43022, 23466, 117, 9992, 23466, 117, 9954, 23466, 120, 8857],
#  [73142, 9675, 12692, 46520],
#  [73142, 9689, 118921, 118969, 120, 8857],
#  [73142, 9689, 42337, 24974, 52951, 120, 8857],
#  [73142, 9689, 21155, 46520, 120, 10407, 10240],
#  [73142, 9689, 21155, 46520, 120, 8857],
#  [73142, 9701, 40958, 21155, 52951, 46520, 120, 8857],
#  [73142, 9730, 32158, 38688, 120, 8857],
#  [73142, 9738, 22333],
#  [73142, 9738, 22333, 46520],
#  [73142, 9738, 22333, 46520, 120, 10407, 10240],
#  [73142, 9738, 22333, 46520, 120, 11895],
#  [73142, 9738, 22333, 46520, 120, 8857],
#  [73142, 9751, 11882],
#  [73142, 9751, 22333, 24974, 52951, 120, 8857],
#  [73142, 9757, 25517, 11882, 13764, 120, 8857],
#  [73142, 9757, 119308, 118906, 120, 8857],
#  [73142, 9779, 24891, 120, 8857],
#  [73142, 9779, 119330, 117, 9089, 11287, 12605, 120, 10407, 10240],
#  [73142, 9779, 119330, 117, 9089, 11287, 12605, 120, 11895],
#  [73142, 9793, 46520],
#  [73142, 9798, 97146, 120, 8857],
#  [73142, 9798, 97146, 36210, 38688, 120, 11895],
#  [73142, 9806, 10739, 20308, 120, 8857],
#  [73142, 9812, 25517, 16985, 120, 8857],
#  [73142, 9819, 16439, 29364, 120, 10407, 10240],
#  [73142, 9819, 16439, 29364, 120, 8857],
#  [73142, 9819, 29364],
#  [73142, 9824, 21039, 120, 8857],
#  [73142, 9834, 37388, 106826, 120, 8857],
#  [73142,
#   9847,
#   21386,
#   15891,
#   78301,
#   10929,
#   77526,
#   115,
#   10233,
#   118,
#   139,
#   62146,
#   11090,
#   51036],
#  [73142, 9847, 21386, 32158, 38688, 120, 8857],
#  [73142, 9873, 23811, 26444, 120, 8857],
#  [73142, 9879, 20626, 67527, 120, 8857],
#  [73142, 9886, 118667, 117, 9365, 119285, 11287, 35866, 120, 8857],
#  [73142, 9886, 118667, 46520],
#  [73142,
#   9890,
#   12692,
#   119412,
#   119043,
#   48205,
#   10929,
#   77526,
#   118,
#   139,
#   62146,
#   11090,
#   51036],
#  [73142, 9928, 12092, 120, 8857],
#  [73142, 9935, 31503, 12692, 28847, 10929, 11447, 118, 12262, 85771, 11369],
#  [73142,
#   9949,
#   17342,
#   118791,
#   97146,
#   16985,
#   18622,
#   24891,
#   88332,
#   119188,
#   11305,
#   11373,
#   11011,
#   11447,
#   118,
#   32349,
#   108408,
#   139,
#   72185],
#  [73142, 9954, 11882, 117, 9615, 35506, 12605, 120, 8857],
#  [73142, 9963, 120, 8857],
#  [73142, 9993, 13890, 12508, 120, 8857],
#  [73142, 9993, 13890, 52951, 120, 8857],
#  [73142, 120, 8857, 113, 9331, 31928, 114],
#  ...]

# %%
add_special_token(doc)
# Out:
# ['[CLS]  찰기장 40kg        [SEP]',
#  '[CLS] Vanilla Raspberry Cake KR 245g(바닐라라즈베리케익)1pack(245g) 냉동[SEP]',
#  '[CLS] y트리오 1kg[SEP]',
#  '[CLS] 건아로니아[SEP]',
#  '[CLS] 계란(30구)[SEP]',
#  '[CLS] 니콜하우스 생과일주스[SEP]',
#  '[CLS] 다래월드 다목적 세정제[SEP]',
#  '[CLS] 돌김자반80g [SEP]',
#  '[CLS] 돼지갈비찜[SEP]',
#  '[CLS] 딸기잼(225g/병)[SEP]',
#  '[CLS] 람베르츠리블링스슈튀케250g[SEP]',
#  '[CLS] 메디테라니아스파게티500g[SEP]',
#  '[CLS] 몽블랑[SEP]',
#  '[CLS] 바나나200 [SEP]',
#  '[CLS] 바움쿠헨 흑당[SEP]',
#  '[CLS] 바이탭 쿨 브리즈  핸드 선풍기[SEP]',
#  '[CLS] 발사믹 드레싱(샐러디)[SEP]',
#  '[CLS] 속편한우유 플러스 저지방 멸균 190ml[SEP]',
#  '[CLS] 스파게티면 170g[SEP]',
#  '[CLS] 육개장 사발면 농심 86g[SEP]',
#  '[CLS] 음료류[SEP]',
#  '[CLS] 이츠웰 떡뽂이(국) [SEP]',
#  '[CLS] 일년내내 찰보리   [SEP]',
#  '[CLS] 종가집 생생김치 3kg[SEP]',
#  '[CLS] 참부오느 소불&amp;파타타빵[SEP]',
#  '[CLS] 청정원 청정미역 150g[SEP]',
#  '[CLS] 치즈떡볶이[SEP]',
#  '[CLS] 포도 5kg[SEP]',
#  '[CLS] 포테이토달라스(감자튀김) 2,27kg[SEP]',
#  '[CLS] 프레시워터핸드세니타이저(100ml)[SEP]',
#  '[CLS] 허니머스타드 드레싱(샐러디)[SEP]',
#  '[CLS] 화이트  시크릿홀 울날 중형19입[SEP]',
#  '[CLS](냉동)밀떡볶이[SEP]',
#  '[CLS](농심)맥코믹바질10g[SEP]',
#  '[CLS](떡보의하루)떡[SEP]',
#  '[CLS](롯데)국산콩두부기획[SEP]',
#  '[CLS](롯데)야채크래커300G[SEP]',
#  '[CLS](마산蒙명산)몽고국간장 900ml[SEP]',
#  '[CLS](뱅크)소고기향쌀국수240g[SEP]',
#  '[CLS](뱅크)치킨향쌀국수240g[SEP]',
#  '[CLS](북부산새마을금고) 사과 식초 PET 900ml[SEP]',
#  '[CLS](비건)식물성 동글떡볶이[SEP]',
#  '[CLS](실온) 크림파스타 1인[SEP]',
#  '[CLS](쌀)짠맛을 줄인 건강한 쌀고추장 500G[SEP]',
#  '[CLS](아이큐어)에어포테쉬볼륨팝브러시(골드)[SEP]',
#  '[CLS](아이큐어)에포데쉬볼륨팝브러시세트(블루브러시1+다크브라운헤어왁스1)[SEP]',
#  '[CLS](아이큐어)에포테쉬볼륨팝브러시세트(그린브러쉬1+다크브라운헤어왁스1)[SEP]',
#  '[CLS](아이큐어)에포테쉬볼륨팝브러시세트(그린브러시1+브라운헤어왁스1)[SEP]',
#  '[CLS](아이큐어)에포테쉬볼륨팝브러시세트(핫핑크브러시1+다크브라운헤어왁스1)[SEP]',
#  '[CLS](아이큐어)에포테쉬볼륨팝브러시세트(핫핑크브러시1+브라운헤어왁스)[SEP]',
#  '[CLS](아이큐어)에포테쉬볼륨팝브러시헤어왁스(다크브라운)10g[SEP]',
#  '[CLS](아이큐어)에포테쉬볼륨팝브러시헤어왁스(브라운)10g[SEP]',
#  '[CLS](애니펀)빵모자[SEP]',
#  '[CLS](전)활력천왕_지함[SEP]',
#  '[CLS](주) 빙그레 바나나맛우유 바나나향 240ML[SEP]',
#  '[CLS](주) 오뚜기 3분 햄버그 스테이크 140G x 6EA[SEP]',
#  '[CLS](주) 일등농산 경기미 10kg[SEP]',
#  '[CLS](주)그린 일상가정식 나주곰탕 450g[SEP]',
#  '[CLS](주)그린 일상가정식 장어탕 450g[SEP]',
#  '[CLS](주)꽃샘식품 둥굴레 담은 누룽지차 1.5g*40T [SEP]',
#  '[CLS](주)꿈꾸는콩 맑은물에 국산 촌두부 찌개용 300g [SEP]',
#  '[CLS](주)농심 누들핏 떡볶이국물맛 50.4g [SEP]',
#  '[CLS](주)농심 덴마크튤립햄 클래식 200g[SEP]',
#  '[CLS](주)농심 배홍동 비빔면 137g*4입[SEP]',
#  '[CLS](주)농심 신라면(멀티박스) 600G x 8EA[SEP]',
#  '[CLS](주)농심 안성탕면컵66g*6입[SEP]',
#  '[CLS](주)농심 오징어집 83g[SEP]',
#  '[CLS](주)농심 옥수수면 73g[SEP]',
#  '[CLS](주)농협목우촌 프라임 리얼감자너겟 450G x 1EA[SEP]',
#  '[CLS](주)다래월드 저푸른초원위에 손세정제 500ml[SEP]',
#  '[CLS](주)다래월드 저푸른초원위에 손세정제(젤타입) 250ml[SEP]',
#  '[CLS](주)대경햄 화이트소시지(햄)[SEP]',
#  '[CLS](주)대상 태양초고추장 1800G[SEP]',
#  '[CLS](주)대신에프에스 카라멜칩 [SEP]',
#  '[CLS](주)동원F&amp;B 쎈쿡 100% 통곡물밥 195G x 1EA[SEP]',
#  '[CLS](주)동원F&B 동원 웨이크업뷰티 500ML x 1EA[SEP]',
#  '[CLS](주)동원F&B 동원 웨이크업뷰티 500ML x 20EA[SEP]',
#  '[CLS](주)동원에프앤비 데일리케어 쇠고기죽 287.5g[SEP]',
#  '[CLS](주)동원에프앤비 동원 간편요리KIT 골뱅이탕 얼큰한국물 280g[SEP]',
#  '[CLS](주)동원에프앤비 동원 자연산 골뱅이 300g[SEP]',
#  '[CLS](주)동원에프앤비 동원참치 단백질바 30g(오리지널)[SEP]',
#  '[CLS](주)동원에프앤비 동원참치 단백질바 30g(초코로핀)[SEP]',
#  '[CLS](주)동원에프앤비 떡볶이의신 더매운 떡볶이 160g[SEP]',
#  '[CLS](주)동원에프앤비 양반 김부각 50g[SEP]',
#  '[CLS](주)동원에프앤비 양반 소고기미역국 460G[SEP]',
#  '[CLS](주)동원에프앤비 양반 수라 차돌삼합죽 420g[SEP]',
#  '[CLS](주)동원에프앤비 양반 수라 차돌육개장 460g[SEP]',
#  '[CLS](주)동원에프앤비 양반 수라 통다리닭죽 420g[SEP]',
#  '[CLS](주)동원에프앤비 양반 수라 통다리삼계탕 460G[SEP]',
#  '[CLS](주)동원에프앤비 양반 전복죽 420g[SEP]',
#  '[CLS](주)동원에프앤비 양반김치 양반 볶음 비빔김치 120g[SEP]',
#  '[CLS](주)동원에프앤비 콩카페 연유라떼 250mL[SEP]',
#  '[CLS](주)디핀다트코리아 팝앤샷 레인보우[SEP]',
#  '[CLS](주)로뎀푸드 서울마님 즉석 오감떡볶이 정통짜장맛 280g[SEP]',
#  '[CLS](주)롯데삼강 Chefood 부산밀면&부산비빔밀면 1420G[SEP]',
#  '[CLS](주)롯데제과 운동할때 씹는 껌 리필_107g[SEP]',
#  '[CLS](주)맑은동해 맑은물에 연해주콩 콩물 1000ml[SEP]',
#  '[CLS](주)맑은물에 좋은상품 순두부(국산) 400G[SEP]',
#  '[CLS](주)미당  오징어뭇국[SEP]',
#  '[CLS](주)빙그레 요맘때 그릭플레인 150ml[SEP]',
#  '[CLS](주)빙그레 요맘때 쉐이크 딸기 120ml[SEP]',
#  '[CLS](주)빙그레 요맘때 프로바이오틱스 그릭콘 믹스 베리 150ml[SEP]',
#  '[CLS](주)빙그레 초코 붕어싸만코 150ml[SEP]',
#  '[CLS](주)사조대림 대림선 옛날붕어빵 단팥 500G x 1EA[SEP]',
#  '[CLS](주)사조대림 대림선 옛날붕어빵 슈크림 500G x 1EA[SEP]',
#  '[CLS](주)삼립식품 리얼촉촉치즈케익 700G[SEP]',
#  '[CLS](주)숲풀림식품 청정원 안주야 논현동포차스타일 매운껍데기180g  [SEP]',
#  '[CLS](주)스윗밸런스 라이스 누들 샐러드 180g [SEP]',
#  '[CLS](주)스윗밸런스 심플 다크카카오 쫀득빵 43g[SEP]',
#  '[CLS](주)스윗밸런스 심플 얼그레이 쫀득빵 43g[SEP]',
#  '[CLS](주)스윗밸런스 심플 흑임자 쫀득빵 43g[SEP]',
#  '[CLS](주)스윗밸런스 치킨 볼로네제 파스타 샐러드 180g[SEP]',
#  '[CLS](주)신원에프아이  일상가정식 도가니탕 450g [SEP]',
#  '[CLS](주)신원에프아이  일상가정식 소머리곰탕 450g [SEP]',
#  '[CLS](주)쌍용씨앤비  코디 순수 3겹 데코 30*30[SEP]',
#  '[CLS](주)쌍용씨앤비  코디 순수 3겹데코 30*30[SEP]',
#  '[CLS](주)쌍용씨앤비  코디 행복이 사사삭 130*2[SEP]',
#  '[CLS](주)쌍용씨앤비 코디 에코그린 180*3(무향) [SEP]',
#  '[CLS](주)쌍용씨앤비 후레시아 마일드(캡) 100매 [SEP]',
#  '[CLS](주)씨알푸드 씨알로 뽀로로아몬드프레이크 580G[SEP]',
#  '[CLS](주)씨알푸드 씨알로 뽀로로오곡초코로핀 520G[SEP]',
#  '[CLS](주)아이디플라코스메틱 아이디에이지 페이스핏 브이 핏러 15ml[SEP]',
#  '[CLS](주)아이비젼 파워레인저스윙검(캔디토이) [SEP]',
#  '[CLS](주)에스앤푸드 GS 1974 국산콩두부 찌개/부침겸용 120g[SEP]',
#  '[CLS](주)에스피씨삼립 삼립호빵 발효미종 꿀고구마 360g 4개입[SEP]',
#  '[CLS](주)에스피씨삼립 삼립호빵 발효미종 듬뿍피자 360g 4개입[SEP]',
#  '[CLS](주)에스피씨삼립 삼립호빵 발효미종 생생야채 360g 4개입[SEP]',
#  '[CLS](주)에스피씨삼립 삼립호빵 발효미종 정통단팥 380g 4개입[SEP]',
#  '[CLS](주)에이치에스푸드 귀리·쌀과 물로만 지은 집밥 180g[SEP]',
#  '[CLS](주)엘지생활건강 닥터그루트 애딕트 샴푸 피오니 루즈 100mL[SEP]',
#  '[CLS](주)엘지생활건강 리엔 닥터그루트 애딕트 샴푸 네롤리 아말피 680mL[SEP]',
#  '[CLS](주)엘지생활건강 비욘드 피토아쿠아 픽싱 파운데이션 21호(환한 피부톤) 35G[SEP]',
#  '[CLS](주)엘지생활건강 세이프프렌즈 버블 향균 핸드워시 리틀라이언 500ml 파우더향[SEP]',
#  '[CLS](주)엘지생활건강 세이프프렌즈 버블 향균 핸드워시 리틀어피치 500ml 시트러스향[SEP]',
#  '[CLS](주)엘지생활건강 수퍼보타닉 로즈마리 바디워시 900g[SEP]',
#  '[CLS](주)엘지생활건강 엘라스틴 원더글램 시크릿 볼륨앤컬 에센스 150ml[SEP]',
#  '[CLS](주)엘지생활건강 온더바디 데일리 선크림 파우치 7ml*3입[SEP]',
#  '[CLS](주)엘지생활건강 온더바디 벨먼내추럴스파 릴리드모헬리 스크럽 바디클렌저 1L[SEP]',
#  '[CLS](주)엘지생활건강 온더바디 세꼼마 버블 항균 핸드워시  레몬향 200ml[SEP]',
#  '[CLS](주)엘지생활건강 온더바디 세꼼마 버블 항균 핸드워시 레몬향 250ml[SEP]',
#  '[CLS](주)엘지생활건강 온더바디 핸드 새니타이저 겔(에탄올) 480ml[SEP]',
#  '[CLS](주)엘지생활건강 죽염 청신원 90g[SEP]',
#  '[CLS](주)엘지생활건강 페리오 히말라야 핑크솔트 칫솔[SEP]',
#  '[CLS](주)오뚜기 GAMERZ CUP  딜러 핫치킨마요 로스트아크소서리스 스페셜에디션 130G[SEP]',
#  '[CLS](주)오뚜기 김치라면 멀티 (120gX4)[SEP]',
#  '[CLS](주)오뚜기 맛있는 오뚜기 컵밥  톡톡 김치알밥 192g[SEP]',
#  '[CLS](주)오뚜기 맛있는 오뚜기 컵밥 오삼불고기덮밥[SEP]',
#  '[CLS](주)오뚜기 맛있는 오뚜기 컵밥 제육덮밥[SEP]',
#  '[CLS](주)오뚜기 맛있는 오뚜기 컵밥 진짬뽕밥[SEP]',
#  '[CLS](주)오뚜기 맛있는 오뚜기 컵밥 춘천닭갈비덮밥[SEP]',
#  '[CLS](주)오뚜기 연생강 35G[SEP]',
#  '[CLS](주)오뚜기 옛날 쇠고기미역국 500G[SEP]',
#  '[CLS](주)오뚜기 오감포차 새우감바스 200G[SEP]',
#  '[CLS](주)오뚜기 육개장 컵 (104GX6개)[SEP]',
#  '[CLS](주)오뚜기 컵누들 매콤한맛 195kcal 박스 [SEP]',
#  '[CLS](주)오뚜기 프레스코 게살로제 파스타소스 360G[SEP]',
#  '[CLS](주)오뚜기 프레스코 베이컨 토마토 리조또 250g[SEP]',
#  '[CLS](주)오뚜기 해물짬뽕 120g[SEP]',
#  '[CLS](주)오뚜기라면 오뚜기 초간편 감자전 믹스[SEP]',
#  '[CLS](주)오리온 눈을감자[SEP]',
#  '[CLS](주)우리찬 베베푸드 아빠가 만든 야채밥앤 [SEP]',
#  '[CLS](주)움트리 까르보나라 떡볶이 155G x 1EA[SEP]',
#  '[CLS](주)원당 보기(寶氣)톳국수[SEP]',
#  '[CLS](주)원일식품 샐뽕소스 [SEP]',
#  '[CLS](주)위드 1인중심 구운치즈오징어포 [SEP]',
#  '[CLS](주)유한양행 해피홈 에어로솔(무향) [SEP]',
#  '[CLS](주)이지바이오 닭가슴살 소시지[SEP]',
#  '[CLS](주)정다운 유황오리훈제[SEP]',
#  '[CLS](주)정식품 검은콩고칼슘 1000G x 6EA[SEP]',
#  '[CLS](주)정식품 담백한고칼슘베지밀에이 190G x 16EA[SEP]',
#  '[CLS](주)정식품 담백한베지밀 검은콩두유 190G[SEP]',
#  '[CLS](주)정식품 아몬드와호두베지밀 190G[SEP]',
#  '[CLS](주)정식품 진하고고소한두유 190G x 16EA[SEP]',
#  '[CLS](주)정식품 칼슘가득베지밀 검은콩두유 190G x 1EA[SEP]',
#  '[CLS](주)정우식품 배추김치 [SEP]',
#  '[CLS](주)제이드에프앤비  카페디바  무야호커피[SEP]',
#  '[CLS](주)제이앤이 HBAF 허니버터 팝콘[SEP]',
#  '[CLS](주)제이제이푸드 우리밀프리미엄더츄로 [SEP]',
#  '[CLS](주)지엔엠라이프 품격있는 유기농석류즙[SEP]',
#  '[CLS](주)진주햄 천하장사 치즈 504g[SEP]',
#  '[CLS](주)토박이 제주보리된장 450g[SEP]',
#  '[CLS](주)파낙스코리아 내이름은장어 장어구이양념소스(진짜매운맛) [SEP]',
#  '[CLS](주)파렌즈 NII 3단우산[SEP]',
#  '[CLS](주)팔도 더 왕뚜껑 120g[SEP]',
#  '[CLS](주)팔도 더왕뚜껑(멀티) 120g [SEP]',
#  '[CLS](주)팔도 비빔면 130G x 1EA[SEP]',
#  '[CLS](주)팔도 왕뚜껑(봉지면) 130g[SEP]',
#  '[CLS](주)팔복 사골진국 420g[SEP]',
#  '[CLS](주)풍림푸드 피코크 야채계란말이 165G[SEP]',
#  '[CLS](주)프레시지 식재료외 소스류[SEP]',
#  '[CLS](주)피죤 2017뉴액츠 퍼펙트 베이킹소다 1.6LIT 파우치 [SEP]',
#  '[CLS](주)하늘바이오농업회사법인 오희숙전통부각 김부각 40g 40G x 1EA[SEP]',
#  '[CLS](주)하림)참진얼큰짜글이300*20[SEP]',
#  '[CLS](주)하림산업 글라이드 구운삼각밥 480g[SEP]',
#  '[CLS](주)하림산업 글라이드 국물라볶이 400g[SEP]',
#  '[CLS](주)하림산업 글라이드 남도떡갈비 450g[SEP]',
#  '[CLS](주)하림산업 글라이드 육수의 내공 닭육수라면 (116g*4봉)[SEP]',
#  '[CLS](주)하림산업 글라이드 육수의 내공 칼칼라면 (137g * 4입)[SEP]',
#  '[CLS](주)하림산업 글라이드 육수의 내공 칼칼라면 Non Fried (116 * 4입)[SEP]',
#  '[CLS](주)하림산업 글라이드 육수의 내공 칼칼라면 용기 Non-Fried 105g[SEP]',
#  '[CLS](주)하림산업 글라이드 통가슴살가라아게 480g[SEP]',
#  '[CLS](주)해피트리 명안가  율무자색명안떡 [SEP]',
#  '[CLS](중외)손소독세정제[SEP]',
#  '[CLS](청정원)미네스트로네수프240G[SEP]',
#  '[CLS](크라운)땅콩카라멜220G[SEP]',
#  '[CLS](파)꽈배기도넛[SEP]',
#  '[CLS](파)단팥도넛[SEP]',
#  '[CLS](파)맘모스빵[SEP]',
#  '[CLS](파)생크림소보루[SEP]',
#  '[CLS](파)슈크림빵(리)[SEP]',
#  '[CLS](파)정통크라상[SEP]',
#  '[CLS](파)커피번[SEP]',
#  '[CLS](포)리무버[SEP]',
#  '[CLS](학)연세대학교 연세우유 연세 고칼슘두유 200ml 200G x 1EA[SEP]',
#  '[CLS](해초)조염(미역)120G[SEP]',
#  '[CLS](현미)매운고추장 400g+100g[SEP]',
#  '[CLS](현미)찰고추장 800g+200g(대리점[SEP]',
#  '[CLS]*계란[SEP]',
#  '[CLS]*사골육수[SEP]',
#  '[CLS]*치킨[SEP]',
#  '[CLS]？？니 크레이지 레몬맛 29g[SEP]',
#  '[CLS][B2B][미트리] 프로틴바 아몬드 40 g (20입)[SEP]',
#  '[CLS][C]로제소스 4.8kg(냉장)[SEP]',
#  '[CLS][C]목살막구이 4.95kg(냉장)[SEP]',
#  '[CLS][C]비빔냉면장 2kg(냉장)[SEP]',
#  '[CLS][C]비트부각 30g(냉장) [SEP]',
#  '[CLS][C]쑥쑥미니롤딸기 70g(냉장) [SEP]',
#  '[CLS][C]쑥쑥미니롤치즈 70g(냉장) [SEP]',
#  '[CLS][C]프리미엄된장다데기 2kg(냉장)[SEP]',
#  '[CLS][CJ]참기름류[SEP]',
#  '[CLS][PS] PS바로느껴지는미남콜라겐+ 3g x 14포 [SEP]',
#  '[CLS][PS] PS바로느껴지는미인콜라겐+ 3g x 14포 [SEP]',
#  '[CLS][농협]임금님표이천쌀 10kg[SEP]',
#  '[CLS][대경] 비빔국수소스 /개[SEP]',
#  '[CLS][면나라]548g쌀국수[SEP]',
#  '[CLS][모나미]12색 6ml 수채물감 모니주(남)[SEP]',
#  '[CLS][모닝]줄없는종합장(여)(무형광)무선[SEP]',
#  '[CLS][모닝]캠퍼스메이트원링SP노트[SEP]',
#  '[CLS][쌀10kg] 여주농협대왕님표 여주쌀(롯데랑)[SEP]',
#  '[CLS][쌀10kg] 추청경기미[SEP]',
#  '[CLS][아임이] 신선함을 그대로 제주감귤 500ml[SEP]',
#  '[CLS][애김] 그린 멀티 트리플러스+ (1,000mg x 60캡슐)[SEP]',
#  '[CLS][에스앤푸드][gs리테일 1974 국산콩두부 부침찌개겸용 300g+300g][SEP]',
#  '[CLS][참존]양배추피클[SEP]',
#  '[CLS][청정원]기타장류[SEP]',
#  '[CLS][카페더치즈케익] 기타케익[SEP]',
#  '[CLS][팝콘]몰랑 스케치북[SEP]',
#  '[CLS][팝콘]몰랑스탬프마스킹세트[SEP]',
#  '[CLS][한성]부식류[SEP]',
#  '[CLS]06BCPNS000GBM_비와이씨덧댐에어메리남상하100호[SEP]',
#  '[CLS]0710떡케익[SEP]',
#  '[CLS]1 락스[SEP]',
#  '[CLS]1 밀가루[SEP]',
#  '[CLS]1 식용유[SEP]',
#  '[CLS]1 주방세제(퐁퐁)[SEP]',
#  '[CLS]100% 레드비트 주스 1L (더봄 전용)[SEP]',
#  '[CLS]1000당근슬라이더지우개[SEP]',
#  '[CLS]1000아일랜드드레싱250g[SEP]',
#  '[CLS]12단도시락김(5g*12봉)[SEP]',
#  '[CLS]130ml 워터젤리 사과[SEP]',
#  '[CLS]1회용 우비[SEP]',
#  '[CLS]2 TARTELETTES CHOCOLAT 160g(초코타르트2입)160gx1pack냉동[SEP]',
#  '[CLS]2 된장[SEP]',
#  '[CLS]2 식초[SEP]',
#  '[CLS]2000 냥냥 피규어 10색 볼펜[SEP]',
#  '[CLS]2000베니스콘[SEP]',
#  '[CLS]2080 샤이닝화이트치약 100g*3[SEP]',
#  '[CLS]2080 스마트케어 치약[SEP]',
#  '[CLS]2080 칫솔[SEP]',
#  '[CLS]2080청은차석류치약[SEP]',
#  '[CLS]2080청은차청쾌한[SEP]',
#  '[CLS]2080치솔[SEP]',
#  '[CLS]2080치약 오리지날 알파(4개입)[SEP]',
#  '[CLS]2080치약150G*4, 시그니처토탈블루[SEP]',
#  '[CLS]2080칫솔5+5입세트[SEP]',
#  '[CLS]20랩신손소독제 튜브 75ml[SEP]',
#  '[CLS]22마늘)부드러운갈릭브레드[SEP]',
#  '[CLS]24PONANE000GBB_뽀로로남아수면조끼자동차  해맑은 무채색(흰색) 아동의류-S[SEP]',
#  '[CLS]3 간장[SEP]',
#  '[CLS]3 고등어[SEP]',
#  '[CLS]3 당면[SEP]',
#  '[CLS]3000 꼬망 소프트 노트[SEP]',
#  '[CLS]365.24 닭가슴살 꼬꼬칩 김스틱 매콤한맛25g[SEP]',
#  '[CLS]3M 마스크 공산품 레어(50매입) 대형[SEP]',
#  '[CLS]3M(쓰리엠) KF-94 황사마스크[SEP]',
#  '[CLS]3배사과식초[SEP]',
#  '[CLS]3분 미트볼 150g[SEP]',
#  '[CLS]3분 쇠고기 짜장200g\t\t\t\t[SEP]',
#  '[CLS]3분 짜장[SEP]',
#  '[CLS]3분 짜장 200G[SEP]',
#  '[CLS]3분 카레 순한맛 200G[SEP]',
#  '[CLS]3분 카레 약간매운맛 200G[SEP]',
#  '[CLS]3분김치참치덮밥소스150g[SEP]',
#  '[CLS]3분쇠고기짜장200g[SEP]',
#  '[CLS]3분쇠고기카레[SEP]',
#  '[CLS]3분짜장[SEP]',
#  '[CLS]3분카레[SEP]',
#  '[CLS]3분카레매운맛 200g*3[SEP]',
#  '[CLS]3분햄버거스테이크140g[SEP]',
#  '[CLS]4500나뚜루 쇼콜라 조각케이크[SEP]',
#  '[CLS]5000전통김포쌀 3KG[SEP]',
#  '[CLS]56시간 저온숙식빵[SEP]',
#  '[CLS]5곡 미숫가루[SEP]',
#  '[CLS]5펄풍선혼합외[SEP]',
#  '[CLS]79부대찌개 [SEP]',
#  '[CLS]7oz 후룻컵 배[SEP]',
#  '[CLS]7oz 후룻컵 사과[SEP]',
#  '[CLS]ABC 주스 오리진 NFC[SEP]',
#  '[CLS]ABC초코렛1200[SEP]',
#  '[CLS]ABC초코쿠키 민트 130g*18입 [SEP]',
#  '[CLS]adblue 요소수 10L[SEP]',
#  '[CLS]B)？크레잇/김치찌개250G/상온[SEP]',
#  '[CLS]B)？크레잇/사골곰탕250G/상온[SEP]',
#  '[CLS]B)？크레잇/육개장250G/상온[SEP]',
#  '[CLS]B)？크레잇된장찌개250G/상온[SEP]',
#  '[CLS]B)？햇반210G(36입)NEW/상온[SEP]',
#  '[CLS]BBQ극한왕갈비치킨볶음밥230g[SEP]',
#  '[CLS]BBQ매운극한왕갈비맛볶음밥[SEP]',
#  '[CLS]BBQ오리지날볶음밥[SEP]',
#  '[CLS]BBQ치킨[SEP]',
#  '[CLS]BBQ통살닭다리구이(소금구이맛)[SEP]',
#  '[CLS]Bio spectra 에티튜드 주방세제700ml무향 1개 [SEP]',
#  '[CLS]BYO 10억 생 유산균 2g[SEP]',
#  '[CLS]BYO 20？억생키즈 비타민A[SEP]',
#  '[CLS]BYO？식물성유산균 스킨플러스[SEP]',
#  '[CLS]BYO？식물성유산균패밀리플러스쿠팡/상온[SEP]',
#  '[CLS]C J 둥근햇반[SEP]',
#  '[CLS]C J 백설햇바삭김재래김[SEP]',
#  '[CLS]C J 중력밀가루[SEP]',
#  '[CLS]C J 햄벅스테이크[SEP]',
#  '[CLS]C J 후랑크쏘세지[SEP]',
#  '[CLS]Cica Moisturizing Facial Cleansing Towelettes[SEP]',
#  '[CLS]CJ 백설 신)중력밀가루 1kg[SEP]',
#  '[CLS]CJ 백설설탕 1KG[SEP]',
#  '[CLS]cj 식재료[SEP]',
#  '[CLS]CJ 식재료[SEP]',
#  '[CLS]CJ 하선정 쌈무 새콤한맛 350G x 1EA[SEP]',
#  '[CLS]CJ 하선정김밥단무지[SEP]',
#  '[CLS]CJ 햇반 200g*4[SEP]',
#  '[CLS]CJ 햇반발아현미쌀850g[SEP]',
#  '[CLS]CJ) 쇠고기 다시다 100g[SEP]',
#  '[CLS]CJ) 하선정 멸치액젓 800g[SEP]',
#  '[CLS]CJ)1000 아일랜드 드레싱 240[SEP]',
#  '[CLS]CJ)꽃소금 1kg[SEP]',
#  '[CLS]CJ)다담청국장찌개[SEP]',
#  '[CLS]CJ)맥스봉[SEP]',
#  '[CLS]CJ)밀가루 1Kg[SEP]',
#  '[CLS]CJ)백색설탕 1kg[SEP]',
#  '[CLS]CJ)백설햇당면 500g[SEP]',
#  '[CLS]CJ)비엔나소세지265g[SEP]',
#  '[CLS]CJ)스팸클래식 200g[SEP]',
#  '[CLS]CJ)우동사리면[SEP]',
#  '[CLS]CJ)햇바삭명가김재리김-4*16[SEP]',
#  '[CLS]CJ)햇반 210g[SEP]',
#  '[CLS]CJ백설 하얀설탕 1kg[SEP]',
#  '[CLS]CJ백설올리고당700g[SEP]',
#  '[CLS]CJ백설유 국내콩기름0.5L[SEP]',
#  '[CLS]cj스팸[SEP]',
#  '[CLS]cj스팸복합1호[SEP]',
#  '[CLS]CJ식재료(이관)[SEP]',
#  '[CLS]CJ재래김16봉[SEP]',
#  '[CLS]CJ제일제당 비비고 사골곰탕 500g[SEP]',
#  '[CLS]CJ제일제당 비비고 소고기무국 500g[SEP]',
#  '[CLS]CJ제일제당 식재료[SEP]',
#  '[CLS]CJ제일제당 행복한콩 천일염 국산콩두부 340G x 2EA[SEP]',
#  '[CLS]cj참그린1.2kg[SEP]',
#  '[CLS]CJ햇반 200g[SEP]',
#  '[CLS]CS_카세라믹컵[SEP]',
#  '[CLS]delaffe 아메리카노[SEP]',
#  '[CLS]DJD1002B 100% ABC착즙주스(2L)병[SEP]',
#  '[CLS]DJD1004B 100% 제주당근감귤착즙주스(2L)병[SEP]',
#  '[CLS]DJD1005B 100% 제주비트감귤착즙주스(2L) 병[SEP]',
#  '[CLS]dm체다스트링 치즈(냉동)[SEP]',
#  '[CLS]Dole 애플팝 496ml(62ml*8입)[SEP]',
#  '[CLS]Dole 오렌지팝 62ml 8입팩[SEP]',
#  '[CLS]Dole 파인애플팝 62ml 8입팩[SEP]',
#  '[CLS]Dole 피치팝 496ml(62ml*8입)[SEP]',
#  '[CLS]DY)스위토리졸음뚝껌(87gx6)x4[SEP]',
#  '[CLS]Ear-Friendly Mask[SEP]',
#  '[CLS]EM가루비누(1KG)[SEP]',
#  '[CLS]FD 블루베리 파우더(80mesh) 300g/pack [SEP]',
#  '[CLS]FILSTEM 쇼퍼백 장바구니 M[SEP]',
#  '[CLS]FM기본조끼-35(KHAKI/100)[SEP]',
#  '[CLS]FR네이비구두[SEP]',
#  '[CLS]G7 coffee mix 3in1[SEP]',
#  '[CLS]G7 베트남 커피[SEP]',
#  '[CLS]G7카푸치노모카12입[SEP]',
#  '[CLS]gs 왕두부 550g[SEP]',
#  '[CLS]Gsfresh/맑은콩왕두부550g[SEP]',
#  '[CLS]GSSM 마스크[SEP]',
#  '[CLS]GS리테일 기타신선식품류[SEP]',
#  '[CLS]GS식재료(신선식품)[SEP]',
#  '[CLS]GS신선식품[SEP]',
#  "[CLS]Hannah's Orchard 배도라지[SEP]",
#  "[CLS]Hannah's Orchard 석류[SEP]",
#  '[CLS]HBAF 쌀로별 마늘빵맛(GS)[SEP]',
#  '[CLS]HF절단절임배추(면공방)*10kg*쿱청과김치[SEP]',
#  '[CLS]HY BTS콜드브루(인도전용) 270ml [SEP]',
#  '[CLS]IS  선블록크림[SEP]',
#  '[CLS]just기픈물 1000[SEP]',
#  '[CLS]just기픈물 330[SEP]',
#  '[CLS]just기픈물 330(박스) [SEP]',
#  '[CLS]just기픈물1000(박스)[SEP]',
#  '[CLS]Kettle 크링클컷 감자칩 397g[SEP]',
#  '[CLS]KF80마스크[SEP]',
#  '[CLS]KF94 마스크[SEP]',
#  '[CLS]kf94마스크[SEP]',
#  '[CLS]KF94마스크[SEP]',
#  '[CLS]kF94마스크 [SEP]',
#  '[CLS]KF94마스크(대)[SEP]',
#  '[CLS]KF-AD 비말마스크[SEP]',
#  '[CLS]KF-AD 일회용마스크[SEP]',
#  '[CLS]KF마스크[SEP]',
#  '[CLS]K마스크(KF94)[SEP]',
#  '[CLS]LCL 미키미니아동속옷3500[SEP]',
#  '[CLS]LED43랜턴[SEP]',
#  '[CLS]LG)샤프란아로마     [SEP]',
#  '[CLS]LG)샤프란코튼용[SEP]',
#  '[CLS]LG)샤프란핑크센[SEP]',
#  '[CLS]LG)해피바디워시630g[SEP]',
#  '[CLS]LG생활건강 에어워셔 황사방역용마스크 KF94[SEP]',
#  '[CLS]LG생활건강 종합세트 스타3호(11)[SEP]',
#  '[CLS]LG생활건강 죽염 오리지날진 치약 120g[SEP]',
#  '[CLS]LG생활건강 화장품[SEP]',
#  '[CLS]lg생활용품[SEP]',
#  '[CLS]LG생활용품 [SEP]',
#  '[CLS]LG화장품  [SEP]',
#  '[CLS]LOL 서프라이즈 키링 (젤리빈) 10g[SEP]',
#  '[CLS]LOTTE)가나밀크75G[SEP]',
#  '[CLS]MAIYANGTRADEHA ND BAG CO.,LTD 뿌까, 뿌까 피크닉 부직포가방(중)  x 1EA[SEP]',
#  '[CLS]MAY 칼라서류꽂이-네이비 560G[SEP]',
#  '[CLS]MX 의류[SEP]',
#  '[CLS]NB)구강청결제[SEP]',
#  '[CLS]NB)하루한장마스크팩(20입)[SEP]',
#  '[CLS]NEW 시크릿쥬쥬 립스틱 캔디 케이크 기획[SEP]',
#  '[CLS]NEW단팥도넛[SEP]',
#  '[CLS]NEW에어베이크드4번들120g[SEP]',
#  '[CLS]NK-LASSIC 여리수 땅콩블럭쵸콜렛 80G[SEP]',
#  '[CLS]ＯＰＰ테이프[SEP]',
#  '[CLS]p)부산어묵180g[SEP]',
#  '[CLS]PB)바프꿀물180ml[SEP]',
#  '[CLS]PP쇼핑백대[SEP]',
#  '[CLS]PP쇼핑백중[SEP]',
#  '[CLS]P보리쌀1kg[SEP]',
#  '[CLS]Q.L친환경녹즙신선초500G[SEP]',
#  '[CLS]R1193블링털모자-민트[SEP]',
#  '[CLS]SY된장육수 350g[SEP]',
#  '[CLS]SY오뎅육수 2kg(냉장)1봉지[SEP]',
#  '[CLS]T.S food 달인밀떡[SEP]',
#  '[CLS]tca후룻팝 오렌지팝(62ml) [SEP]',
#  '[CLS]The미식 장인라면 얼큰한맛 464g (116g*4봉)[SEP]',
#  '[CLS]TSUBUKI CO.,LTD.  Yoshikai 모치모치 타이야키 커스타드 85g[SEP]',
#  '[CLS]TSUBUKI CO.,LTD. Yoshikai 모치모치 타이야키 레드빈 85g[SEP]',
#  '[CLS]U/M반팔 티셔츠(남)[SEP]',
#  '[CLS]UCC)콜드브루커피375ML[SEP]',
#  '[CLS]Uhrenholt 무염버터 [SEP]',
#  '[CLS]XGT2201여성티셔츠[SEP]',
#  '[CLS]YH 고들빼기무침 1Kg[SEP]',
#  '[CLS]YH 숄더랙 400g[SEP]',
#  '[CLS]YH가시없는 임연수 100g[SEP]',
#  '[CLS]YH부채살스테이크 200g[SEP]',
#  '[CLS]YH삼겹살 400g[SEP]',
#  '[CLS]YH숯불직화불곱창 200g[SEP]',
#  '[CLS]YH황제갈비살 200g[SEP]',
#  '[CLS]YUMIbites 멘보샤 369g[SEP]',
#  '[CLS]가가짬뽕[SEP]',
#  '[CLS]가공선식/개[SEP]',
#  '[CLS]가공식품[SEP]',
#  '[CLS]가공식품 등[SEP]',
#  '[CLS]가구용품(수납용품,의자.책상 등)/개[SEP]',
#  '[CLS]가나초코아이스 160ml[SEP]',
#  '[CLS]가나초콜렛[SEP]',
#  '[CLS]가락엿(생강)/개[SEP]',
#  '[CLS]가래떡[SEP]',
#  '[CLS]가루다 마늘맛[SEP]',
#  '[CLS]가방[SEP]',
#  '[CLS]가스오부시(맛다랑어)[SEP]',
#  '[CLS]가슴속살텐더스틱 720G[SEP]',
#  '[CLS]가습기[SEP]',
#  '[CLS]가쓰오부시장국 360ML[SEP]',
#  '[CLS]가야)포도농장1.5L[SEP]',
#  '[CLS]가오리포 300G[SEP]',
#  '[CLS]가을)너진짜밤맛이구나[SEP]',
#  '[CLS]가을상의[SEP]',
#  '[CLS]가이아 곡물담은 선식 통곡물 발아현미 35g  x 10EA[SEP]',
#  '[CLS]가지[SEP]',
#  '[CLS]가지 10kg[SEP]',
#  '[CLS]가지(2입)[SEP]',
#  '[CLS]가지말랭이, 호박말랭이[SEP]',
#  '[CLS]각설탕[SEP]',
#  '[CLS]각티슈[SEP]',
#  '[CLS]간마늘 1kg[SEP]',
#  '[CLS]간이접이식테이블[SEP]',
#  '[CLS]간장[SEP]',
#  '[CLS]간장 1.8L[SEP]',
#  '[CLS]간장/개[SEP]',
#  '[CLS]간장담은숙성왕쪽갈비(1kg)[SEP]',
#  '[CLS]간장맛 센베[SEP]',
#  '[CLS]간장알마늘(냉장)4kg[SEP]',
#  '[CLS]간편모기장[SEP]',
#  "[CLS]간편식, 대용식 '밀키트/개'[SEP]",
#  '[CLS]간편야채/g[SEP]',
#  '[CLS]간편야채/kg[SEP]',
#  '[CLS]간편야채/개[SEP]',
#  '[CLS]갈떡[SEP]',
#  '[CLS]갈릭스틱브레드[SEP]',
#  '[CLS]갈릭스틱빵[SEP]',
#  '[CLS]갈릭크림 파스타 소스[SEP]',
#  '[CLS]갈릭햄치즈샌드위치[SEP]',
#  '[CLS]갈비살 [SEP]',
#  '[CLS]갈비찜[SEP]',
#  '[CLS]갈비탕[SEP]',
#  '[CLS]갈치류[SEP]',
#  '[CLS]감/개[SEP]',
#  '[CLS]감귤[SEP]',
#  '[CLS]감귤 5kg[SEP]',
#  '[CLS]감귤쥬스[SEP]',
#  '[CLS]감바스오일(2kg)냉동[SEP]',
#  '[CLS]감자[SEP]',
#  '[CLS]감자 10KG[SEP]',
#  '[CLS]감자 1kg[SEP]',
#  '[CLS]감자 20kg[SEP]',
#  '[CLS]감자 수제비[SEP]',
#  '[CLS]감자 수제비가루 240g[SEP]',
#  '[CLS]감자/kg[SEP]',
#  '[CLS]감자/개[SEP]',
#  '[CLS]감자국수 감자가루15% 1KG[SEP]',
#  '[CLS]감자국수 감자가루30% 900G[SEP]',
#  '[CLS]감자떡크로켓[SEP]',
#  '[CLS]감자분말[SEP]',
#  '[CLS]감자생칼국수450g[SEP]',
#  '[CLS]감자수제비(400g) 냉장[SEP]',
#  '[CLS]감자전믹스[SEP]',
#  '[CLS]감자칩[SEP]',
#  '[CLS]감자탕[SEP]',
#  '[CLS]감자탕(800g)[SEP]',
#  '[CLS]감자탕용 돼지등뼈 (국내산2KG)[SEP]',
#  '[CLS]감치미 다시다[SEP]',
#  '[CLS]감칠맛 미원 100g[SEP]',
#  '[CLS]갑오징어채[SEP]',
#  '[CLS]갓김치[SEP]',
#  '[CLS]강강술래 한돈양념불고기[SEP]',
#  '[CLS]강경 멸치액젓 10kg[SEP]',
#  '[CLS]강다니엘 1st full album "The Story" (플랫폼) [SEP]',
#  '[CLS]강다니엘 3rd MINI ALBUM YELLOW[SEP]',
#  '[CLS]강다니엘 앨범[SEP]',
#  '[CLS]강동퓨어푸드 구슬떡 1kg[SEP]',
#  '[CLS]강동퓨어푸드 잘크미쌀떡볶이 500G x 1EA[SEP]',
#  '[CLS]강동퓨어푸드 평양냉면[SEP]',
#  '[CLS]강릉초당두부 유기농콩순두부500G - VINYL[SEP]',
#  '[CLS]강릉초당두부 유기농헬로키티두부100G - PET CASE[SEP]',
#  '[CLS]강릉커피 블랙스틱 8T [SEP]',
#  '[CLS]강원균농 DMZ서리태 콩 1kg 1000G[SEP]',
#  '[CLS]강원도 화천 토마토 소스(400g)[SEP]',
#  '[CLS]강정 200G[SEP]',
#  '[CLS]강화섬쌀4kg[SEP]',
#  '[CLS]강황골드 카레 순한맛 80g[SEP]',
#  '[CLS]강황바몬드카레가루-순한맛100g[SEP]',
#  '[CLS]거림)아쌈밀크티P500ml[SEP]',
#  '[CLS]거품칫솔 5개입[SEP]',
#  '[CLS]건강곡물식빵[SEP]',
#  '[CLS]건강기능식품[SEP]',
#  '[CLS]건강보조식품[SEP]',
#  '[CLS]건강식품류[SEP]',
#  '[CLS]건강음료[SEP]',
#  '[CLS]건강음료/개[SEP]',
#  '[CLS]건강한재래된장1kg[SEP]',
#  '[CLS]건국우유 200ml[SEP]',
#  '[CLS]건멸치[SEP]',
#  '[CLS]건무화과[SEP]',
#  '[CLS]건양꿀복분자600g[SEP]',
#  '[CLS]건어물 [SEP]',
#  '[CLS]건어물종합[SEP]',
#  '[CLS]건전지[SEP]',
#  '[CLS]건조파블럭[SEP]',
#  '[CLS]건크랜베리[SEP]',
#  '[CLS]건표고버섯 70G[SEP]',
#  '[CLS]검은콩[SEP]',
#  '[CLS]검은콩 두유 고칼슘 베지밀 190ml[SEP]',
#  '[CLS]검은콩500g[SEP]',
#  '[CLS]검은콩베지밀[SEP]',
#  '[CLS]겉절이[SEP]',
#  '[CLS]겉절이 양념 2kg(냉장)[SEP]',
#  '[CLS]게맛살 1KG[SEP]',
#  '[CLS]겨울모자[SEP]',
#  '[CLS]견과류[SEP]',
#  '[CLS]견과류/kg[SEP]',
#  '[CLS]견과류/개[SEP]',
#  '[CLS]결명자차[SEP]',
#  '[CLS]경기미 10kg[SEP]',
#  '[CLS]경농) 대추방울토마토[SEP]',
#  '[CLS]경주빵[SEP]',
#  '[CLS]경추베게[SEP]',
#  '[CLS]계든든한초계국수[SEP]',
#  '[CLS]계란[SEP]',
#  '[CLS]계란 1판[SEP]',
#  '[CLS]계란 1판 30구 [SEP]',
#  '[CLS]계란 30ea[SEP]',
#  '[CLS]계란(30구)[SEP]',
#  '[CLS]계란/판[SEP]',
#  '[CLS]계란30입[SEP]',
#  '[CLS]계란30입(다온)[SEP]',
#  '[CLS]계란국수 218G[SEP]',
#  '[CLS]계란꼬치[SEP]',
#  '[CLS]계란지단[SEP]',
#  '[CLS]고구마[SEP]',
#  '[CLS]고구마 10kg[SEP]',
#  '[CLS]고구마(봉)[SEP]',
#  '[CLS]고구마/개[SEP]',
#  '[CLS]고구마-2KG[SEP]',
#  '[CLS]고구마당면500[SEP]',
#  '[CLS]고구마빵[SEP]',
#  '[CLS]고구마스틱 230G 1봉지[SEP]',
#  '[CLS]고구마줄기[SEP]',
#  '[CLS]고구마치즈돈가스[SEP]',
#  '[CLS]고기만두[SEP]',
#  '[CLS]고기산적 350G[SEP]',
#  '[CLS]고기손만두[SEP]',
#  '[CLS]고기순대[SEP]',
#  '[CLS]고기왕교자 1000g[SEP]',
#  '[CLS]고기짜조 1.4Kg[SEP]',
#  '[CLS]고기통교자[SEP]',
#  '[CLS]고등어[SEP]',
#  '[CLS]고등어 통조림[SEP]',
#  '[CLS]고등어/개[SEP]',
#  '[CLS]고등어구이[SEP]',
#  '[CLS]고등어조림 [SEP]',
#  '[CLS]고등어캔 400g\t[SEP]',
#  '[CLS]고등어통조림[SEP]',
#  '[CLS]고등어통조림 400g[SEP]',
#  '[CLS]고려 강낭콩 3000G[SEP]',
#  '[CLS]고려)한겨울광천도시락김16봉[SEP]',
#  '[CLS]고려은단 쏠라씨 복숭아 20정 40g [SEP]',
#  '[CLS]고려인삼홍삼진액[SEP]',
#  '[CLS]고로케(고수)[SEP]',
#  '[CLS]고르곤퐁듀소스2 (냉장)1kg[SEP]',
#  '[CLS]고메레시피 연탄불고기양념 140g[SEP]',
#  '[CLS]고무신[SEP]',
#  '[CLS]고무장갑 10개*1BOX[SEP]',
#  '[CLS]고사리 200g[SEP]',
#  '[CLS]고삼농협안성마춤푸드센터 횡성공근한우사골곰탕 600G[SEP]',
#  '[CLS]고소하게 한번만 짠 참기름 320ML[SEP]',
#  '[CLS]고소한 참깨된장 목살 샐러드 185g[SEP]',
#  '[CLS]고소한건빵 150G[SEP]',
#  '[CLS]고소한삼육두유 200ml[SEP]',
#  '[CLS]고소한참기름(병) 80ML[SEP]',
#  '[CLS]고추[SEP]',
#  '[CLS]고추(매운고추-봉)[SEP]',
#  '[CLS]고추/봉[SEP]',
#  '[CLS]고추가루[SEP]',
#  '[CLS]고추가루 1kg[SEP]',
#  '[CLS]고추가루 270G[SEP]',
#  '[CLS]고추부각 30G 1봉지[SEP]',
#  '[CLS]고추씨기름 160ml[SEP]',
#  '[CLS]고추장[SEP]',
#  '[CLS]고추장 (신송)  500g[SEP]',
#  '[CLS]고추장 500g[SEP]',
#  '[CLS]고추장/100g[SEP]',
#  '[CLS]고추장/개[SEP]',
#  '[CLS]고추장1kg[SEP]',
#  '[CLS]고추절임[SEP]',
#  '[CLS]고추지무침[SEP]',
#  '[CLS]고춧가루 1kg[SEP]',
#  '[CLS]고춧가루/g[SEP]',
#  '[CLS]고춧가루/kg[SEP]',
#  '[CLS]고춧가루/개[SEP]',
#  '[CLS]고춧잎[SEP]',
#  '[CLS]고향참쌀2kg[SEP]',
#  '[CLS]곤드레나물밥[SEP]',
#  '[CLS]곤약볶음 배불바(20G*20개입)[SEP]',
#  '[CLS]곤약비빔냉면[SEP]',
#  '[CLS]곤약소바면[SEP]',
#  '[CLS]곤약젤리 트로피컬[SEP]',
#  '[CLS]곤약즉석밥 귀리 150g[SEP]',
#  '[CLS]곤약쫀드기[SEP]',
#  '[CLS]골드 마요네스 300G[SEP]',
#  '[CLS]골드 마요네스 500g[SEP]',
#  '[CLS]골드고추맛기름1.8L[SEP]',
#  '[CLS]골드마요네스 800G[SEP]',
#  '[CLS]골드마요네즈300g[SEP]',
#  '[CLS]골든드랍 흑당밀크티 270ML  [SEP]',
#  '[CLS]곰곰 돌돌말이 대패삼겹살 750g*2팩(냉동)[SEP]',
#  '[CLS]곰곰 돌돌말이 대패삼겹살_냉동_1kg[SEP]',
#  '[CLS]곰곰 돌돌말이 무연골 대패 삼겹살_냉동_1kg[SEP]',
#  '[CLS]곰곰 돌돌말이 무연골 대패삼겹살 750g*2팩(냉동)[SEP]',
#  '[CLS]곰표 밀가루 2500g[SEP]',
#  '[CLS]곰표 중력 밀가루 1kg[SEP]',
#  '[CLS]곱슬이콩나물 10kg[SEP]',
#  '[CLS]곱슬이콩나물 4kg[SEP]',
#  '[CLS]곱창[국내산][SEP]',
#  '[CLS]곱창전골[SEP]',
#  '[CLS]공동모금회)성인용마스크[SEP]',
#  '[CLS]공심채[SEP]',
#  '[CLS]곶감[SEP]',
#  '[CLS]과일[SEP]',
#  '[CLS]과일 꾸러미[SEP]',
#  '[CLS]과일바구니세트3호(세트)[SEP]',
#  '[CLS]과일잼[SEP]',
#  '[CLS]과일채소류[SEP]',
#  '[CLS]과일푸딩[SEP]',
#  '[CLS]과일푸딩 퓨레[SEP]',
#  '[CLS]과일향 젤리 머쉬멜로우 110g[SEP]',
#  '[CLS]과자[SEP]',
#  '[CLS]과자 12000[SEP]',
#  '[CLS]과자/빵[SEP]',
#  '[CLS]과자4번들1묶음[SEP]',
#  '[CLS]과자류[SEP]',
#  '[CLS]과자류/빵[SEP]',
#  '[CLS]곽티슈[SEP]',
#  '[CLS]광동 비타500[SEP]',
#  '[CLS]광림상회 된장짜글이 200g[SEP]',
#  '[CLS]광수반코팅장갑[SEP]',
#  '[CLS]광주통일기업 유한공사 통일 아쌈 오리지날 밀크티 [SEP]',
#  '[CLS]광천 돌김자반[SEP]',
#  '[CLS]광천김[SEP]',
#  '[CLS]광천김 30G[SEP]',
#  '[CLS]광천김16단[SEP]',
#  '[CLS]광천올리브자반볶음[SEP]',
#  '[CLS]광천특산품 소문난 파래김[SEP]',
#  '[CLS]광천파래김[SEP]',
#  '[CLS]광천해저 파래김[23g][SEP]',
#  '[CLS]교자만두 1,350g[SEP]',
#  '[CLS]교자만두1000g[SEP]',
#  '[CLS]교촌 치킨맛스낵 신화맛 54g[SEP]',
#  '[CLS]교촌 치킨맛스낵 허니맛 54g[SEP]',
#  '[CLS]교촌오리지날[SEP]',
#  '[CLS]교촌-치킨맛스낵-신화 1봉지[SEP]',
#  '[CLS]구두[SEP]',
#  '[CLS]구미캔디 50G[SEP]',
#  '[CLS]구운 오징어다리[SEP]',
#  '[CLS]구운감자기획[SEP]',
#  '[CLS]구운감자양파맛124G[SEP]',
#  '[CLS]구운계란[SEP]',
#  '[CLS]구운계란 파인알구이(30구)[SEP]',
#  '[CLS]구운계란(30구)[SEP]',
#  '[CLS]구운란 20입[SEP]',
#  '[CLS]구운아몬드 90g[SEP]',
#  '[CLS]구운쪽갈비매운맛(350g)[SEP]',
#  '[CLS]구운찰바피자   120g[SEP]',
#  '[CLS]구워먹는치즈 80g[SEP]',
#  '[CLS]국내산 생크림이 풍부한 크림 스파게티소스[SEP]',
#  '[CLS]국내산유기농누룽지과자[SEP]',
#  '[CLS]국물닭발900g [SEP]',
#  '[CLS]국물용멸치[SEP]',
#  '[CLS]국산 다진생강 [SEP]',
#  '[CLS]국산 블루베리[SEP]',
#  '[CLS]국산 한돈 얇은 등심[SEP]',
#  '[CLS]국산민물어죽살[SEP]',
#  '[CLS]국산부침두부[SEP]',
#  '[CLS]국산쌀로 만든 우리쌀 떡국떡[SEP]',
#  '[CLS]국산찌개두부3kg[SEP]',
#  '[CLS]국산참기름광천김[SEP]',
#  '[CLS]국산참기름셋 1호[SEP]',
#  '[CLS]국산콩 콩국물[SEP]',
#  '[CLS]국수[SEP]',
#  '[CLS]국수/개[SEP]',
#  '[CLS]국제식품진천공장 돈목전지(300g±30g 보쌈용_수육용 5Kg/EA)[SEP]',
#  '[CLS]군계란[SEP]',
#  '[CLS]군만두/kg[SEP]',
#  '[CLS]군만두/개[SEP]',
#  '[CLS]굴진짬뽕 멀티(130g*4) (오뚜기)[SEP]',
#  '[CLS]굴진짬뽕멀티(130gX4)[SEP]',
#  '[CLS]굵은소금3kg[SEP]',
#  '[CLS]굿민국산콩두부150g*2[SEP]',
#  '[CLS]굿바이브스황사방역용마스크(KF94)(대형) 50개입[SEP]',
#  '[CLS]굿온가족유산균[SEP]',
#  '[CLS]굿키즈앤베베유산균[SEP]',
#  '[CLS]궁중 왕교자 468g[SEP]',
#  '[CLS]궁중팬22cm[SEP]',
#  '[CLS]귀리[SEP]',
#  '[CLS]귤/개[SEP]',
#  '[CLS]그대로카레(약간매운맛) 200G[SEP]',
#  '[CLS]그라비올라 퓨레 1kg*12병[SEP]',
#  '[CLS]그래놀라[SEP]',
#  '[CLS]그레이드 터치후레쉬 크린 린넨 본품[SEP]',
#  '[CLS]그레이스85G[SEP]',
#  '[CLS]그릇/개[SEP]',
#  '[CLS]그리스 땅콩바 30g[SEP]',
#  '[CLS]그리스 땅콩참깨바 30g[SEP]',
#  '[CLS]그릭요거트 500[SEP]',
#  '[CLS]그릭요거트 500g[SEP]',
#  '[CLS]그린락스2L[SEP]',
#  '[CLS]그린물티슈 100매[SEP]',
#  '[CLS]그립톡 백색[SEP]',
#  '[CLS]근대[SEP]',
#  '[CLS]글라이드 바베큐통닭[SEP]',
#  '[CLS]글라이드메가이뮨365(본품)[SEP]',
#  '[CLS]글라이드메가이뮨365(증정품)[SEP]',
#  '[CLS]글로리아비스코뭉크참깨&밀크비스킷스틱45g[SEP]',
#  '[CLS]글로리아비스코뭉크치즈&치브비스킷스틱45g[SEP]',
#  '[CLS]금성 마카로니 과자[SEP]',
#  '[CLS]금천 조르단치약칫솔세트[SEP]',
#  '[CLS]급식(국)/kg[SEP]',
#  '[CLS]급식(반찬) 300g[SEP]',
#  '[CLS]급식(반찬) 500g[SEP]',
#  '[CLS]급식(반찬)/kg[SEP]',
#  '[CLS]급식(반찬류)[SEP]',
#  '[CLS]급식(반찬류)/kg[SEP]',
#  '[CLS]급식(밥) [SEP]',
#  '[CLS]급식(밥) 300g[SEP]',
#  '[CLS]급식(밥) 500g[SEP]',
#  '[CLS]급식(밥)/kg[SEP]',
#  '[CLS]기)머쉬멜로우[SEP]',
#  '[CLS]기다려온 헬씨메이커 20[SEP]',
#  '[CLS]기린 미니컵케익145g[SEP]',
#  '[CLS]기린 왕만쥬[SEP]',
#  '[CLS]기린 한입만쥬[SEP]',
#  '[CLS]기린)통밀식빵3,300류[SEP]',
#  '[CLS]기부용 순살치킨가라아게[SEP]',
#  '[CLS]기부용 치즈[SEP]',
#  '[CLS]기억미디움월간 길드그레이[SEP]',
#  '[CLS]기억미디움월간 다크로즈[SEP]',
#  '[CLS]기억미디움월간 샤베트[SEP]',
#  '[CLS]기억미디움월간 코튼라일락[SEP]',
#  '[CLS]기억미디움월간 클로버민트[SEP]',
#  '[CLS]기억미디움월간_다크 로즈[SEP]',
#  '[CLS]기억스몰 다크로즈[SEP]',
#  '[CLS]기저귀[SEP]',
#  '[CLS]기정떡(1상자)[SEP]',
#  '[CLS]기타  떡/kg[SEP]',
#  '[CLS]기타 / 장아찌류[SEP]',
#  '[CLS]기타 /생선류[SEP]',
#  '[CLS]기타 가루다코팅땅콩(마늘맛)200G - VINYL[SEP]',
#  '[CLS]기타 간식류[SEP]',
#  '[CLS]기타 간식류/개 [SEP]',
#  '[CLS]기타 간식류/박스[SEP]',
#  '[CLS]기타 간장/g[SEP]',
#  '[CLS]기타 간장/개[SEP]',
#  '[CLS]기타 갈치,고등어,삼치/개[SEP]',
#  '[CLS]기타 감/개[SEP]',
#  '[CLS]기타 감자튀김[SEP]',
#  '[CLS]기타 건강용품/개[SEP]',
#  '[CLS]기타 건강음료/개[SEP]',
#  '[CLS]기타 건과류,견과류/개[SEP]',
#  '[CLS]기타 계란/개[SEP]',
#  '[CLS]기타 고기류/kg[SEP]',
#  '[CLS]기타 고기류/개[SEP]',
#  '[CLS]기타 고추장/개[SEP]',
#  '[CLS]기타 과일 / 박스[SEP]',
#  '[CLS]기타 과일류/100g[SEP]',
#  '[CLS]기타 과일류/kg[SEP]',
#  '[CLS]기타 과일류/개[SEP]',
#  '[CLS]기타 과일류/박스[SEP]',
#  '[CLS]기타 과일음료/개[SEP]',
#  '[CLS]기타 과자류/개[SEP]',
#  '[CLS]기타 국수,당면/개[SEP]',
#  '[CLS]기타 급식(밥)/kg[SEP]',
#  '[CLS]기타 급식류/kg[SEP]',
#  '[CLS]기타 김/100g[SEP]',
#  '[CLS]기타 김/g[SEP]',
#  '[CLS]기타 김/개[SEP]',
#  '[CLS]기타 김말이/2kg[SEP]',
#  '[CLS]기타 나물류,버섯류/개[SEP]',
#  '[CLS]기타 냉동식품류/kg[SEP]',
#  '[CLS]기타 냉동식품류/개[SEP]',
#  '[CLS]기타 냉장식품류/100g[SEP]',
#  '[CLS]기타 냉장식품류/개[SEP]',
#  '[CLS]기타 다시다/개[SEP]',
#  '[CLS]기타 닭/g[SEP]',
#  '[CLS]기타 닭/kg[SEP]',
#  '[CLS]기타 닭/개[SEP]',
#  '[CLS]기타 더덕[SEP]',
#  '[CLS]기타 도라지[SEP]',
#  '[CLS]기타 도시락/개[SEP]',
#  '[CLS]기타 도시락류[SEP]',
#  '[CLS]기타 돼지고기/100g[SEP]',
#  '[CLS]기타 돼지고기/kg[SEP]',
#  '[CLS]기타 돼지고기/개[SEP]',
#  '[CLS]기타 된장/개[SEP]',
#  '[CLS]기타 두부/g[SEP]',
#  '[CLS]기타 두부/kg[SEP]',
#  '[CLS]기타 두부/개[SEP]',
#  '[CLS]기타 두유[SEP]',
#  '[CLS]기타 두유/개[SEP]',
#  '[CLS]기타 디즈니푸우솜사탕버블껌25G - VINYL[SEP]',
#  '[CLS]기타 딸기/kg[SEP]',
#  '[CLS]기타 떡[SEP]',
#  '[CLS]기타 떡 /g[SEP]',
#  '[CLS]기타 떡갈비,완자/kg[SEP]',
#  '[CLS]기타 떡갈비,완자/개[SEP]',
#  '[CLS]기타 떡국떡[SEP]',
#  '[CLS]기타 떡류/100g[SEP]',
#  '[CLS]기타 떡류/kg[SEP]',
#  '[CLS]기타 떡류/개[SEP]',
#  '[CLS]기타 라면[SEP]',
#  '[CLS]기타 마가린/개[SEP]',
#  '[CLS]기타 만두[SEP]',
#  '[CLS]기타 망고,열대과일/개[SEP]',
#  '[CLS]기타 문구용품/개[SEP]',
#  '[CLS]기타 미용용품/개[SEP]',
#  '[CLS]기타 밑반찬[SEP]',
#  '[CLS]기타 배/개[SEP]',
#  '[CLS]기타 배추,무/kg[SEP]',
#  '[CLS]기타 버터/개[SEP]',
#  '[CLS]기타 볶음밥[SEP]',
#  '[CLS]기타 봉지라면/개[SEP]',
#  '[CLS]기타 부식류 / 박스[SEP]',
#  '[CLS]기타 부식류(냉동)/박스[SEP]',
#  '[CLS]기타 부식류/100g[SEP]',
#  '[CLS]기타 부식류/g[SEP]',
#  '[CLS]기타 부식류/kg[SEP]',
#  '[CLS]기타 부식류/개[SEP]',
#  '[CLS]기타 비누/개[SEP]',
#  '[CLS]기타 빵[SEP]',
#  '[CLS]기타 사탕류/개[SEP]',
#  '[CLS]기타 삼각김밥[SEP]',
#  '[CLS]기타 새우/kg[SEP]',
#  '[CLS]기타 샐러드,간편야채/개[SEP]',
#  '[CLS]기타 생선류 /개[SEP]',
#  '[CLS]기타 생활용품/개[SEP]',
#  '[CLS]기타 샴푸,린스,트리트먼트/개[SEP]',
#  '[CLS]기타 세탁세제/개[SEP]',
#  '[CLS]기타 소스류/g[SEP]',
#  '[CLS]기타 소스류/kg[SEP]',
#  '[CLS]기타 소스류/개[SEP]',
#  '[CLS]기타 소시지/100g[SEP]',
#  '[CLS]기타 소시지/g[SEP]',
#  '[CLS]기타 소시지/개[SEP]',
#  '[CLS]기타 수박/개[SEP]',
#  '[CLS]기타 수산물(냉동)[SEP]',
#  '[CLS]기타 수입소고기/개[SEP]',
#  '[CLS]기타 순대[SEP]',
#  '[CLS]기타 스낵/개[SEP]',
#  '[CLS]기타 스파게티/개[SEP]',
#  '[CLS]기타 시리얼 /개[SEP]',
#  '[CLS]기타 시즈닝소스250G - VINYL[SEP]',
#  '[CLS]기타 식료품[SEP]',
#  '[CLS]기타 식재료[SEP]',
#  '[CLS]기타 식품양념[SEP]',
#  '[CLS]기타 쌀[SEP]',
#  '[CLS]기타 쌀 / kg[SEP]',
#  '[CLS]기타 쌀1[SEP]',
#  '[CLS]기타 쌀국수소스육수용50G - BOTTLE[SEP]',
#  '[CLS]기타 아이스크림/개[SEP]',
#  '[CLS]기타 야채[SEP]',
#  '[CLS]기타 양념장[SEP]',
#  '[CLS]기타 어묵[SEP]',
#  '[CLS]기타 어묵/개[SEP]',
#  '[CLS]기타 에이미키친시금치피자397G - PAPER BOX[SEP]',
#  '[CLS]기타 오뚜기 식재료[SEP]',
#  '[CLS]기타 오티티오베커드빈스400G - VINYL[SEP]',
#  '[CLS]기타 욕실용품/개[SEP]',
#  '[CLS]기타 우동/개[SEP]',
#  '[CLS]기타 육수[SEP]',
#  '[CLS]기타 음료/개[SEP]',
#  '[CLS]기타 음료류/개[SEP]',
#  '[CLS]기타 음료류/박스[SEP]',
#  '[CLS]기타 의류[SEP]',
#  '[CLS]기타 의류 1[SEP]',
#  '[CLS]기타 이온음료/개[SEP]',
#  '[CLS]기타 이유식/개[SEP]',
#  '[CLS]기타 잡화용품/개[SEP]',
#  '[CLS]기타 장류/개 [SEP]',
#  '[CLS]기타 잼/개[SEP]',
#  '[CLS]기타 적된장1KG - VINYL[SEP]',
#  '[CLS]기타 전통차,홍차,한차/개[SEP]',
#  '[CLS]기타 젤리류[SEP]',
#  '[CLS]기타 주먹밥/개[SEP]',
#  '[CLS]기타 주방용품/개[SEP]',
#  '[CLS]기타 주식류/100g[SEP]',
#  '[CLS]기타 주식류/개[SEP]',
#  '[CLS]기타 즉석식품류/개[SEP]',
#  '[CLS]기타 차음료/개[SEP]',
#  '[CLS]기타 채소[SEP]',
#  '[CLS]기타 채소류[SEP]',
#  '[CLS]기타 채소류/100g[SEP]',
#  '[CLS]기타 채소류/kg[SEP]',
#  '[CLS]기타 채소류/개[SEP]',
#  '[CLS]기타 청과[SEP]',
#  '[CLS]기타 청소용품/개[SEP]',
#  '[CLS]기타 초코과자/개[SEP]',
#  '[CLS]기타 초콜릿/개[SEP]',
#  '[CLS]기타 치즈/개[SEP]',
#  '[CLS]기타 치킨,돈가스/100g[SEP]',
#  '[CLS]기타 치킨,돈가스/kg[SEP]',
#  '[CLS]기타 캔류[SEP]',
#  '[CLS]기타 커피/개[SEP]',
#  '[CLS]기타 커피재료/kg[SEP]',
#  '[CLS]기타 케이크/개[SEP]',
#  '[CLS]기타 코코아/개[SEP]',
#  '[CLS]기타 콩나물/100g[SEP]',
#  '[CLS]기타 콩나물/개[SEP]',
#  '[CLS]기타 콩물[SEP]',
#  '[CLS]기타 쿠키/개[SEP]',
#  '[CLS]기타 크래커/개[SEP]',
#  '[CLS]기타 탄산수340ML*24 - BOTTLE[SEP]',
#  '[CLS]기타 탄산음료/개[SEP]',
#  '[CLS]기타 토마토/개[SEP]',
#  '[CLS]기타 통조림/개[SEP]',
#  '[CLS]기타 튀김,부침가루/개[SEP]',
#  '[CLS]기타 튀김류[SEP]',
#  '[CLS]기타 트리플섹700ML - BOTTLE[SEP]',
#  '[CLS]기타 포도/개[SEP]',
#  '[CLS]기타 푸실리500G - VINYL[SEP]',
#  '[CLS]기타 필라델피아치즈케익794G - PAPER BOX[SEP]',
#  '[CLS]기타 한과,웨하스/개[SEP]',
#  '[CLS]기타 햄/개[SEP]',
#  '[CLS]기타 화장지/개[SEP]',
#  '[CLS]기타 화장품/개[SEP]',
#  '[CLS]기타/개(백설)[SEP]',
#  ...]

# %%
# Out:
# Downloading model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# C:\Users\Samsung\anaconda3\Lib\site-packages\transformers\optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# no GPU available
# ------------------------------
# Epoch : 1 in 4 / Step : 0

# %%
args
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 args.raw_data
#
# AttributeError: 'tuple' object has no attribute 'raw_data'

# %% [markdown]
# # 참고
#
# https://noanomal.tistory.com/entry/bert%EB%A5%BC-%ED%99%9C%EC%9A%A9%ED%95%9C-%EB%AC%B8%EC%9E%A5-%EB%B6%84%EB%A5%98bert-classification-BertForSequenceClassification
