# %%
import os
import random
import time
import datetime
import torch
import argparse

import pandas as pd
import numpy as np

# %%
from transformers import BertTokenizer, BertForSequenceClassification, AdamW, get_linear_schedule_with_warmup, BertConfig

from tensorflow.keras.preprocessing.sequence import pad_sequences
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# data Loading 
### dataframe의 col 이름이 document, label 이어야 한다. 
def load_data(args):
    temp = pd.read_csv(args.raw_data, sep="\t",encoding='cp949')
    temp = temp
    document = temp.document.tolist()
    labels = temp.label.tolist()
    return document, labels
# Marking 앞단 끝단에 
def add_special_token(document):
    added = ["[CLS]" + str(sentence) + "[SEP]" for sentence in document]
    return added
# Tokenization
def tokenization(document, mode="huggingface"):
    if mode == "huggingface":
        tokenizer = BertTokenizer.from_pretrained(
                'bert-base-multilingual-cased', 
                do_lower_case=False,
                )
        tokenized = [tokenizer.tokenize(sentence) for sentence in document]
        ids = [tokenizer.convert_tokens_to_ids(sentence) for sentence in tokenized]
        return ids
# Padding = 길이 일치
def padding(ids, args):
    ids = pad_sequences(ids, maxlen=args.max_len, dtype="long", truncating='post', padding='post')
    return ids

def attention_mask(ids):
    masks = []
    for id in ids:
        mask = [float(i>0) for i in id]
        masks.append(mask)
    return masks

def preprocess(args):
    document, labels = load_data(args)
    document = add_special_token(document)
    ids = tokenization(document)
    ids = padding(ids, args)
    masks = attention_mask(ids)
    del document
    return ids, masks, labels

def train_test_data_split(ids, masks, labels):
    train_ids, test_ids, train_labels, test_labels = train_test_split(ids, labels
                                                                      , random_state=42, test_size=0.1)
    train_masks, test_masks, _, _ = train_test_split(masks, ids, random_state=42, test_size=0.1)
    return train_ids, train_masks, train_labels, test_ids, test_masks, test_labels

def build_dataloader(ids, masks, label, args):
    dataloader = TensorDataset(torch.tensor(ids), torch.tensor(masks), torch.tensor(label))
    dataloader = DataLoader(dataloader, sampler=RandomSampler(dataloader), batch_size=args.batch_size)
    return dataloader
##############################################################################

def build_model(args):
    model = BertForSequenceClassification.from_pretrained("bert-base-multilingual-cased", num_labels=args.num_labels)
    if torch.cuda.is_available():
        device = torch.device("cuda")
        print(f"{torch.cuda.get_device_name(0)} available")
        model = model.cuda()
    else:
        device = torch.device("cpu")
        print("no GPU available")
        model = model
    return model, device

def test(test_dataloader, model, device):
    model.eval()
    total_accuracy = 0
    for batch in test_dataloader:
        batch = tuple(index.to(device) for index in batch)
        ids, masks, labels = batch
        with torch.no_grad():
            outputs = model(ids, token_type_ids=None, attention_mask=masks)
        pred = [torch.argmax(logit).cpu().detach().item() for logit in outputs.logits]
        true = [label for label in labels.cpu().numpy()]
        accuracy = accuracy_score(true, pred)
        total_accuracy += accuracy
    avg_accuracy = total_accuracy/len(test_dataloader)
    print(f"test AVG accuracy : {avg_accuracy: .4f}")
    return avg_accuracy

def train(train_dataloader, test_dataloader, args):
    model, device = build_model(args)
    
    # 옵티마이저 정의 
    optimizer = AdamW(model.parameters(), lr=2e-5, eps=1e-8)
    
    # learning rate decay
    scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=len(train_dataloader)*args.epochs)
    
    # 시드 고정
    random.seed(args.seed_val)
    np.random.seed(args.seed_val)
    torch.manual_seed(args.seed_val)
    torch.cuda.manual_seed_all(args.seed_val)
    

    
    # 그레디언트 초기화
    model.zero_grad()
    for epoch in range(0, args.epochs):
        # 훈련모드 
        model.train()
        
        # 로스와 정확도 초기화
        total_loss, total_accuracy = 0, 0
        print("-"*30)
        for step, batch in enumerate(train_dataloader):
            if step % 500 == 0 :
                print(f"Epoch : {epoch+1} in {args.epochs} / Step : {step}")

            # 배치 선정
            batch = tuple(index.to(device) for index in batch)
            ids, masks, labels, = batch

            # forward
            outputs = model(ids, token_type_ids=None, attention_mask=masks, labels=labels)
            
            # loss 도출
            loss = outputs.loss
            total_loss += loss.item()

            # 정확도 도출
            pred = [torch.argmax(logit).cpu().detach().item() for logit in outputs.logits]
            true = [label for label in labels.cpu().numpy()]
            accuracy = accuracy_score(true, pred)
            total_accuracy += accuracy
            
            # 그레디언트 연산
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            
            # 파라미터 업데이트
            optimizer.step()
            
            # 러닝레이트 최적화
            scheduler.step()
            
            # 그레디언트 초기화
            model.zero_grad()
            
        # epoch 당 loss 와 정확도 계산
        avg_loss = total_loss / len(train_dataloader)
        avg_accuracy = total_accuracy/len(train_dataloader)
        print(f" {epoch+1} Epoch Average train loss :  {avg_loss}")
        print(f" {epoch+1} Epoch Average train accuracy :  {avg_accuracy}")
        
        # test 수행
        acc = test(test_dataloader, model, device)
        
        # 모델 저장
        os.makedirs("results", exist_ok=True)
        #f = os.path.join("results", f'epoch_{epoch+1}_evalAcc_{acc*100:.0f}.pth')
        f = args.save_data + "\\" + "results_" + f'epoch_{epoch+1}_evalAcc_{acc*100:.0f}.pth'
        if epoch % 5 ==0:
            torch.save(model.state_dict(), f)
            print('Saved checkpoint:', f)

def run(args):
    ids, masks, labels = preprocess(args)
    train_ids, train_masks, train_labels, test_ids, test_masks, test_labels = train_test_data_split(ids, masks, labels)
    train_dataloader = build_dataloader(train_ids, train_masks, train_labels, args)
    test_dataloader = build_dataloader(test_ids, test_masks, test_labels, args)
    train(train_dataloader, test_dataloader, args)

# %%
load_path = r"C:\Users\USER\Desktop\All\Project\23_VRP\Data\경기\version_2\{}"
save_path = r"C:\Users\USER\Desktop\All\Project\23_VRP\Classification\model"

# %%
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
if __name__ == "__main__":
    parser = argparse.ArgumentParser()

    parser.add_argument("-raw_data", default=load_path.format("dataset_1.txt"))
    parser.add_argument("-save_data", default=save_path)
    
    parser.add_argument("-max_len", default=32, type=int)
    parser.add_argument("-batch_size", default=128, type=int)
    parser.add_argument("-num_labels", default=21, type=int)
    parser.add_argument("-epochs", default=600, type=int)
    parser.add_argument("-seed_val", default=42, type=int)

    #args = parser.parse_args()
    args,_ = parser.parse_known_args()
    run(args)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# NVIDIA GeForce RTX 4070 available
# C:\Users\USER\anaconda3\Lib\site-packages\transformers\optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ------------------------------
# Epoch : 1 in 600 / Step : 0
#  1 Epoch Average train loss :  2.548988426053846
#  1 Epoch Average train accuracy :  0.24731749412455936
# test AVG accuracy :  0.30
# Saved checkpoint: C:\Users\USER\Desktop\All\Project\23_VRP\Classification\model\results_epoch_1_evalAcc_30.pth
# ------------------------------
# Epoch : 2 in 600 / Step : 0
#  2 Epoch Average train loss :  2.113664443428452
#  2 Epoch Average train accuracy :  0.37591069330199767
# test AVG accuracy :  0.48
# ------------------------------
# Epoch : 3 in 600 / Step : 0
#  3 Epoch Average train loss :  1.691626890285595
#  3 Epoch Average train accuracy :  0.5499045240893067
# test AVG accuracy :  0.59
# ------------------------------
# Epoch : 4 in 600 / Step : 0
#  4 Epoch Average train loss :  1.3641817247545398
#  4 Epoch Average train accuracy :  0.6401164071680376
# test AVG accuracy :  0.64
# ------------------------------
# Epoch : 5 in 600 / Step : 0
#  5 Epoch Average train loss :  1.1288203129897247
#  5 Epoch Average train accuracy :  0.7144168625146886
# test AVG accuracy :  0.68
# ------------------------------
# Epoch : 6 in 600 / Step : 0
#  6 Epoch Average train loss :  0.9454361667504182
#  6 Epoch Average train accuracy :  0.7669965481786134
# test AVG accuracy :  0.72
# ------------------------------
# Epoch : 7 in 600 / Step : 0
#  7 Epoch Average train loss :  0.7942351263922613
#  7 Epoch Average train accuracy :  0.8005251175088132
# test AVG accuracy :  0.75
# ------------------------------
# Epoch : 8 in 600 / Step : 0
#  8 Epoch Average train loss :  0.6862820483542778
#  8 Epoch Average train accuracy :  0.8312132784958872
# test AVG accuracy :  0.75
# ------------------------------
# Epoch : 9 in 600 / Step : 0
#  9 Epoch Average train loss :  0.5959029447388005
#  9 Epoch Average train accuracy :  0.852777981786134
# test AVG accuracy :  0.76
# ------------------------------
# Epoch : 10 in 600 / Step : 0
#  10 Epoch Average train loss :  0.5211104533156833
#  10 Epoch Average train accuracy :  0.8716858842538191
# test AVG accuracy :  0.76
# ------------------------------
# Epoch : 11 in 600 / Step : 0
#  11 Epoch Average train loss :  0.4418529078767106
#  11 Epoch Average train accuracy :  0.8938803613396005
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 12 in 600 / Step : 0
#  12 Epoch Average train loss :  0.38548823868906174
#  12 Epoch Average train accuracy :  0.9046489424206815
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 13 in 600 / Step : 0
#  13 Epoch Average train loss :  0.34241705488514257
#  13 Epoch Average train accuracy :  0.9169231051703879
# test AVG accuracy :  0.77
# ------------------------------
# Epoch : 14 in 600 / Step : 0
#  14 Epoch Average train loss :  0.30786077637930176
#  14 Epoch Average train accuracy :  0.926444991186839
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 15 in 600 / Step : 0
#  15 Epoch Average train loss :  0.2881854506763252
#  15 Epoch Average train accuracy :  0.9316319036427733
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 16 in 600 / Step : 0
#  16 Epoch Average train loss :  0.24058253257661252
#  16 Epoch Average train accuracy :  0.9413686104582845
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 17 in 600 / Step : 0
#  17 Epoch Average train loss :  0.2259218370592272
#  17 Epoch Average train accuracy :  0.9422132050528791
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 18 in 600 / Step : 0
#  18 Epoch Average train loss :  0.20934562707269513
#  18 Epoch Average train accuracy :  0.946436178025852
# test AVG accuracy :  0.74
# ------------------------------
# Epoch : 19 in 600 / Step : 0
#  19 Epoch Average train loss :  0.20166496791549632
#  19 Epoch Average train accuracy :  0.9481731051703879
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 20 in 600 / Step : 0
#  20 Epoch Average train loss :  0.1734955594749064
#  20 Epoch Average train accuracy :  0.9584955199764983
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 21 in 600 / Step : 0
#  21 Epoch Average train loss :  0.1530980451686962
#  21 Epoch Average train accuracy :  0.9608420240893067
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 22 in 600 / Step : 0
#  22 Epoch Average train loss :  0.15559261312355865
#  22 Epoch Average train accuracy :  0.9579575499412456
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 23 in 600 / Step : 0
#  23 Epoch Average train loss :  0.15095123527823268
#  23 Epoch Average train accuracy :  0.9600212984723855
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 24 in 600 / Step : 0
#  24 Epoch Average train loss :  0.1408710382073312
#  24 Epoch Average train accuracy :  0.9653000146886017
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 25 in 600 / Step : 0
#  25 Epoch Average train loss :  0.13483720091549126
#  25 Epoch Average train accuracy :  0.9642681404230318
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 26 in 600 / Step : 0
#  26 Epoch Average train loss :  0.12812287964530894
#  26 Epoch Average train accuracy :  0.9663796269095183
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 27 in 600 / Step : 0
#  27 Epoch Average train loss :  0.12493633186897717
#  27 Epoch Average train accuracy :  0.9661446092831962
# test AVG accuracy :  0.77
# ------------------------------
# Epoch : 28 in 600 / Step : 0
#  28 Epoch Average train loss :  0.12005698731219447
#  28 Epoch Average train accuracy :  0.9686545240893067
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 29 in 600 / Step : 0
#  29 Epoch Average train loss :  0.1177095754726513
#  29 Epoch Average train accuracy :  0.9671526145710929
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 30 in 600 / Step : 0
#  30 Epoch Average train loss :  0.11049884718817633
#  30 Epoch Average train accuracy :  0.969945284958872
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 31 in 600 / Step : 0
#  31 Epoch Average train loss :  0.10671079883704314
#  31 Epoch Average train accuracy :  0.9696863983548767
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 32 in 600 / Step : 0
#  32 Epoch Average train loss :  0.10581209555872388
#  32 Epoch Average train accuracy :  0.9726663484136311
# test AVG accuracy :  0.76
# ------------------------------
# Epoch : 33 in 600 / Step : 0
#  33 Epoch Average train loss :  0.10277634667786392
#  33 Epoch Average train accuracy :  0.9711883078730905
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 34 in 600 / Step : 0
#  34 Epoch Average train loss :  0.09828609051937992
#  34 Epoch Average train accuracy :  0.9724790687426558
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 35 in 600 / Step : 0
#  35 Epoch Average train loss :  0.09848615305649268
#  35 Epoch Average train accuracy :  0.9712121768507639
# test AVG accuracy :  0.83
# ------------------------------
# Epoch : 36 in 600 / Step : 0
#  36 Epoch Average train loss :  0.09425863193197025
#  36 Epoch Average train accuracy :  0.972502937720329
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 37 in 600 / Step : 0
#  37 Epoch Average train loss :  0.08781695282841856
#  37 Epoch Average train accuracy :  0.973534811985899
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 38 in 600 / Step : 0
#  38 Epoch Average train loss :  0.09790614937004205
#  38 Epoch Average train accuracy :  0.9716106051703879
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 39 in 600 / Step : 0
#  39 Epoch Average train loss :  0.09671288044066043
#  39 Epoch Average train accuracy :  0.9720090334900118
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 40 in 600 / Step : 0
#  40 Epoch Average train loss :  0.09375844352148674
#  40 Epoch Average train accuracy :  0.9725268066980024
# test AVG accuracy :  0.83
# ------------------------------
# Epoch : 41 in 600 / Step : 0
#  41 Epoch Average train loss :  0.09551056887249688
#  41 Epoch Average train accuracy :  0.9712360458284371
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 42 in 600 / Step : 0
#  42 Epoch Average train loss :  0.09789787137226479
#  42 Epoch Average train accuracy :  0.9711883078730905
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 43 in 600 / Step : 0
#  43 Epoch Average train loss :  0.09099169551218683
#  43 Epoch Average train accuracy :  0.9734870740305523
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 44 in 600 / Step : 0
#  44 Epoch Average train loss :  0.09205344465334674
#  44 Epoch Average train accuracy :  0.9728774970622798
# test AVG accuracy :  0.83
# ------------------------------
# Epoch : 45 in 600 / Step : 0
#  45 Epoch Average train loss :  0.08473426907801547
#  45 Epoch Average train accuracy :  0.9760685957696827
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 46 in 600 / Step : 0
#  46 Epoch Average train loss :  0.08445889804814313
#  46 Epoch Average train accuracy :  0.973534811985899
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 47 in 600 / Step : 0
#  47 Epoch Average train loss :  0.07908891843682206
#  47 Epoch Average train accuracy :  0.9754590188014102
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 48 in 600 / Step : 0
#  48 Epoch Average train loss :  0.07985394790365889
#  48 Epoch Average train accuracy :  0.9769131903642774
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 49 in 600 / Step : 0
#  49 Epoch Average train loss :  0.08831949506861132
#  49 Epoch Average train accuracy :  0.9717501468860166
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 50 in 600 / Step : 0
#  50 Epoch Average train loss :  0.09157912808193548
#  50 Epoch Average train accuracy :  0.9733236633372503
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 51 in 600 / Step : 0
#  51 Epoch Average train loss :  0.07979507933093889
#  51 Epoch Average train accuracy :  0.9750605904817862
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 52 in 600 / Step : 0
#  52 Epoch Average train loss :  0.08016872758398184
#  52 Epoch Average train accuracy :  0.9756224294947121
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 53 in 600 / Step : 0
#  53 Epoch Average train loss :  0.08136293724984736
#  53 Epoch Average train accuracy :  0.9756701674500587
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 54 in 600 / Step : 0
#  54 Epoch Average train loss :  0.08528422789547492
#  54 Epoch Average train accuracy :  0.9743555376028202
# test AVG accuracy :  0.77
# ------------------------------
# Epoch : 55 in 600 / Step : 0
#  55 Epoch Average train loss :  0.08652458395305518
#  55 Epoch Average train accuracy :  0.9740287162162162
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 56 in 600 / Step : 0
#  56 Epoch Average train loss :  0.07269023212830762
#  56 Epoch Average train accuracy :  0.9769370593419506
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 57 in 600 / Step : 0
#  57 Epoch Average train loss :  0.08172171094731705
#  57 Epoch Average train accuracy :  0.9754828877790834
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 58 in 600 / Step : 0
#  58 Epoch Average train loss :  0.08097286884849136
#  58 Epoch Average train accuracy :  0.9739571092831962
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 59 in 600 / Step : 0
#  59 Epoch Average train loss :  0.08039957924267731
#  59 Epoch Average train accuracy :  0.9746382931844888
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 60 in 600 / Step : 0
#  60 Epoch Average train loss :  0.07474436384399195
#  60 Epoch Average train accuracy :  0.9758813160987074
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 61 in 600 / Step : 0
#  61 Epoch Average train loss :  0.08937138317756958
#  61 Epoch Average train accuracy :  0.9731602526439483
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 62 in 600 / Step : 0
#  62 Epoch Average train loss :  0.07437550047462857
#  62 Epoch Average train accuracy :  0.9760924647473561
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 63 in 600 / Step : 0
#  63 Epoch Average train loss :  0.07550124698192687
#  63 Epoch Average train accuracy :  0.9767259106933021
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 64 in 600 / Step : 0
#  64 Epoch Average train loss :  0.08068769525837254
#  64 Epoch Average train accuracy :  0.9752956081081081
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 65 in 600 / Step : 0
#  65 Epoch Average train loss :  0.07349805091193097
#  65 Epoch Average train accuracy :  0.9760685957696827
# test AVG accuracy :  0.77
# ------------------------------
# Epoch : 66 in 600 / Step : 0
#  66 Epoch Average train loss :  0.07436950338652006
#  66 Epoch Average train accuracy :  0.9765147620446534
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 67 in 600 / Step : 0
#  67 Epoch Average train loss :  0.07277068162865534
#  67 Epoch Average train accuracy :  0.9755746915393655
# test AVG accuracy :  0.84
# ------------------------------
# Epoch : 68 in 600 / Step : 0
#  68 Epoch Average train loss :  0.07514740996113098
#  68 Epoch Average train accuracy :  0.9744271445358402
# test AVG accuracy :  0.83
# ------------------------------
# Epoch : 69 in 600 / Step : 0
#  69 Epoch Average train loss :  0.07505209462062733
#  69 Epoch Average train accuracy :  0.9753635428907169
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 70 in 600 / Step : 0
#  70 Epoch Average train loss :  0.07481086014996509
#  70 Epoch Average train accuracy :  0.9756940364277321
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 71 in 600 / Step : 0
#  71 Epoch Average train loss :  0.0752568586502929
#  71 Epoch Average train accuracy :  0.9752478701527615
# test AVG accuracy :  0.74
# ------------------------------
# Epoch : 72 in 600 / Step : 0
#  72 Epoch Average train loss :  0.08366509355806015
#  72 Epoch Average train accuracy :  0.974096650998825
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 73 in 600 / Step : 0
#  73 Epoch Average train loss :  0.07596354873699916
#  73 Epoch Average train accuracy :  0.9764908930669801
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 74 in 600 / Step : 0
#  74 Epoch Average train loss :  0.07338969835797576
#  74 Epoch Average train accuracy :  0.9765386310223267
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 75 in 600 / Step : 0
#  75 Epoch Average train loss :  0.07273922181008635
#  75 Epoch Average train accuracy :  0.9758813160987074
# test AVG accuracy :  0.83
# ------------------------------
# Epoch : 76 in 600 / Step : 0
#  76 Epoch Average train loss :  0.07366149812131315
#  76 Epoch Average train accuracy :  0.9756224294947121
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 77 in 600 / Step : 0
#  77 Epoch Average train loss :  0.07854890592106795
#  77 Epoch Average train accuracy :  0.9756462984723855
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 78 in 600 / Step : 0
#  78 Epoch Average train loss :  0.07451965179092981
#  78 Epoch Average train accuracy :  0.9748017038777909
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 79 in 600 / Step : 0
#  79 Epoch Average train loss :  0.07190483678887422
#  79 Epoch Average train accuracy :  0.9758335781433608
# test AVG accuracy :  0.75
# ------------------------------
# Epoch : 80 in 600 / Step : 0
#  80 Epoch Average train loss :  0.07314867876168038
#  80 Epoch Average train accuracy :  0.9760685957696827
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 81 in 600 / Step : 0
#  81 Epoch Average train loss :  0.07920100690947997
#  81 Epoch Average train accuracy :  0.9746144242068155
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 82 in 600 / Step : 0
#  82 Epoch Average train loss :  0.07276695350034011
#  82 Epoch Average train accuracy :  0.9754112808460635
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 83 in 600 / Step : 0
#  83 Epoch Average train loss :  0.07283674474377688
#  83 Epoch Average train accuracy :  0.9752717391304347
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 84 in 600 / Step : 0
#  84 Epoch Average train loss :  0.07394520330205057
#  84 Epoch Average train accuracy :  0.9758097091656875
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 85 in 600 / Step : 0
#  85 Epoch Average train loss :  0.07259298010565643
#  85 Epoch Average train accuracy :  0.9769370593419506
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 86 in 600 / Step : 0
#  86 Epoch Average train loss :  0.06980495610450571
#  86 Epoch Average train accuracy :  0.9771482079905993
# test AVG accuracy :  0.77
# ------------------------------
# Epoch : 87 in 600 / Step : 0
#  87 Epoch Average train loss :  0.06977180051743179
#  87 Epoch Average train accuracy :  0.9773354876615746
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 88 in 600 / Step : 0
#  88 Epoch Average train loss :  0.06737381365854998
#  88 Epoch Average train accuracy :  0.9769131903642774
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 89 in 600 / Step : 0
#  89 Epoch Average train loss :  0.07608368373601823
#  89 Epoch Average train accuracy :  0.9745666862514689
# test AVG accuracy :  0.84
# ------------------------------
# Epoch : 90 in 600 / Step : 0
#  90 Epoch Average train loss :  0.07333759092599959
#  90 Epoch Average train accuracy :  0.9761163337250294
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 91 in 600 / Step : 0
#  91 Epoch Average train loss :  0.07759337680968079
#  91 Epoch Average train accuracy :  0.9745428172737955
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 92 in 600 / Step : 0
#  92 Epoch Average train loss :  0.07574061986461685
#  92 Epoch Average train accuracy :  0.9760685957696827
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 93 in 600 / Step : 0
#  93 Epoch Average train loss :  0.07503849399477444
#  93 Epoch Average train accuracy :  0.9763954171562869
# test AVG accuracy :  0.74
# ------------------------------
# Epoch : 94 in 600 / Step : 0
#  94 Epoch Average train loss :  0.07397899177630206
#  94 Epoch Average train accuracy :  0.9764908930669801
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 95 in 600 / Step : 0
#  95 Epoch Average train loss :  0.06891645161384666
#  95 Epoch Average train accuracy :  0.9771720769682727
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 96 in 600 / Step : 0
#  96 Epoch Average train loss :  0.07413151298926489
#  96 Epoch Average train accuracy :  0.9749651145710929
# test AVG accuracy :  0.83
# ------------------------------
# Epoch : 97 in 600 / Step : 0
#  97 Epoch Average train loss :  0.07174473472342298
#  97 Epoch Average train accuracy :  0.9764908930669801
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 98 in 600 / Step : 0
#  98 Epoch Average train loss :  0.06969859285556988
#  98 Epoch Average train accuracy :  0.9773116186839014
# test AVG accuracy :  0.83
# ------------------------------
# Epoch : 99 in 600 / Step : 0
#  99 Epoch Average train loss :  0.06665113925732472
#  99 Epoch Average train accuracy :  0.977359356639248
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 100 in 600 / Step : 0
#  100 Epoch Average train loss :  0.07289646742110317
#  100 Epoch Average train accuracy :  0.9760924647473561
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 101 in 600 / Step : 0
#  101 Epoch Average train loss :  0.06743331545510807
#  101 Epoch Average train accuracy :  0.9778055229142186
# test AVG accuracy :  0.82
# Saved checkpoint: C:\Users\USER\Desktop\All\Project\23_VRP\Classification\model\results_epoch_101_evalAcc_82.pth
# ------------------------------
# Epoch : 102 in 600 / Step : 0
#  102 Epoch Average train loss :  0.06857180628120094
#  102 Epoch Average train accuracy :  0.9771243390129261
# test AVG accuracy :  0.85
# ------------------------------
# Epoch : 103 in 600 / Step : 0
#  103 Epoch Average train loss :  0.06979239358868752
#  103 Epoch Average train accuracy :  0.9767259106933021
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 104 in 600 / Step : 0
#  104 Epoch Average train loss :  0.06909229654214673
#  104 Epoch Average train accuracy :  0.9760447267920095
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 105 in 600 / Step : 0
#  105 Epoch Average train loss :  0.07201857016598051
#  105 Epoch Average train accuracy :  0.9750128525264395
# test AVG accuracy :  0.84
# ------------------------------
# Epoch : 106 in 600 / Step : 0
#  106 Epoch Average train loss :  0.06877869833260775
#  106 Epoch Average train accuracy :  0.9763513513513513
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 107 in 600 / Step : 0
#  107 Epoch Average train loss :  0.07361796765109978
#  107 Epoch Average train accuracy :  0.9761163337250294
# test AVG accuracy :  0.84
# ------------------------------
# Epoch : 108 in 600 / Step : 0
# KeyboardInterrupt

# %%
if __name__ == "__main__":
    parser = argparse.ArgumentParser()

    parser.add_argument("-raw_data", default=load_path.format("dataset_2.txt"))
    parser.add_argument("-save_data", default=save_path)
    
    parser.add_argument("-max_len", default=20, type=int)
    parser.add_argument("-batch_size", default=128, type=int)
    parser.add_argument("-num_labels", default=21, type=int)
    parser.add_argument("-epochs", default=600, type=int)
    parser.add_argument("-seed_val", default=42, type=int)

    #args = parser.parse_args()
    args,_ = parser.parse_known_args()
    run(args)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# NVIDIA GeForce RTX 4070 available
# C:\Users\USER\anaconda3\Lib\site-packages\transformers\optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ------------------------------
# Epoch : 1 in 600 / Step : 0
#  1 Epoch Average train loss :  2.5276468380077466
#  1 Epoch Average train accuracy :  0.2514009253819036
# test AVG accuracy :  0.33
# Saved checkpoint: C:\Users\USER\Desktop\All\Project\23_VRP\Classification\model\results_epoch_1_evalAcc_33.pth
# ------------------------------
# Epoch : 2 in 600 / Step : 0
#  2 Epoch Average train loss :  2.110715878976358
#  2 Epoch Average train accuracy :  0.3645049941245594
# test AVG accuracy :  0.45
# ------------------------------
# Epoch : 3 in 600 / Step : 0
#  3 Epoch Average train loss :  1.748921023832785
#  3 Epoch Average train accuracy :  0.5124118683901292
# test AVG accuracy :  0.57
# ------------------------------
# Epoch : 4 in 600 / Step : 0
#  4 Epoch Average train loss :  1.444826093879906
#  4 Epoch Average train accuracy :  0.6138384988249118
# test AVG accuracy :  0.60
# ------------------------------
# Epoch : 5 in 600 / Step : 0
#  5 Epoch Average train loss :  1.1904516558389406
#  5 Epoch Average train accuracy :  0.690206374853114
# test AVG accuracy :  0.69
# ------------------------------
# Epoch : 6 in 600 / Step : 0
#  6 Epoch Average train loss :  1.0074698506174862
#  6 Epoch Average train accuracy :  0.7395949618096357
# test AVG accuracy :  0.69
# ------------------------------
# Epoch : 7 in 600 / Step : 0
#  7 Epoch Average train loss :  0.8539676392400587
#  7 Epoch Average train accuracy :  0.7806771445358403
# test AVG accuracy :  0.74
# ------------------------------
# Epoch : 8 in 600 / Step : 0
#  8 Epoch Average train loss :  0.7227444310446043
#  8 Epoch Average train accuracy :  0.8129590188014102
# test AVG accuracy :  0.76
# ------------------------------
# Epoch : 9 in 600 / Step : 0
#  9 Epoch Average train loss :  0.6299719005017668
#  9 Epoch Average train accuracy :  0.8412088719153937
# test AVG accuracy :  0.77
# ------------------------------
# Epoch : 10 in 600 / Step : 0
#  10 Epoch Average train loss :  0.5391392313145302
#  10 Epoch Average train accuracy :  0.8712397179788485
# test AVG accuracy :  0.76
# ------------------------------
# Epoch : 11 in 600 / Step : 0
#  11 Epoch Average train loss :  0.4655616935845968
#  11 Epoch Average train accuracy :  0.8873108842538191
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 12 in 600 / Step : 0
#  12 Epoch Average train loss :  0.42440787199381236
#  12 Epoch Average train accuracy :  0.894796562867215
# test AVG accuracy :  0.76
# ------------------------------
# Epoch : 13 in 600 / Step : 0
#  13 Epoch Average train loss :  0.3736864014251812
#  13 Epoch Average train accuracy :  0.909859723854289
# test AVG accuracy :  0.76
# ------------------------------
# Epoch : 14 in 600 / Step : 0
#  14 Epoch Average train loss :  0.3368464152555208
#  14 Epoch Average train accuracy :  0.918397473560517
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 15 in 600 / Step : 0
#  15 Epoch Average train loss :  0.3179219759799339
#  15 Epoch Average train accuracy :  0.9195248237367802
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 16 in 600 / Step : 0
#  16 Epoch Average train loss :  0.2728594058268779
#  16 Epoch Average train accuracy :  0.9309507197414806
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 17 in 600 / Step : 0
#  17 Epoch Average train loss :  0.2642760651337134
#  17 Epoch Average train accuracy :  0.9320542009400706
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 18 in 600 / Step : 0
#  18 Epoch Average train loss :  0.2395778985039608
#  18 Epoch Average train accuracy :  0.9347752643948295
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 19 in 600 / Step : 0
#  19 Epoch Average train loss :  0.2285832750636178
#  19 Epoch Average train accuracy :  0.9390459753231493
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 20 in 600 / Step : 0
#  20 Epoch Average train loss :  0.2201506042399922
#  20 Epoch Average train accuracy :  0.9400778495887192
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 21 in 600 / Step : 0
#  21 Epoch Average train loss :  0.20015255563162468
#  21 Epoch Average train accuracy :  0.9473285105757933
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 22 in 600 / Step : 0
#  22 Epoch Average train loss :  0.1899423039442784
#  22 Epoch Average train accuracy :  0.949300455346651
# test AVG accuracy :  0.72
# ------------------------------
# Epoch : 23 in 600 / Step : 0
#  23 Epoch Average train loss :  0.1976512126825951
#  23 Epoch Average train accuracy :  0.941978187426557
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 24 in 600 / Step : 0
#  24 Epoch Average train loss :  0.17454055324196815
#  24 Epoch Average train accuracy :  0.9500495740305523
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 25 in 600 / Step : 0
#  25 Epoch Average train loss :  0.16666168206044146
#  25 Epoch Average train accuracy :  0.9530056551116335
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 26 in 600 / Step : 0
#  26 Epoch Average train loss :  0.16905191007095413
#  26 Epoch Average train accuracy :  0.9523960781433608
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 27 in 600 / Step : 0
#  27 Epoch Average train loss :  0.16672748649442518
#  27 Epoch Average train accuracy :  0.953145196827262
# test AVG accuracy :  0.75
# ------------------------------
# Epoch : 28 in 600 / Step : 0
#  28 Epoch Average train loss :  0.15395941021474632
#  28 Epoch Average train accuracy :  0.9561490158636898
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 29 in 600 / Step : 0
#  29 Epoch Average train loss :  0.14538936759974505
#  29 Epoch Average train accuracy :  0.9588462103407754
# test AVG accuracy :  0.77
# ------------------------------
# Epoch : 30 in 600 / Step : 0
#  30 Epoch Average train loss :  0.1465479164711527
#  30 Epoch Average train accuracy :  0.9553044212690953
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 31 in 600 / Step : 0
#  31 Epoch Average train loss :  0.13847261737730052
#  31 Epoch Average train accuracy :  0.958706668625147
# test AVG accuracy :  0.76
# ------------------------------
# Epoch : 32 in 600 / Step : 0
#  32 Epoch Average train loss :  0.1370970890731425
#  32 Epoch Average train accuracy :  0.9601608401880142
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 33 in 600 / Step : 0
#  33 Epoch Average train loss :  0.13926300799121727
#  33 Epoch Average train accuracy :  0.9608658930669801
# test AVG accuracy :  0.77
# ------------------------------
# Epoch : 34 in 600 / Step : 0
#  34 Epoch Average train loss :  0.13599862339528832
#  34 Epoch Average train accuracy :  0.9597624118683902
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 35 in 600 / Step : 0
#  35 Epoch Average train loss :  0.13911437645957275
#  35 Epoch Average train accuracy :  0.9559617361927145
# test AVG accuracy :  0.76
# ------------------------------
# Epoch : 36 in 600 / Step : 0
#  36 Epoch Average train loss :  0.13204947204605952
#  36 Epoch Average train accuracy :  0.9600892332549941
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 37 in 600 / Step : 0
#  37 Epoch Average train loss :  0.13471678906195872
#  37 Epoch Average train accuracy :  0.9589416862514689
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 38 in 600 / Step : 0
#  38 Epoch Average train loss :  0.12398348164719504
#  38 Epoch Average train accuracy :  0.9614038631022328
# test AVG accuracy :  0.83
# ------------------------------
# Epoch : 39 in 600 / Step : 0
#  39 Epoch Average train loss :  0.12802374926773277
#  39 Epoch Average train accuracy :  0.9582843713278496
# test AVG accuracy :  0.77
# ------------------------------
# Epoch : 40 in 600 / Step : 0
#  40 Epoch Average train loss :  0.1286440414150019
#  40 Epoch Average train accuracy :  0.9561728848413632
# test AVG accuracy :  0.83
# ------------------------------
# Epoch : 41 in 600 / Step : 0
#  41 Epoch Average train loss :  0.12443703060617319
#  41 Epoch Average train accuracy :  0.9603958578143361
# test AVG accuracy :  0.76
# ------------------------------
# Epoch : 42 in 600 / Step : 0
#  42 Epoch Average train loss :  0.12457259895431029
#  42 Epoch Average train accuracy :  0.9586827996474736
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 43 in 600 / Step : 0
#  43 Epoch Average train loss :  0.12265099967653686
#  43 Epoch Average train accuracy :  0.9604197267920095
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 44 in 600 / Step : 0
#  44 Epoch Average train loss :  0.11848792383396947
#  44 Epoch Average train accuracy :  0.9608420240893067
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 45 in 600 / Step : 0
#  45 Epoch Average train loss :  0.12033728917909635
#  45 Epoch Average train accuracy :  0.9627662309048179
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 46 in 600 / Step : 0
#  46 Epoch Average train loss :  0.10987793483041428
#  46 Epoch Average train accuracy :  0.966120740305523
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 47 in 600 / Step : 0
#  47 Epoch Average train loss :  0.12144311416793514
#  47 Epoch Average train accuracy :  0.9641965334900118
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 48 in 600 / Step : 0
#  48 Epoch Average train loss :  0.12551080495924563
#  48 Epoch Average train accuracy :  0.9629057726204466
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 49 in 600 / Step : 0
#  49 Epoch Average train loss :  0.11088434274534921
#  49 Epoch Average train accuracy :  0.9636108254994125
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 50 in 600 / Step : 0
#  50 Epoch Average train loss :  0.11543378686985455
#  50 Epoch Average train accuracy :  0.9646188307873091
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 51 in 600 / Step : 0
#  51 Epoch Average train loss :  0.11295342566193761
#  51 Epoch Average train accuracy :  0.9625312132784959
# test AVG accuracy :  0.76
# ------------------------------
# Epoch : 52 in 600 / Step : 0
#  52 Epoch Average train loss :  0.1180919692222331
#  52 Epoch Average train accuracy :  0.9607465481786133
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 53 in 600 / Step : 0
#  53 Epoch Average train loss :  0.10629810503608472
#  53 Epoch Average train accuracy :  0.9631169212690953
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 54 in 600 / Step : 0
#  54 Epoch Average train loss :  0.11766926385462284
#  54 Epoch Average train accuracy :  0.9637981051703879
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 55 in 600 / Step : 0
#  55 Epoch Average train loss :  0.10839456103339389
#  55 Epoch Average train accuracy :  0.965160472972973
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 56 in 600 / Step : 0
#  56 Epoch Average train loss :  0.10543872264994157
#  56 Epoch Average train accuracy :  0.9627184929494713
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 57 in 600 / Step : 0
#  57 Epoch Average train loss :  0.10837981044440656
#  57 Epoch Average train accuracy :  0.9642681404230318
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 58 in 600 / Step : 0
#  58 Epoch Average train loss :  0.11468328122754355
#  58 Epoch Average train accuracy :  0.9614516010575794
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 59 in 600 / Step : 0
#  59 Epoch Average train loss :  0.10718587725549131
#  59 Epoch Average train accuracy :  0.9644315511163338
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 60 in 600 / Step : 0
#  60 Epoch Average train loss :  0.10706991188832231
#  60 Epoch Average train accuracy :  0.9657461809635723
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 61 in 600 / Step : 0
#  61 Epoch Average train loss :  0.10860912872453195
#  61 Epoch Average train accuracy :  0.9636585634547591
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 62 in 600 / Step : 0
#  62 Epoch Average train loss :  0.10662672356576533
#  62 Epoch Average train accuracy :  0.9640331227967098
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 63 in 600 / Step : 0
#  63 Epoch Average train loss :  0.10767180077429558
#  63 Epoch Average train accuracy :  0.9633280699177439
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 64 in 600 / Step : 0
#  64 Epoch Average train loss :  0.10378138866980334
#  64 Epoch Average train accuracy :  0.965088866039953
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 65 in 600 / Step : 0
#  65 Epoch Average train loss :  0.10057399467237897
#  65 Epoch Average train accuracy :  0.9651127350176264
# test AVG accuracy :  0.77
# ------------------------------
# Epoch : 66 in 600 / Step : 0
#  66 Epoch Average train loss :  0.10701406092659847
#  66 Epoch Average train accuracy :  0.9653000146886017
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 67 in 600 / Step : 0
#  67 Epoch Average train loss :  0.10299636964761727
#  67 Epoch Average train accuracy :  0.9635869565217392
# test AVG accuracy :  0.83
# ------------------------------
# Epoch : 68 in 600 / Step : 0
#  68 Epoch Average train loss :  0.09865381376113037
#  68 Epoch Average train accuracy :  0.9659334606345477
# test AVG accuracy :  0.83
# ------------------------------
# Epoch : 69 in 600 / Step : 0
#  69 Epoch Average train loss :  0.10275564997180088
#  69 Epoch Average train accuracy :  0.9633042009400706
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 70 in 600 / Step : 0
#  70 Epoch Average train loss :  0.10162922714811724
#  70 Epoch Average train accuracy :  0.9662602820211517
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 71 in 600 / Step : 0
#  71 Epoch Average train loss :  0.10111386917934224
#  71 Epoch Average train accuracy :  0.965323883666275
# test AVG accuracy :  0.73
# ------------------------------
# Epoch : 72 in 600 / Step : 0
#  72 Epoch Average train loss :  0.10358589384201411
#  72 Epoch Average train accuracy :  0.964077188601645
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 73 in 600 / Step : 0
#  73 Epoch Average train loss :  0.09921478544601013
#  73 Epoch Average train accuracy :  0.9663080199764983
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 74 in 600 / Step : 0
#  74 Epoch Average train loss :  0.09909853530493942
#  74 Epoch Average train accuracy :  0.964690437720329
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 75 in 600 / Step : 0
#  75 Epoch Average train loss :  0.10419093319089026
#  75 Epoch Average train accuracy :  0.9640092538190365
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 76 in 600 / Step : 0
#  76 Epoch Average train loss :  0.10335539543145411
#  76 Epoch Average train accuracy :  0.9639853848413632
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 77 in 600 / Step : 0
#  77 Epoch Average train loss :  0.10163579350085677
#  77 Epoch Average train accuracy :  0.9656745740305523
# test AVG accuracy :  0.77
# ------------------------------
# Epoch : 78 in 600 / Step : 0
#  78 Epoch Average train loss :  0.10146067341839946
#  78 Epoch Average train accuracy :  0.9644554200940071
# test AVG accuracy :  0.75
# ------------------------------
# Epoch : 79 in 600 / Step : 0
#  79 Epoch Average train loss :  0.10470501867097777
#  79 Epoch Average train accuracy :  0.965885722679201
# test AVG accuracy :  0.77
# ------------------------------
# Epoch : 80 in 600 / Step : 0
#  80 Epoch Average train loss :  0.09932979531082753
#  80 Epoch Average train accuracy :  0.9650172591069331
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 81 in 600 / Step : 0
#  81 Epoch Average train loss :  0.1019438292730499
#  81 Epoch Average train accuracy :  0.9636585634547591
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 82 in 600 / Step : 0
#  82 Epoch Average train loss :  0.1003488584648113
#  82 Epoch Average train accuracy :  0.9648299794359577
# test AVG accuracy :  0.77
# ------------------------------
# Epoch : 83 in 600 / Step : 0
#  83 Epoch Average train loss :  0.09935265702094782
#  83 Epoch Average train accuracy :  0.9670369418331375
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 84 in 600 / Step : 0
#  84 Epoch Average train loss :  0.10061328233899297
#  84 Epoch Average train accuracy :  0.9649456521739129
# test AVG accuracy :  0.77
# ------------------------------
# Epoch : 85 in 600 / Step : 0
#  85 Epoch Average train loss :  0.10204113305017755
#  85 Epoch Average train accuracy :  0.9645949618096358
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 86 in 600 / Step : 0
#  86 Epoch Average train loss :  0.09863256392811702
#  86 Epoch Average train accuracy :  0.9652284077555817
# test AVG accuracy :  0.75
# ------------------------------
# Epoch : 87 in 600 / Step : 0
#  87 Epoch Average train loss :  0.10319349612738635
#  87 Epoch Average train accuracy :  0.9654634253819037
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 88 in 600 / Step : 0
#  88 Epoch Average train loss :  0.09888844489044435
#  88 Epoch Average train accuracy :  0.9670130728554642
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 89 in 600 / Step : 0
#  89 Epoch Average train loss :  0.10054223511267353
#  89 Epoch Average train accuracy :  0.9654634253819037
# test AVG accuracy :  0.84
# ------------------------------
# Epoch : 90 in 600 / Step : 0
#  90 Epoch Average train loss :  0.09851208731934831
#  90 Epoch Average train accuracy :  0.9661446092831962
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 91 in 600 / Step : 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 15
#      13 #args = parser.parse_args()
#      14 args,_ = parser.parse_known_args()
# ---> 15 run(args)
#
# Cell In[9], line 166, in run(args)
#     164 train_dataloader = build_dataloader(train_ids, train_masks, train_labels, args)
#     165 test_dataloader = build_dataloader(test_ids, test_masks, test_labels, args)
# --> 166 train(train_dataloader, test_dataloader, args)
#
# Cell In[9], line 132, in train(train_dataloader, test_dataloader, args)
#     129 total_accuracy += accuracy
#     131 # 그레디언트 연산
# --> 132 loss.backward()
#     133 torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
#     135 # 파라미터 업데이트
#
# File ~\anaconda3\Lib\site-packages\torch\_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~\anaconda3\Lib\site-packages\torch\autograd\__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
if __name__ == "__main__":
    parser = argparse.ArgumentParser()

    parser.add_argument("-raw_data", default=load_path.format("dataset_3.txt"))
    parser.add_argument("-save_data", default=save_path)
    
    parser.add_argument("-max_len", default=20, type=int)
    parser.add_argument("-batch_size", default=128, type=int)
    parser.add_argument("-num_labels", default=21, type=int)
    parser.add_argument("-epochs", default=100, type=int)
    parser.add_argument("-seed_val", default=42, type=int)

    #args = parser.parse_args()
    args,_ = parser.parse_known_args()
    run(args)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# NVIDIA GeForce RTX 4070 available
# C:\Users\USER\anaconda3\Lib\site-packages\transformers\optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ------------------------------
# Epoch : 1 in 100 / Step : 0
#  1 Epoch Average train loss :  2.5777274853474386
#  1 Epoch Average train accuracy :  0.24330566980023505
# test AVG accuracy :  0.35
# Saved checkpoint: C:\Users\USER\Desktop\All\Project\23_VRP\Classification\model\results_epoch_1_evalAcc_35.pth
# ------------------------------
# Epoch : 2 in 100 / Step : 0
#  2 Epoch Average train loss :  2.141732441412436
#  2 Epoch Average train accuracy :  0.3737514688601645
# test AVG accuracy :  0.47
# ------------------------------
# Epoch : 3 in 100 / Step : 0
#  3 Epoch Average train loss :  1.7575612648113355
#  3 Epoch Average train accuracy :  0.5176905846063454
# test AVG accuracy :  0.60
# ------------------------------
# Epoch : 4 in 100 / Step : 0
#  4 Epoch Average train loss :  1.4352074056058317
#  4 Epoch Average train accuracy :  0.6341087690951821
# test AVG accuracy :  0.65
# ------------------------------
# Epoch : 5 in 100 / Step : 0
#  5 Epoch Average train loss :  1.1820481274579022
#  5 Epoch Average train accuracy :  0.7143250587544065
# test AVG accuracy :  0.71
# ------------------------------
# Epoch : 6 in 100 / Step : 0
#  6 Epoch Average train loss :  0.9904231300225129
#  6 Epoch Average train accuracy :  0.758833357814336
# test AVG accuracy :  0.73
# ------------------------------
# Epoch : 7 in 100 / Step : 0
#  7 Epoch Average train loss :  0.8640825055740975
#  7 Epoch Average train accuracy :  0.7861192714453583
# test AVG accuracy :  0.73
# ------------------------------
# Epoch : 8 in 100 / Step : 0
#  8 Epoch Average train loss :  0.7478970563089525
#  8 Epoch Average train accuracy :  0.8160583137485311
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 9 in 100 / Step : 0
#  9 Epoch Average train loss :  0.6420756916742067
#  9 Epoch Average train accuracy :  0.847941759694477
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 10 in 100 / Step : 0
#  10 Epoch Average train loss :  0.5601519531494862
#  10 Epoch Average train accuracy :  0.8626064923619271
# test AVG accuracy :  0.76
# ------------------------------
# Epoch : 11 in 100 / Step : 0
#  11 Epoch Average train loss :  0.5035546856957513
#  11 Epoch Average train accuracy :  0.880366847826087
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 12 in 100 / Step : 0
#  12 Epoch Average train loss :  0.4393509916357092
#  12 Epoch Average train accuracy :  0.8942787896592245
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 13 in 100 / Step : 0
#  13 Epoch Average train loss :  0.3899912479761484
#  13 Epoch Average train accuracy :  0.9050271739130435
# test AVG accuracy :  0.74
# ------------------------------
# Epoch : 14 in 100 / Step : 0
#  14 Epoch Average train loss :  0.35637324806806203
#  14 Epoch Average train accuracy :  0.914174500587544
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 15 in 100 / Step : 0
#  15 Epoch Average train loss :  0.32402675216262405
#  15 Epoch Average train accuracy :  0.9177438307873091
# test AVG accuracy :  0.76
# ------------------------------
# Epoch : 16 in 100 / Step : 0
#  16 Epoch Average train loss :  0.30968299548368194
#  16 Epoch Average train accuracy :  0.9229270710928319
# test AVG accuracy :  0.74
# ------------------------------
# Epoch : 17 in 100 / Step : 0
#  17 Epoch Average train loss :  0.2816077994333731
#  17 Epoch Average train accuracy :  0.9314207549941247
# test AVG accuracy :  0.77
# ------------------------------
# Epoch : 18 in 100 / Step : 0
#  18 Epoch Average train loss :  0.25603730694667715
#  18 Epoch Average train accuracy :  0.935432579318449
# test AVG accuracy :  0.74
# ------------------------------
# Epoch : 19 in 100 / Step : 0
#  19 Epoch Average train loss :  0.23772912049615705
#  19 Epoch Average train accuracy :  0.9418625146886017
# test AVG accuracy :  0.77
# ------------------------------
# Epoch : 20 in 100 / Step : 0
#  20 Epoch Average train loss :  0.2169495086009438
#  20 Epoch Average train accuracy :  0.947069623971798
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 21 in 100 / Step : 0
#  21 Epoch Average train loss :  0.21096287828844948
#  21 Epoch Average train accuracy :  0.946671195652174
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 22 in 100 / Step : 0
#  22 Epoch Average train loss :  0.2085613259995306
#  22 Epoch Average train accuracy :  0.9458266010575794
# test AVG accuracy :  0.75
# ------------------------------
# Epoch : 23 in 100 / Step : 0
#  23 Epoch Average train loss :  0.19452420340196505
#  23 Epoch Average train accuracy :  0.950260722679201
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 24 in 100 / Step : 0
#  24 Epoch Average train loss :  0.18025811399156982
#  24 Epoch Average train accuracy :  0.9530056551116335
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 25 in 100 / Step : 0
#  25 Epoch Average train loss :  0.18588179088122136
#  25 Epoch Average train accuracy :  0.9481731051703879
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 26 in 100 / Step : 0
#  26 Epoch Average train loss :  0.1634684835334082
#  26 Epoch Average train accuracy :  0.9577225323149237
# test AVG accuracy :  0.75
# ------------------------------
# Epoch : 27 in 100 / Step : 0
#  27 Epoch Average train loss :  0.1706731677860827
#  27 Epoch Average train accuracy :  0.9521133225616922
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 28 in 100 / Step : 0
#  28 Epoch Average train loss :  0.1658087195576848
#  28 Epoch Average train accuracy :  0.9523483401880142
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 29 in 100 / Step : 0
#  29 Epoch Average train loss :  0.1540244306261475
#  29 Epoch Average train accuracy :  0.9572047591069331
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 30 in 100 / Step : 0
#  30 Epoch Average train loss :  0.16060071468756004
#  30 Epoch Average train accuracy :  0.9529579171562869
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 31 in 100 / Step : 0
#  31 Epoch Average train loss :  0.15161696791246132
#  31 Epoch Average train accuracy :  0.9561490158636898
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 32 in 100 / Step : 0
#  32 Epoch Average train loss :  0.1436997251333417
#  32 Epoch Average train accuracy :  0.9588939482961223
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 33 in 100 / Step : 0
#  33 Epoch Average train loss :  0.13890494345813184
#  33 Epoch Average train accuracy :  0.9631646592244418
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 34 in 100 / Step : 0
#  34 Epoch Average train loss :  0.14422925360299446
#  34 Epoch Average train accuracy :  0.9563601645123385
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 35 in 100 / Step : 0
#  35 Epoch Average train loss :  0.13274999204519633
#  35 Epoch Average train accuracy :  0.9618500293772033
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 36 in 100 / Step : 0
#  36 Epoch Average train loss :  0.13496773820873853
#  36 Epoch Average train accuracy :  0.9601369712103409
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 37 in 100 / Step : 0
#  37 Epoch Average train loss :  0.12586732289275607
#  37 Epoch Average train accuracy :  0.9618738983548767
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 38 in 100 / Step : 0
#  38 Epoch Average train loss :  0.12777152113817833
#  38 Epoch Average train accuracy :  0.9624834753231493
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 39 in 100 / Step : 0
#  39 Epoch Average train loss :  0.12868613115436323
#  39 Epoch Average train accuracy :  0.9614038631022328
# test AVG accuracy :  0.75
# ------------------------------
# Epoch : 40 in 100 / Step : 0
#  40 Epoch Average train loss :  0.13128881317538185
#  40 Epoch Average train accuracy :  0.9602324471210342
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 41 in 100 / Step : 0
#  41 Epoch Average train loss :  0.12493256006289173
#  41 Epoch Average train accuracy :  0.9610770417156287
# test AVG accuracy :  0.77
# ------------------------------
# Epoch : 42 in 100 / Step : 0
#  42 Epoch Average train loss :  0.12132209539413452
#  42 Epoch Average train accuracy :  0.9646188307873091
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 43 in 100 / Step : 0
#  43 Epoch Average train loss :  0.11992886793371793
#  43 Epoch Average train accuracy :  0.9621089159811986
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 44 in 100 / Step : 0
#  44 Epoch Average train loss :  0.12566043245228561
#  44 Epoch Average train accuracy :  0.9612881903642774
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 45 in 100 / Step : 0
#  45 Epoch Average train loss :  0.11630490824982927
#  45 Epoch Average train accuracy :  0.9629773795534665
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 46 in 100 / Step : 0
#  46 Epoch Average train loss :  0.1181381222968166
#  46 Epoch Average train accuracy :  0.9622723266745007
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 47 in 100 / Step : 0
#  47 Epoch Average train loss :  0.11893230898154748
#  47 Epoch Average train accuracy :  0.9625312132784959
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 48 in 100 / Step : 0
#  48 Epoch Average train loss :  0.1152687677861871
#  48 Epoch Average train accuracy :  0.9650411280846064
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 49 in 100 / Step : 0
#  49 Epoch Average train loss :  0.112424854289841
#  49 Epoch Average train accuracy :  0.9642204024676851
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 50 in 100 / Step : 0
#  50 Epoch Average train loss :  0.1105507292054795
#  50 Epoch Average train accuracy :  0.965722311985899
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 51 in 100 / Step : 0
#  51 Epoch Average train loss :  0.1136219779381881
#  51 Epoch Average train accuracy :  0.9644554200940071
# test AVG accuracy :  0.77
# ------------------------------
# Epoch : 52 in 100 / Step : 0
#  52 Epoch Average train loss :  0.10823873994318214
#  52 Epoch Average train accuracy :  0.9656507050528791
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 53 in 100 / Step : 0
#  53 Epoch Average train loss :  0.10876758326147054
#  53 Epoch Average train accuracy :  0.9648299794359577
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 54 in 100 / Step : 0
#  54 Epoch Average train loss :  0.10709739365690463
#  54 Epoch Average train accuracy :  0.9650649970622798
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 55 in 100 / Step : 0
#  55 Epoch Average train loss :  0.10784174285426333
#  55 Epoch Average train accuracy :  0.9662162162162162
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 56 in 100 / Step : 0
#  56 Epoch Average train loss :  0.10830463584814523
#  56 Epoch Average train accuracy :  0.9646426997649824
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 57 in 100 / Step : 0
#  57 Epoch Average train loss :  0.10530432001561732
#  57 Epoch Average train accuracy :  0.9664034958871915
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 58 in 100 / Step : 0
#  58 Epoch Average train loss :  0.10737632466731845
#  58 Epoch Average train accuracy :  0.9637742361927145
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 59 in 100 / Step : 0
#  59 Epoch Average train loss :  0.10733981098274926
#  59 Epoch Average train accuracy :  0.9652761457109283
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 60 in 100 / Step : 0
#  60 Epoch Average train loss :  0.10366565200525361
#  60 Epoch Average train accuracy :  0.965487294359577
# test AVG accuracy :  0.76
# ------------------------------
# Epoch : 61 in 100 / Step : 0
#  61 Epoch Average train loss :  0.10575139720143902
#  61 Epoch Average train accuracy :  0.964292009400705
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 62 in 100 / Step : 0
#  62 Epoch Average train loss :  0.1057160142305735
#  62 Epoch Average train accuracy :  0.9651127350176264
# test AVG accuracy :  0.77
# ------------------------------
# Epoch : 63 in 100 / Step : 0
#  63 Epoch Average train loss :  0.1053082297832982
#  63 Epoch Average train accuracy :  0.9639615158636898
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 64 in 100 / Step : 0
#  64 Epoch Average train loss :  0.10181001206306187
#  64 Epoch Average train accuracy :  0.9668257931844888
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 65 in 100 / Step : 0
#  65 Epoch Average train loss :  0.102589029667748
#  65 Epoch Average train accuracy :  0.9653000146886017
# test AVG accuracy :  0.77
# ------------------------------
# Epoch : 66 in 100 / Step : 0
#  66 Epoch Average train loss :  0.10388100403990294
#  66 Epoch Average train accuracy :  0.9668019242068155
# test AVG accuracy :  0.77
# ------------------------------
# Epoch : 67 in 100 / Step : 0
#  67 Epoch Average train loss :  0.10343068956422645
#  67 Epoch Average train accuracy :  0.9675749118683902
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 68 in 100 / Step : 0
#  68 Epoch Average train loss :  0.10110502939268544
#  68 Epoch Average train accuracy :  0.9663557579318449
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 69 in 100 / Step : 0
#  69 Epoch Average train loss :  0.10515462355436506
#  69 Epoch Average train accuracy :  0.9656507050528791
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 70 in 100 / Step : 0
#  70 Epoch Average train loss :  0.10169662696284217
#  70 Epoch Average train accuracy :  0.9669414659224442
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 71 in 100 / Step : 0
#  71 Epoch Average train loss :  0.10045944275082769
#  71 Epoch Average train accuracy :  0.9665669065804936
# test AVG accuracy :  0.72
# ------------------------------
# Epoch : 72 in 100 / Step : 0
#  72 Epoch Average train loss :  0.10143399052321911
#  72 Epoch Average train accuracy :  0.9657902467685076
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 73 in 100 / Step : 0
#  73 Epoch Average train loss :  0.09970137103133507
#  73 Epoch Average train accuracy :  0.965487294359577
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 74 in 100 / Step : 0
#  74 Epoch Average train loss :  0.10087914996453233
#  74 Epoch Average train accuracy :  0.9661684782608696
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 75 in 100 / Step : 0
#  75 Epoch Average train loss :  0.09993889107293374
#  75 Epoch Average train accuracy :  0.9669653349001176
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 76 in 100 / Step : 0
#  76 Epoch Average train loss :  0.1013137492779139
#  76 Epoch Average train accuracy :  0.9652761457109283
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 77 in 100 / Step : 0
#  77 Epoch Average train loss :  0.10128450705795675
#  77 Epoch Average train accuracy :  0.9660968713278496
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 78 in 100 / Step : 0
#  78 Epoch Average train loss :  0.10046406613813864
#  78 Epoch Average train accuracy :  0.9663796269095183
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 79 in 100 / Step : 0
#  79 Epoch Average train loss :  0.09961785396208635
#  79 Epoch Average train accuracy :  0.9669414659224442
# test AVG accuracy :  0.78
# ------------------------------
# Epoch : 80 in 100 / Step : 0
#  80 Epoch Average train loss :  0.09886771873445124
#  80 Epoch Average train accuracy :  0.9660968713278496
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 81 in 100 / Step : 0
#  81 Epoch Average train loss :  0.09981313720345497
#  81 Epoch Average train accuracy :  0.9668257931844888
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 82 in 100 / Step : 0
#  82 Epoch Average train loss :  0.09985473052271314
#  82 Epoch Average train accuracy :  0.9667303172737955
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 83 in 100 / Step : 0
#  83 Epoch Average train loss :  0.09886008282695469
#  83 Epoch Average train accuracy :  0.9668496621621622
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 84 in 100 / Step : 0
#  84 Epoch Average train loss :  0.09812330152537371
#  84 Epoch Average train accuracy :  0.9671287455934195
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 85 in 100 / Step : 0
#  85 Epoch Average train loss :  0.09870709488923485
#  85 Epoch Average train accuracy :  0.9660730023501763
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 86 in 100 / Step : 0
#  86 Epoch Average train loss :  0.097846497381987
#  86 Epoch Average train accuracy :  0.9675987808460635
# test AVG accuracy :  0.75
# ------------------------------
# Epoch : 87 in 100 / Step : 0
#  87 Epoch Average train loss :  0.09859883679530106
#  87 Epoch Average train accuracy :  0.9665430376028202
# test AVG accuracy :  0.79
# ------------------------------
# Epoch : 88 in 100 / Step : 0
#  88 Epoch Average train loss :  0.09862870436061073
#  88 Epoch Average train accuracy :  0.9663557579318449
# test AVG accuracy :  0.80
# ------------------------------
# Epoch : 89 in 100 / Step : 0
#  89 Epoch Average train loss :  0.09865033888333552
#  89 Epoch Average train accuracy :  0.966519168625147
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 90 in 100 / Step : 0
#  90 Epoch Average train loss :  0.0983188103985142
#  90 Epoch Average train accuracy :  0.9663318889541717
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 91 in 100 / Step : 0
#  91 Epoch Average train loss :  0.09856973908136825
#  91 Epoch Average train accuracy :  0.9656507050528791
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 92 in 100 / Step : 0
#  92 Epoch Average train loss :  0.09654954317453746
#  92 Epoch Average train accuracy :  0.9661446092831962
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 93 in 100 / Step : 0
#  93 Epoch Average train loss :  0.09721206214178253
#  93 Epoch Average train accuracy :  0.967316025264395
# test AVG accuracy :  0.75
# ------------------------------
# Epoch : 94 in 100 / Step : 0
#  94 Epoch Average train loss :  0.09691394516896154
#  94 Epoch Average train accuracy :  0.9672003525264395
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 95 in 100 / Step : 0
#  95 Epoch Average train loss :  0.09685764320798822
#  95 Epoch Average train accuracy :  0.9670369418331375
# test AVG accuracy :  0.83
# ------------------------------
# Epoch : 96 in 100 / Step : 0
#  96 Epoch Average train loss :  0.09762918737691802
#  96 Epoch Average train accuracy :  0.966917596944771
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 97 in 100 / Step : 0
#  97 Epoch Average train loss :  0.09813627510054691
#  97 Epoch Average train accuracy :  0.9673637632197416
# test AVG accuracy :  0.82
# ------------------------------
# Epoch : 98 in 100 / Step : 0
#  98 Epoch Average train loss :  0.09899227542651666
#  98 Epoch Average train accuracy :  0.9664952996474736
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 99 in 100 / Step : 0
#  99 Epoch Average train loss :  0.0971807732271987
#  99 Epoch Average train accuracy :  0.9672003525264395
# test AVG accuracy :  0.81
# ------------------------------
# Epoch : 100 in 100 / Step : 0
#  100 Epoch Average train loss :  0.09869748494915061
#  100 Epoch Average train accuracy :  0.9672003525264395
# test AVG accuracy :  0.80

# %%
if __name__ == "__main__":
    parser = argparse.ArgumentParser()

    parser.add_argument("-raw_data", default=load_path.format("dataset_4.txt"))
    parser.add_argument("-save_data", default=save_path)
    
    parser.add_argument("-max_len", default=20, type=int)
    parser.add_argument("-batch_size", default=128, type=int)
    parser.add_argument("-num_labels", default=21, type=int)
    parser.add_argument("-epochs", default=10, type=int)
    parser.add_argument("-seed_val", default=42, type=int)

    #args = parser.parse_args()
    args,_ = parser.parse_known_args()
    run(args)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# NVIDIA GeForce RTX 4070 available
# C:\Users\USER\anaconda3\Lib\site-packages\transformers\optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ------------------------------
# Epoch : 1 in 10 / Step : 0
# Epoch : 1 in 10 / Step : 500
#  1 Epoch Average train loss :  0.9538592897344648
#  1 Epoch Average train accuracy :  0.7443796309916394
# test AVG accuracy :  0.9455
# Saved checkpoint: C:\Users\USER\Desktop\All\Project\23_VRP\Classification\model\results_epoch_1_evalAcc_95.pth
# ------------------------------
# Epoch : 2 in 10 / Step : 0
# Epoch : 2 in 10 / Step : 500
#  2 Epoch Average train loss :  0.19249380348825698
#  2 Epoch Average train accuracy :  0.9494007505370753
# test AVG accuracy :  0.9716
# ------------------------------
# Epoch : 3 in 10 / Step : 0
# Epoch : 3 in 10 / Step : 500
#  3 Epoch Average train loss :  0.10919437655159116
#  3 Epoch Average train accuracy :  0.9681964618026574
# test AVG accuracy :  0.9781
# ------------------------------
# Epoch : 4 in 10 / Step : 0
# Epoch : 4 in 10 / Step : 500
#  4 Epoch Average train loss :  0.0866916540438803
#  4 Epoch Average train accuracy :  0.973581753465333
# test AVG accuracy :  0.9773
# ------------------------------
# Epoch : 5 in 10 / Step : 0
# Epoch : 5 in 10 / Step : 500
#  5 Epoch Average train loss :  0.07564381414466698
#  5 Epoch Average train accuracy :  0.9754599134864055
# test AVG accuracy :  0.9779
# ------------------------------
# Epoch : 6 in 10 / Step : 0
# Epoch : 6 in 10 / Step : 500
#  6 Epoch Average train loss :  0.06919904966773206
#  6 Epoch Average train accuracy :  0.977107058435161
# test AVG accuracy :  0.9788
# Saved checkpoint: C:\Users\USER\Desktop\All\Project\23_VRP\Classification\model\results_epoch_6_evalAcc_98.pth
# ------------------------------
# Epoch : 7 in 10 / Step : 0
# Epoch : 7 in 10 / Step : 500
#  7 Epoch Average train loss :  0.06679637208442908
#  7 Epoch Average train accuracy :  0.977324390060344
# test AVG accuracy :  0.9785
# ------------------------------
# Epoch : 8 in 10 / Step : 0
# Epoch : 8 in 10 / Step : 500
#  8 Epoch Average train loss :  0.06400037970161065
#  8 Epoch Average train accuracy :  0.9778597549294619
# test AVG accuracy :  0.9787
# ------------------------------
# Epoch : 9 in 10 / Step : 0
# Epoch : 9 in 10 / Step : 500
#  9 Epoch Average train loss :  0.06241963206172347
#  9 Epoch Average train accuracy :  0.9780907700017789
# test AVG accuracy :  0.9788
# ------------------------------
# Epoch : 10 in 10 / Step : 0
# Epoch : 10 in 10 / Step : 500
#  10 Epoch Average train loss :  0.06089933181076214
#  10 Epoch Average train accuracy :  0.9786947659104281
# test AVG accuracy :  0.9788
